# %% [markdown]
# # Text Processing
#
# ## Capturing Text Data
#
# ### Plain Text

# %%
import os

# Read in a plain text file
with open(os.path.join("data", "hieroglyph.txt"), "r") as f:
    text = f.read()
    print(text)
# Out:
# Hieroglyphic writing dates from c. 3000 BC, and is composed of hundreds of symbols. A hieroglyph can represent a word, a sound, or a silent determinative; and the same symbol can serve different purposes in different contexts. Hieroglyphs were a formal script, used on stone monuments and in tombs, that could be as detailed as individual works of art.

# %% [markdown]
# ### Tabular Data

# %%
import pandas as pd

# Extract text column from a dataframe
df = pd.read_csv(os.path.join("data", "news.csv"))
df.head()[['publisher', 'title']]

# Convert text column to lowercase
df['title'] = df['title'].str.lower()
df.head()[['publisher', 'title']]
# Out:
#       publisher                                              title
# 0      Livemint  fed's charles plosser sees high bar for change...
# 1  IFA Magazine  us open: stocks fall after fed official hints ...
# 2  IFA Magazine  fed risks falling 'behind the curve', charles ...
# 3     Moneynews  fed's plosser: nasty weather has curbed job gr...
# 4        NASDAQ  plosser: fed may have to accelerate tapering pace

# %% [markdown]
# ### Online Resource

# %%
import requests
import json

# Fetch data from a REST API
r = requests.get(
    "https://quotes.rest/qod.json")
res = r.json()
print(json.dumps(res, indent=4))

# Extract relevant object and field
q = res["contents"]["quotes"][0]
print(q["quote"], "\n--", q["author"])
# Out:
# {
#     "success": {
#         "total": 1
#     },
#     "contents": {
#         "quotes": [
#             {
#                 "quote": "What you do speaks so loudly that I cannot hear what you say.",
#                 "length": "61",
#                 "author": "Ralph Waldo Emerson",
#                 "tags": [
#                     "action",
#                     "inspire",
#                     "leadership",
#                     "management"
#                 ],
#                 "category": "inspire",
#                 "date": "2017-11-01",
#                 "permalink": "https://theysaidso.com/quote/eZ0NtMPtGp8c5eQJOBfJmweF/ralph-waldo-emerson-what-you-do-speaks-so-loudly-that-i-cannot-hear-what-you-say",
#                 "title": "Inspiring Quote of the day",
#                 "background": "https://theysaidso.com/img/bgs/man_on_the_mountain.jpg",
#                 "id": "eZ0NtMPtGp8c5eQJOBfJmweF"
#             }
#         ],
#         "copyright": "2017-19 theysaidso.com"
#     }
# }
# What you do speaks so loudly that I cannot hear what you say.
# -- Ralph Waldo Emerson

# %% [markdown]
# ## Cleaning

# %%
import requests

# Fetch a web page
r = requests.get("https://www.udacity.com/courses/all")
print(r.text)
# Out:
# <!DOCTYPE html><html><head><meta charset="utf-8"><title>Udacity | Udacity</title><base href="/"><meta name="viewport" content="width=device-width,initial-scale=1"><link rel="icon" type="image/x-icon" href="favicon.ico"><script src="/assets/vendor/segment.js" async=""></script><link href="styles.fc8884d3bc103d3339c0.bundle.css" rel="stylesheet"><style ng-transition="my-app-id">html[_ngcontent-c0] {
#   box-sizing: border-box; }
#
# *[_ngcontent-c0], *[_ngcontent-c0]::after, *[_ngcontent-c0]::before {
#   box-sizing: inherit; }
#
# a[_ngcontent-c0] {
#   color: darkviolet; }
#
# body[_ngcontent-c0] {
#   color: #028bb1; }
#
# [_nghost-c0] {
#   display: block;
#   position: relative; }</style><style ng-transition="my-app-id">html[_ngcontent-c1] {
#   box-sizing: border-box; }
#
# *[_ngcontent-c1], *[_ngcontent-c1]::after, *[_ngcontent-c1]::before {
#   box-sizing: inherit; }
#
# .invisible[_ngcontent-c1] {
#   visibility: hidden !important; }
#
# .hide[_ngcontent-c1] {
#   display: none !important; }
#
# .show[_ngcontent-c1] {
#   display: block !important; }
#
# .sr-only[_ngcontent-c1] {
#   height: 1px;
#   width: 1px;
#   overflow: hidden;
#   position: absolute !important;
#   clip: rect(1px, 1px, 1px, 1px); }
#
# .hidden-xs-up[_ngcontent-c1] {
#   display: none !important; }
#
# @media (max-width: 479px) {
#   .hidden-xs-down[_ngcontent-c1] {
#     display: none !important; } }
#
# @media (min-width: 480px) {
#   .hidden-sm-up[_ngcontent-c1] {
#     display: none !important; } }
#
# @media (max-width: 767px) {
#   .hidden-sm-down[_ngcontent-c1] {
#     display: none !important; } }
#
# @media (min-width: 768px) {
#   .hidden-md-up[_ngcontent-c1] {
#     display: none !important; } }
#
# @media (max-width: 991px) {
#   .hidden-md-down[_ngcontent-c1] {
#     display: none !important; } }
#
# @media (min-width: 992px) {
#   .hidden-lg-up[_ngcontent-c1] {
#     display: none !important; } }
#
# @media (max-width: 1179px) {
#   .hidden-lg-down[_ngcontent-c1] {
#     display: none !important; } }
#
# @media (min-width: 1180px) {
#   .hidden-xl-up[_ngcontent-c1] {
#     display: none !important; } }
#
# .hidden-xl-down[_ngcontent-c1] {
#   display: none !important; }
#
# .visible-print-block[_ngcontent-c1] {
#   display: none !important; }
#   @media print {
#     .visible-print-block[_ngcontent-c1] {
#       display: block !important; } }
#
# .visible-print-inline[_ngcontent-c1] {
#   display: none !important; }
#   @media print {
#     .visible-print-inline[_ngcontent-c1] {
#       display: inline !important; } }
#
# .visible-print-inline-block[_ngcontent-c1] {
#   display: none !important; }
#   @media print {
#     .visible-print-inline-block[_ngcontent-c1] {
#       display: inline-block !important; } }
#
# @media print {
#   .hidden-print[_ngcontent-c1] {
#     display: none !important; } }
#
# #contain-all[_ngcontent-c1] {
#   width: 100%;
#   overflow: hidden;
#   background: #fff;
#   backface-visibility: hidden;
#   -webkit-transform-style: preserve-3d; }
#
# .outer_contain[_ngcontent-c1] {
#   margin: 0 auto;
#   max-width: 90rem; }
#
# .contain[_ngcontent-c1] {
#   max-width: 73.75rem;
#   margin-left: auto;
#   margin-right: auto;
#   padding-top: 3rem;
#   padding-bottom: 3rem;
#   padding-left: 1.5rem;
#   padding-right: 1.5rem; }
#   .contain[_ngcontent-c1]::after {
#     clear: both;
#     content: "";
#     display: table; }
#   @media screen and (min-width: 48rem) {
#     .contain[_ngcontent-c1] {
#       padding-top: 6rem;
#       padding-bottom: 6rem; } }
#   @media screen and (min-width: 73.75rem) {
#     .contain[_ngcontent-c1] {
#       padding-left: 0;
#       padding-right: 0; } }
#   .contain.no-padding[_ngcontent-c1] {
#     padding: 0; }
#   .contain.no-padding-top[_ngcontent-c1] {
#     padding-top: 0; }
#   .contain.no-padding-bottom[_ngcontent-c1] {
#     padding-bottom: 0; }
#   .contain--none[_ngcontent-c1] {
#     padding-top: 0rem;
#     padding-bottom: 0rem;
#     margin: 0 auto; }
#     @media screen and (min-width: 48rem) {
#       .contain--none[_ngcontent-c1] {
#         padding-top: 0rem;
#         padding-bottom: 0rem; } }
#   .contain--small[_ngcontent-c1] {
#     padding-top: 3rem;
#     padding-bottom: 3rem;
#     margin: 0 auto; }
#     @media screen and (min-width: 48rem) {
#       .contain--small[_ngcontent-c1] {
#         padding-top: 4.5rem;
#         padding-bottom: 4.5rem; } }
#
# .cards_contain[_ngcontent-c1] {
#   max-width: 73.75rem;
#   margin-left: auto;
#   margin-right: auto; }
#   .cards_contain[_ngcontent-c1]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# [_ngcontent-c1]:target:before {
#   content: '';
#   display: inline-block;
#   height: 130px;
#   margin: -130px 0 0; }
#
# .header[_ngcontent-c1] {
#   max-width: 100%;
#   margin-left: auto;
#   margin-right: auto; }
#   .header[_ngcontent-c1]::after {
#     clear: both;
#     content: "";
#     display: table; }
#   .header.header--clone[_ngcontent-c1] {
#     width: 100%;
#     top: -1000px; }
#     .header.header--clone[_ngcontent-c1]   .header__navbar[_ngcontent-c1] {
#       height: 4.5rem; }
#   .header.header--stick[_ngcontent-c1] {
#     top: 0;
#     background-color: #fff;
#     z-index: 8000;
#     box-shadow: 0px 1px 2px rgba(0, 0, 0, 0.1); }
#   .header__navbar[_ngcontent-c1] {
#     max-width: 73.75rem;
#     margin-left: auto;
#     margin-right: auto;
#     height: 4.5rem;
#     padding: 0 1.5em; }
#     .header__navbar[_ngcontent-c1]::after {
#       clear: both;
#       content: "";
#       display: table; }
#     @media screen and (min-width: 48rem) {
#       .header__navbar[_ngcontent-c1] {
#         height: 6rem; } }
#     @media screen and (min-width: 73.75rem) {
#       .header__navbar[_ngcontent-c1] {
#         padding: 0; } }
#     .header__navbar--toggle[_ngcontent-c1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       -moz-transform: translateY(-50%);
#       -ms-transform: translateY(-50%);
#       -o-transform: translateY(-50%);
#       transform: translateY(-50%);
#       float: left;
#       display: block;
#       margin-right: 1.69492%;
#       width: 15.25424%; }
#       .header__navbar--toggle[_ngcontent-c1]:last-child {
#         margin-right: 0; }
#       @media screen and (min-width: 30rem) {
#         .header__navbar--toggle[_ngcontent-c1] {
#           display: none; } }
#     .header__navbar--logo[_ngcontent-c1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       -moz-transform: translateY(-50%);
#       -ms-transform: translateY(-50%);
#       -o-transform: translateY(-50%);
#       transform: translateY(-50%);
#       float: left;
#       display: block;
#       margin-right: 1.69492%;
#       width: 66.10169%; }
#       .header__navbar--logo[_ngcontent-c1]:last-child {
#         margin-right: 0; }
#       @media screen and (min-width: 30rem) {
#         .header__navbar--logo[_ngcontent-c1] {
#           float: left;
#           display: block;
#           margin-right: 1.69492%;
#           width: 23.72881%; }
#           .header__navbar--logo[_ngcontent-c1]:last-child {
#             margin-right: 0; } }
#     .header__navbar--navigation[_ngcontent-c1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       -moz-transform: translateY(-50%);
#       -ms-transform: translateY(-50%);
#       -o-transform: translateY(-50%);
#       transform: translateY(-50%);
#       display: none; }
#       @media screen and (min-width: 30rem) {
#         .header__navbar--navigation[_ngcontent-c1] {
#           float: left;
#           display: block;
#           margin-right: 1.69492%;
#           width: 74.57627%; }
#           .header__navbar--navigation[_ngcontent-c1]:last-child {
#             margin-right: 0; } }
#   .header__navbar--logo[_ngcontent-c1] {
#     text-align: center; }
#     @media screen and (min-width: 30rem) {
#       .header__navbar--logo[_ngcontent-c1] {
#         text-align: left; } }
#     .header__navbar--logo[_ngcontent-c1]   .logo-wordmark[_ngcontent-c1] {
#       width: 11.25rem;
#       height: 1.875rem;
#       display: none; }
#       @media screen and (min-width: 30rem) {
#         .header__navbar--logo[_ngcontent-c1]   .logo-wordmark[_ngcontent-c1] {
#           display: block; } }
#     .header__navbar--logo[_ngcontent-c1]   .logo-mark[_ngcontent-c1] {
#       display: block;
#       margin: 0 auto;
#       width: 1.875rem;
#       height: 1.875rem; }
#       @media screen and (min-width: 30rem) {
#         .header__navbar--logo[_ngcontent-c1]   .logo-mark[_ngcontent-c1] {
#           display: none; } }
#   .header__navbar--toggle[_ngcontent-c1]   .nav-toggle[_ngcontent-c1] {
#     display: block;
#     width: 1.25rem;
#     height: 1.25rem;
#     cursor: pointer;
#     transition: transform .25s ease; }
#     .header__navbar--toggle[_ngcontent-c1]   .nav-toggle[_ngcontent-c1]   .bar[_ngcontent-c1] {
#       display: block;
#       width: 100%;
#       height: 0.1875rem;
#       margin-left: -0.5rem;
#       margin-top: 0.1875rem;
#       background: #02b3e4;
#       transition: opacity .25s ease, transform .25s ease;
#       user-select: none; }
#   .header__navbar--navigation[_ngcontent-c1]   nav[_ngcontent-c1] {
#     float: right; }
#   .header__navbar--navigation[_ngcontent-c1]   a[_ngcontent-c1], .header__navbar--navigation[_ngcontent-c1]   div[_ngcontent-c1] {
#     float: left; }
#   .header__navbar--navigation[_ngcontent-c1]   .button[_ngcontent-c1] {
#     display: none;
#     letter-spacing: 0;
#     font-size: 0.875rem;
#     text-transform: capitalize;
#     height: 2.25rem;
#     font-weight: 400;
#     margin-left: 2.5rem;
#     line-height: 1.9375rem; }
#     .header__navbar--navigation[_ngcontent-c1]   .button[_ngcontent-c1]:first-child {
#       margin-left: 0; }
#     @media screen and (min-width: 62rem) {
#       .header__navbar--navigation[_ngcontent-c1]   .button[_ngcontent-c1] {
#         display: block; } }
#     .header__navbar--navigation[_ngcontent-c1]   .button--navigation[_ngcontent-c1] {
#       padding: 0;
#       color: #525c65; }
#       .header__navbar--navigation[_ngcontent-c1]   .button--navigation[_ngcontent-c1]:hover {
#         color: #474f57; }
#     .header__navbar--navigation[_ngcontent-c1]   .button--primary[_ngcontent-c1], .header__navbar--navigation[_ngcontent-c1]   .button--turquoise[_ngcontent-c1] {
#       width: 7.75rem;
#       box-shadow: 8px 10px 20px 0px rgba(46, 61, 73, 0.15);
#       background-color: #02b3e4; }
#       .header__navbar--navigation[_ngcontent-c1]   .button--primary[_ngcontent-c1]:hover, .header__navbar--navigation[_ngcontent-c1]   .button--turquoise[_ngcontent-c1]:hover {
#         box-shadow: 2px 4px 8px 0px rgba(46, 61, 73, 0.2);
#         background-color: #02b7e9; }
#     .header__navbar--navigation[_ngcontent-c1]   .button--turquoise[_ngcontent-c1] {
#       background-color: #02ccba; }
#       .header__navbar--navigation[_ngcontent-c1]   .button--turquoise[_ngcontent-c1]:hover {
#         background-color: #02d1bf; }
#     .header__navbar--navigation[_ngcontent-c1]   .button--guest[_ngcontent-c1], .header__navbar--navigation[_ngcontent-c1]   .button--student[_ngcontent-c1] {
#       display: none; }
#   .header__navbar--navigation[_ngcontent-c1]   .divider[_ngcontent-c1] {
#     cursor: default; }
#     .header__navbar--navigation[_ngcontent-c1]   .divider[_ngcontent-c1]::before {
#       content: '';
#       border-left: 1px solid rgba(82, 92, 101, 0.4);
#       width: 0px;
#       height: 12px; }
#   .header__sidenav[_ngcontent-c1] {
#     background-color: #2e3d49; }
#     .header__sidenav--logo[_ngcontent-c1] {
#       height: 4.5rem;
#       display: block;
#       background-color: #1C262F; }
#       .header__sidenav--logo[_ngcontent-c1]::after {
#         clear: both;
#         content: "";
#         display: table; }
#       .header__sidenav--logo[_ngcontent-c1]   .logo-link[_ngcontent-c1] {
#         display: block;
#         width: 100%;
#         height: 100%; }
#         .header__sidenav--logo[_ngcontent-c1]   .logo-link[_ngcontent-c1]   .logo-wordmark[_ngcontent-c1] {
#           position: relative;
#           top: 50%;
#           -webkit-transform: translateY(-50%);
#           -moz-transform: translateY(-50%);
#           -ms-transform: translateY(-50%);
#           -o-transform: translateY(-50%);
#           transform: translateY(-50%);
#           padding-left: 1.5em;
#           width: 11.25rem;
#           height: 1.875rem; }
#         .header__sidenav--logo[_ngcontent-c1]   .logo-link[_ngcontent-c1]   #wordmark[_ngcontent-c1] {
#           fill: #fff; }
#     .header__sidenav--navigation[_ngcontent-c1] {
#       display: block; }
#       .header__sidenav--navigation[_ngcontent-c1]::after {
#         clear: both;
#         content: "";
#         display: table; }
#       .header__sidenav--navigation[_ngcontent-c1]   li[_ngcontent-c1] {
#         height: 4.5rem; }
#       .header__sidenav--navigation[_ngcontent-c1]   a[_ngcontent-c1] {
#         padding-top: 1.5rem;
#         padding-bottom: 1.5rem;
#         color: #fff;
#         display: block;
#         padding-left: 1.5em; }
#         @media screen and (min-width: 48rem) {
#           .header__sidenav--navigation[_ngcontent-c1]   a[_ngcontent-c1] {
#             padding-top: 1.5rem;
#             padding-bottom: 1.5rem; } }
#         .header__sidenav--navigation[_ngcontent-c1]   a[_ngcontent-c1]:hover {
#           color: #cccccc; }
#       .header__sidenav--navigation[_ngcontent-c1]   .guest[_ngcontent-c1], .header__sidenav--navigation[_ngcontent-c1]   .student[_ngcontent-c1] {
#         display: none; }
#         .header__sidenav--navigation[_ngcontent-c1]   .guest[_ngcontent-c1]   a[_ngcontent-c1], .header__sidenav--navigation[_ngcontent-c1]   .student[_ngcontent-c1]   a[_ngcontent-c1] {
#           color: #02b3e4; }
#           .header__sidenav--navigation[_ngcontent-c1]   .guest[_ngcontent-c1]   a[_ngcontent-c1]:hover, .header__sidenav--navigation[_ngcontent-c1]   .student[_ngcontent-c1]   a[_ngcontent-c1]:hover {
#             color: #01647f; }
#
# [_nghost-c1] {
#   background: #2e3d49;
#   position: fixed;
#   top: 0;
#   left: 0;
#   height: 100vh;
#   display: block;
#   overflow-y: auto;
#   z-index: -1000;
#   width: 16.25rem;
#   -webkit-overflow-scrolling: touch;
#   display: block; }
#   @media screen and (min-width: 30rem) {
#     [_nghost-c1] {
#       display: none; } }
#   [_nghost-c1]   .logo-link[_ngcontent-c1] {
#     height: 4.5rem;
#     display: block;
#     background-color: #1C262F; }
#     [_nghost-c1]   .logo-link[_ngcontent-c1]::after {
#       clear: both;
#       content: "";
#       display: table; }
#     [_nghost-c1]   .logo-link[_ngcontent-c1]   .logo-wordmark[_ngcontent-c1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       -moz-transform: translateY(-50%);
#       -ms-transform: translateY(-50%);
#       -o-transform: translateY(-50%);
#       transform: translateY(-50%);
#       padding-left: 1.5em;
#       width: 11.25rem;
#       height: 1.875rem; }
#     [_nghost-c1]   .logo-link[_ngcontent-c1]   #wordmark[_ngcontent-c1] {
#       fill: #fff; }
#   [_nghost-c1]   ul[_ngcontent-c1] {
#     list-style: none;
#     padding: 0; }</style><style ng-transition="my-app-id">html[_ngcontent-c2] {
#   box-sizing: border-box; }
#
# *[_ngcontent-c2], *[_ngcontent-c2]::after, *[_ngcontent-c2]::before {
#   box-sizing: inherit; }
#
# [_nghost-c2] {
#   position: absolute;
#   width: 100%;
#   top: 0;
#   left: 0;
#   min-height: 100vh;
#   z-index: 0;
#   transition: transform 0.3s ease;
#   background: #fff; }
#
# .menu--open[_nghost-c2], .menu--open   [_nghost-c2] {
#   transform: translateX(16.25rem);
#   height: 100vh;
#   overflow: hidden; }
#   @media screen and (min-width: 30rem) {
#     .menu--open[_nghost-c2], .menu--open   [_nghost-c2] {
#       overflow: auto;
#       transform: none;
#       height: auto; } }
#
# .sticky[_nghost-c2], .sticky   [_nghost-c2] {
#   padding-top: 4.5rem; }
#   @media screen and (min-width: 48rem) {
#     .sticky[_nghost-c2], .sticky   [_nghost-c2] {
#       padding-top: 6rem; } }
#
# .nd101-cn[_nghost-c2], .nd101-cn   [_nghost-c2], .nd101[_nghost-c2]:not(.page-in), .nd101:not(.page-in)   [_nghost-c2] {
#   background-color: #000;
#   background-repeat: no-repeat;
#   background-size: 100%;
#   background-attachment: scroll;
#   background-position: center top;
#   background-image: url("/assets/images/nanodegree-overview/shared/nd-hero-video/hero-bg-nd101.jpg"); }</style><style ng-transition="my-app-id">html[_ngcontent-c3] {
#   box-sizing: border-box; }
#
# *[_ngcontent-c3], *[_ngcontent-c3]::after, *[_ngcontent-c3]::before {
#   box-sizing: inherit; }
#
# .page-homepage[_nghost-c3]   .banner[_ngcontent-c3]   p[_ngcontent-c3], .page-homepage   [_nghost-c3]   .banner[_ngcontent-c3]   p[_ngcontent-c3], .page-homepage[_nghost-c3]   .banner[_ngcontent-c3]   a[_ngcontent-c3], .page-homepage   [_nghost-c3]   .banner[_ngcontent-c3]   a[_ngcontent-c3], .page-homepage[_nghost-c3]   .banner[_ngcontent-c3]   .close[_ngcontent-c3], .page-homepage   [_nghost-c3]   .banner[_ngcontent-c3]   .close[_ngcontent-c3] {
#   color: #02b3e4; }
#
# .page-homepage[_nghost-c3]   .banner.featured[_ngcontent-c3], .page-homepage   [_nghost-c3]   .banner.featured[_ngcontent-c3] {
#   background-color: #fff; }
#
# .page-homepage[_nghost-c3]   .banner[_ngcontent-c3]   #close-icon[_ngcontent-c3], .page-homepage   [_nghost-c3]   .banner[_ngcontent-c3]   #close-icon[_ngcontent-c3] {
#   fill: #02b3e4; }
#
# .banner[_ngcontent-c3] {
#   width: 100%;
#   color: #fff;
#   position: relative;
#   text-align: center;
#   padding: 0.75rem 1.5rem;
#   background-color: #7d97ad; }
#   .banner.featured[_ngcontent-c3] {
#     border-radius: 0;
#     background-color: #02b3e4; }
#   .banner[_ngcontent-c3]   p[_ngcontent-c3], .banner[_ngcontent-c3]   a[_ngcontent-c3] {
#     color: #fff;
#     display: inline-block;
#     margin: 0; }
#   .banner[_ngcontent-c3]   .close[_ngcontent-c3] {
#     position: absolute;
#     display: inline;
#     color: #fff;
#     right: 0;
#     top: 0;
#     height: 100%;
#     background-color: transparent;
#     border: none;
#     outline: none;
#     opacity: 0.75;
#     transition: opacity 0.3s ease; }
#     .banner[_ngcontent-c3]   .close[_ngcontent-c3]   svg[_ngcontent-c3] {
#       height: 13px;
#       width: auto;
#       top: 50%;
#       position: absolute;
#       right: 1rem;
#       transform: translateY(-50%); }
#     .banner[_ngcontent-c3]   .close[_ngcontent-c3]:hover {
#       opacity: 1; }</style><style ng-transition="my-app-id">html[_ngcontent-c3] {
#   box-sizing: border-box; }
#
# *[_ngcontent-c3], *[_ngcontent-c3]::after, *[_ngcontent-c3]::before {
#   box-sizing: inherit; }
#
# .invisible[_ngcontent-c3] {
#   visibility: hidden !important; }
#
# .hide[_ngcontent-c3] {
#   display: none !important; }
#
# .show[_ngcontent-c3] {
#   display: block !important; }
#
# .sr-only[_ngcontent-c3] {
#   height: 1px;
#   width: 1px;
#   overflow: hidden;
#   position: absolute !important;
#   clip: rect(1px, 1px, 1px, 1px); }
#
# .hidden-xs-up[_ngcontent-c3] {
#   display: none !important; }
#
# @media (max-width: 479px) {
#   .hidden-xs-down[_ngcontent-c3] {
#     display: none !important; } }
#
# @media (min-width: 480px) {
#   .hidden-sm-up[_ngcontent-c3] {
#     display: none !important; } }
#
# @media (max-width: 767px) {
#   .hidden-sm-down[_ngcontent-c3] {
#     display: none !important; } }
#
# @media (min-width: 768px) {
#   .hidden-md-up[_ngcontent-c3] {
#     display: none !important; } }
#
# @media (max-width: 991px) {
#   .hidden-md-down[_ngcontent-c3] {
#     display: none !important; } }
#
# @media (min-width: 992px) {
#   .hidden-lg-up[_ngcontent-c3] {
#     display: none !important; } }
#
# @media (max-width: 1179px) {
#   .hidden-lg-down[_ngcontent-c3] {
#     display: none !important; } }
#
# @media (min-width: 1180px) {
#   .hidden-xl-up[_ngcontent-c3] {
#     display: none !important; } }
#
# .hidden-xl-down[_ngcontent-c3] {
#   display: none !important; }
#
# .visible-print-block[_ngcontent-c3] {
#   display: none !important; }
#   @media print {
#     .visible-print-block[_ngcontent-c3] {
#       display: block !important; } }
#
# .visible-print-inline[_ngcontent-c3] {
#   display: none !important; }
#   @media print {
#     .visible-print-inline[_ngcontent-c3] {
#       display: inline !important; } }
#
# .visible-print-inline-block[_ngcontent-c3] {
#   display: none !important; }
#   @media print {
#     .visible-print-inline-block[_ngcontent-c3] {
#       display: inline-block !important; } }
#
# @media print {
#   .hidden-print[_ngcontent-c3] {
#     display: none !important; } }
#
# html[_ngcontent-c3] {
#   box-sizing: border-box; }
#
# *[_ngcontent-c3], *[_ngcontent-c3]::after, *[_ngcontent-c3]::before {
#   box-sizing: inherit; }
#
# ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3], input[type="color"][_ngcontent-c3], input[type="date"][_ngcontent-c3], input[type="datetime"][_ngcontent-c3], input[type="datetime-local"][_ngcontent-c3], input[type="email"][_ngcontent-c3], input[type="month"][_ngcontent-c3], input[type="number"][_ngcontent-c3], input[type="password"][_ngcontent-c3], input[type="search"][_ngcontent-c3], input[type="tel"][_ngcontent-c3], input[type="text"][_ngcontent-c3], input[type="time"][_ngcontent-c3], input[type="url"][_ngcontent-c3], input[type="week"][_ngcontent-c3], input[_ngcontent-c3]:not([type]), textarea[_ngcontent-c3], select[multiple][_ngcontent-c3] {
#   margin-top: 0;
#   margin-bottom: 0.75rem;
#   width: 100%;
#   outline: none;
#   color: #7d97ad;
#   vertical-align: top;
#   height: 3rem;
#   border: 1px solid #dbe2e8;
#   padding: 0 1.25rem;
#   box-sizing: border-box;
#   font-size: 0.875rem;
#   box-shadow: 5px 5px 10px 0 rgba(46, 61, 73, 0.05);
#   border-radius: 0.25rem;
#   transition: box-shadow 0.3s ease, border 0.3s ease; }
#   @media screen and (min-width: 48rem) {
#     ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3], input[type="color"][_ngcontent-c3], input[type="date"][_ngcontent-c3], input[type="datetime"][_ngcontent-c3], input[type="datetime-local"][_ngcontent-c3], input[type="email"][_ngcontent-c3], input[type="month"][_ngcontent-c3], input[type="number"][_ngcontent-c3], input[type="password"][_ngcontent-c3], input[type="search"][_ngcontent-c3], input[type="tel"][_ngcontent-c3], input[type="text"][_ngcontent-c3], input[type="time"][_ngcontent-c3], input[type="url"][_ngcontent-c3], input[type="week"][_ngcontent-c3], input[_ngcontent-c3]:not([type]), textarea[_ngcontent-c3], select[multiple][_ngcontent-c3] {
#       margin-bottom: 1.5rem; } }
#   ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]:hover, ir-modal[_ngcontent-c3]   .hover.newsletter-form[_ngcontent-c3], input[type="color"][_ngcontent-c3]:hover, input[type="color"].hover[_ngcontent-c3], input[type="date"][_ngcontent-c3]:hover, input[type="date"].hover[_ngcontent-c3], input[type="datetime"][_ngcontent-c3]:hover, input[type="datetime"].hover[_ngcontent-c3], input[type="datetime-local"][_ngcontent-c3]:hover, input[type="datetime-local"].hover[_ngcontent-c3], input[type="email"][_ngcontent-c3]:hover, input[type="email"].hover[_ngcontent-c3], input[type="month"][_ngcontent-c3]:hover, input[type="month"].hover[_ngcontent-c3], input[type="number"][_ngcontent-c3]:hover, input[type="number"].hover[_ngcontent-c3], input[type="password"][_ngcontent-c3]:hover, input[type="password"].hover[_ngcontent-c3], input[type="search"][_ngcontent-c3]:hover, input[type="search"].hover[_ngcontent-c3], input[type="tel"][_ngcontent-c3]:hover, input[type="tel"].hover[_ngcontent-c3], input[type="text"][_ngcontent-c3]:hover, input[type="text"].hover[_ngcontent-c3], input[type="time"][_ngcontent-c3]:hover, input[type="time"].hover[_ngcontent-c3], input[type="url"][_ngcontent-c3]:hover, input[type="url"].hover[_ngcontent-c3], input[type="week"][_ngcontent-c3]:hover, input[type="week"].hover[_ngcontent-c3], input[_ngcontent-c3]:not([type]):hover, input[_ngcontent-c3]:not([type]).hover, textarea[_ngcontent-c3]:hover, textarea.hover[_ngcontent-c3], select[multiple][_ngcontent-c3]:hover, select[multiple].hover[_ngcontent-c3] {
#     box-shadow: 0 4px 8px 0 rgba(46, 61, 73, 0.12); }
#   ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]:focus, ir-modal[_ngcontent-c3]   .focus.newsletter-form[_ngcontent-c3], input[type="color"][_ngcontent-c3]:focus, input[type="color"].focus[_ngcontent-c3], input[type="date"][_ngcontent-c3]:focus, input[type="date"].focus[_ngcontent-c3], input[type="datetime"][_ngcontent-c3]:focus, input[type="datetime"].focus[_ngcontent-c3], input[type="datetime-local"][_ngcontent-c3]:focus, input[type="datetime-local"].focus[_ngcontent-c3], input[type="email"][_ngcontent-c3]:focus, input[type="email"].focus[_ngcontent-c3], input[type="month"][_ngcontent-c3]:focus, input[type="month"].focus[_ngcontent-c3], input[type="number"][_ngcontent-c3]:focus, input[type="number"].focus[_ngcontent-c3], input[type="password"][_ngcontent-c3]:focus, input[type="password"].focus[_ngcontent-c3], input[type="search"][_ngcontent-c3]:focus, input[type="search"].focus[_ngcontent-c3], input[type="tel"][_ngcontent-c3]:focus, input[type="tel"].focus[_ngcontent-c3], input[type="text"][_ngcontent-c3]:focus, input[type="text"].focus[_ngcontent-c3], input[type="time"][_ngcontent-c3]:focus, input[type="time"].focus[_ngcontent-c3], input[type="url"][_ngcontent-c3]:focus, input[type="url"].focus[_ngcontent-c3], input[type="week"][_ngcontent-c3]:focus, input[type="week"].focus[_ngcontent-c3], input[_ngcontent-c3]:not([type]):focus, input[_ngcontent-c3]:not([type]).focus, textarea[_ngcontent-c3]:focus, textarea.focus[_ngcontent-c3], select[multiple][_ngcontent-c3]:focus, select[multiple].focus[_ngcontent-c3] {
#     border-color: #02b3e4;
#     box-shadow: 5px 5px 10px 0 rgba(46, 61, 73, 0.05); }
#   ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]:disabled, ir-modal[_ngcontent-c3]   .disabled.newsletter-form[_ngcontent-c3], input[type="color"][_ngcontent-c3]:disabled, input[type="color"].disabled[_ngcontent-c3], input[type="date"][_ngcontent-c3]:disabled, input[type="date"].disabled[_ngcontent-c3], input[type="datetime"][_ngcontent-c3]:disabled, input[type="datetime"].disabled[_ngcontent-c3], input[type="datetime-local"][_ngcontent-c3]:disabled, input[type="datetime-local"].disabled[_ngcontent-c3], input[type="email"][_ngcontent-c3]:disabled, input[type="email"].disabled[_ngcontent-c3], input[type="month"][_ngcontent-c3]:disabled, input[type="month"].disabled[_ngcontent-c3], input[type="number"][_ngcontent-c3]:disabled, input[type="number"].disabled[_ngcontent-c3], input[type="password"][_ngcontent-c3]:disabled, input[type="password"].disabled[_ngcontent-c3], input[type="search"][_ngcontent-c3]:disabled, input[type="search"].disabled[_ngcontent-c3], input[type="tel"][_ngcontent-c3]:disabled, input[type="tel"].disabled[_ngcontent-c3], input[type="text"][_ngcontent-c3]:disabled, input[type="text"].disabled[_ngcontent-c3], input[type="time"][_ngcontent-c3]:disabled, input[type="time"].disabled[_ngcontent-c3], input[type="url"][_ngcontent-c3]:disabled, input[type="url"].disabled[_ngcontent-c3], input[type="week"][_ngcontent-c3]:disabled, input[type="week"].disabled[_ngcontent-c3], input[_ngcontent-c3]:not([type]):disabled, input[_ngcontent-c3]:not([type]).disabled, textarea[_ngcontent-c3]:disabled, textarea.disabled[_ngcontent-c3], select[multiple][_ngcontent-c3]:disabled, select[multiple].disabled[_ngcontent-c3] {
#     opacity: 0.5;
#     cursor: not-allowed;
#     pointer-events: none; }
#     ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]:disabled:hover, ir-modal[_ngcontent-c3]   .disabled.newsletter-form[_ngcontent-c3]:hover, input[type="color"][_ngcontent-c3]:disabled:hover, input[type="color"].disabled[_ngcontent-c3]:hover, input[type="date"][_ngcontent-c3]:disabled:hover, input[type="date"].disabled[_ngcontent-c3]:hover, input[type="datetime"][_ngcontent-c3]:disabled:hover, input[type="datetime"].disabled[_ngcontent-c3]:hover, input[type="datetime-local"][_ngcontent-c3]:disabled:hover, input[type="datetime-local"].disabled[_ngcontent-c3]:hover, input[type="email"][_ngcontent-c3]:disabled:hover, input[type="email"].disabled[_ngcontent-c3]:hover, input[type="month"][_ngcontent-c3]:disabled:hover, input[type="month"].disabled[_ngcontent-c3]:hover, input[type="number"][_ngcontent-c3]:disabled:hover, input[type="number"].disabled[_ngcontent-c3]:hover, input[type="password"][_ngcontent-c3]:disabled:hover, input[type="password"].disabled[_ngcontent-c3]:hover, input[type="search"][_ngcontent-c3]:disabled:hover, input[type="search"].disabled[_ngcontent-c3]:hover, input[type="tel"][_ngcontent-c3]:disabled:hover, input[type="tel"].disabled[_ngcontent-c3]:hover, input[type="text"][_ngcontent-c3]:disabled:hover, input[type="text"].disabled[_ngcontent-c3]:hover, input[type="time"][_ngcontent-c3]:disabled:hover, input[type="time"].disabled[_ngcontent-c3]:hover, input[type="url"][_ngcontent-c3]:disabled:hover, input[type="url"].disabled[_ngcontent-c3]:hover, input[type="week"][_ngcontent-c3]:disabled:hover, input[type="week"].disabled[_ngcontent-c3]:hover, input[_ngcontent-c3]:not([type]):disabled:hover, input[_ngcontent-c3]:not([type]).disabled:hover, textarea[_ngcontent-c3]:disabled:hover, textarea.disabled[_ngcontent-c3]:hover, select[multiple][_ngcontent-c3]:disabled:hover, select[multiple].disabled[_ngcontent-c3]:hover {
#       box-shadow: 5px 5px 10px 0 rgba(46, 61, 73, 0.05); }
#   ir-modal[_ngcontent-c3]   .inline.newsletter-form[_ngcontent-c3], input[type="color"].inline[_ngcontent-c3], input[type="date"].inline[_ngcontent-c3], input[type="datetime"].inline[_ngcontent-c3], input[type="datetime-local"].inline[_ngcontent-c3], input[type="email"].inline[_ngcontent-c3], input[type="month"].inline[_ngcontent-c3], input[type="number"].inline[_ngcontent-c3], input[type="password"].inline[_ngcontent-c3], input[type="search"].inline[_ngcontent-c3], input[type="tel"].inline[_ngcontent-c3], input[type="text"].inline[_ngcontent-c3], input[type="time"].inline[_ngcontent-c3], input[type="url"].inline[_ngcontent-c3], input[type="week"].inline[_ngcontent-c3], input[_ngcontent-c3]:not([type]).inline, textarea.inline[_ngcontent-c3], select[multiple].inline[_ngcontent-c3] {
#     display: inline-block;
#     margin-right: 0.75rem; }
#     ir-modal[_ngcontent-c3]   .inline.newsletter-form[_ngcontent-c3]:last-child, input[type="color"].inline[_ngcontent-c3]:last-child, input[type="date"].inline[_ngcontent-c3]:last-child, input[type="datetime"].inline[_ngcontent-c3]:last-child, input[type="datetime-local"].inline[_ngcontent-c3]:last-child, input[type="email"].inline[_ngcontent-c3]:last-child, input[type="month"].inline[_ngcontent-c3]:last-child, input[type="number"].inline[_ngcontent-c3]:last-child, input[type="password"].inline[_ngcontent-c3]:last-child, input[type="search"].inline[_ngcontent-c3]:last-child, input[type="tel"].inline[_ngcontent-c3]:last-child, input[type="text"].inline[_ngcontent-c3]:last-child, input[type="time"].inline[_ngcontent-c3]:last-child, input[type="url"].inline[_ngcontent-c3]:last-child, input[type="week"].inline[_ngcontent-c3]:last-child, input[_ngcontent-c3]:not([type]).inline:last-child, textarea.inline[_ngcontent-c3]:last-child, select[multiple].inline[_ngcontent-c3]:last-child {
#       margin-right: 0; }
#     @media screen and (min-width: 48rem) {
#       ir-modal[_ngcontent-c3]   .inline.newsletter-form[_ngcontent-c3], input[type="color"].inline[_ngcontent-c3], input[type="date"].inline[_ngcontent-c3], input[type="datetime"].inline[_ngcontent-c3], input[type="datetime-local"].inline[_ngcontent-c3], input[type="email"].inline[_ngcontent-c3], input[type="month"].inline[_ngcontent-c3], input[type="number"].inline[_ngcontent-c3], input[type="password"].inline[_ngcontent-c3], input[type="search"].inline[_ngcontent-c3], input[type="tel"].inline[_ngcontent-c3], input[type="text"].inline[_ngcontent-c3], input[type="time"].inline[_ngcontent-c3], input[type="url"].inline[_ngcontent-c3], input[type="week"].inline[_ngcontent-c3], input[_ngcontent-c3]:not([type]).inline, textarea.inline[_ngcontent-c3], select[multiple].inline[_ngcontent-c3] {
#         margin-top: 0;
#         margin-bottom: 0; } }
#   @media screen and (min-width: 48rem) and (min-width: 48rem) {
#     ir-modal[_ngcontent-c3]   .inline.newsletter-form[_ngcontent-c3], input[type="color"].inline[_ngcontent-c3], input[type="date"].inline[_ngcontent-c3], input[type="datetime"].inline[_ngcontent-c3], input[type="datetime-local"].inline[_ngcontent-c3], input[type="email"].inline[_ngcontent-c3], input[type="month"].inline[_ngcontent-c3], input[type="number"].inline[_ngcontent-c3], input[type="password"].inline[_ngcontent-c3], input[type="search"].inline[_ngcontent-c3], input[type="tel"].inline[_ngcontent-c3], input[type="text"].inline[_ngcontent-c3], input[type="time"].inline[_ngcontent-c3], input[type="url"].inline[_ngcontent-c3], input[type="week"].inline[_ngcontent-c3], input[_ngcontent-c3]:not([type]).inline, textarea.inline[_ngcontent-c3], select[multiple].inline[_ngcontent-c3] {
#       margin-bottom: 0; } }
#
# fieldset[_ngcontent-c3] {
#   margin-top: 0;
#   margin-bottom: 0.75rem;
#   border: 0;
#   padding: 0;
#   background-color: transparent; }
#   @media screen and (min-width: 48rem) {
#     fieldset[_ngcontent-c3] {
#       margin-bottom: 1.5rem; } }
#
# legend[_ngcontent-c3] {
#   margin-top: 0;
#   margin-bottom: 0.75rem;
#   padding: 0; }
#   @media screen and (min-width: 48rem) {
#     legend[_ngcontent-c3] {
#       margin-bottom: 1.5rem; } }
#
# label[_ngcontent-c3] {
#   margin-top: 0;
#   margin-bottom: 0.75rem;
#   display: block; }
#   @media screen and (min-width: 48rem) {
#     label[_ngcontent-c3] {
#       margin-bottom: 1.5rem; } }
#
# textarea[_ngcontent-c3] {
#   padding: 0.6875rem 1.25rem; }
#
# input[type="number"][_ngcontent-c3] {
#   -moz-appearance: textfield; }
#
# input[_ngcontent-c3]::-webkit-outer-spin-button, input[_ngcontent-c3]::-webkit-inner-spin-button {
#   -webkit-appearance: none; }
#
# [type="search"][_ngcontent-c3] {
#   appearance: none; }
#
# [type="radio"][_ngcontent-c3] {
#   display: inline;
#   margin-right: 0.75rem; }
#
# [type="file"][_ngcontent-c3] {
#   margin-top: 0;
#   margin-bottom: 0.75rem;
#   width: 100%; }
#   @media screen and (min-width: 48rem) {
#     [type="file"][_ngcontent-c3] {
#       margin-bottom: 1.5rem; } }
#
# select[_ngcontent-c3] {
#   margin-top: 0;
#   margin-bottom: 0.75rem;
#   max-width: 100%;
#   width: auto; }
#   @media screen and (min-width: 48rem) {
#     select[_ngcontent-c3] {
#       margin-bottom: 1.5rem; } }
#
# .checkbox[_ngcontent-c3] {
#   position: relative; }
#   .checkbox[_ngcontent-c3]   input[type=checkbox][_ngcontent-c3] {
#     display: none !important; }
#     .checkbox[_ngcontent-c3]   input[type=checkbox][_ngcontent-c3]:checked    + label[_ngcontent-c3]::after {
#       background-size: 60%;
#       opacity: 1; }
#     .checkbox[_ngcontent-c3]   input[type=checkbox][_ngcontent-c3]:disabled    + label[_ngcontent-c3] {
#       opacity: .5; }
#   .checkbox[_ngcontent-c3]   label[_ngcontent-c3] {
#     font-size: 0.8125rem;
#     line-height: 1.5rem;
#     margin-top: 0;
#     margin-bottom: 0.75rem;
#     clear: left;
#     display: block;
#     position: relative;
#     color: #7d97ad;
#     letter-spacing: 0.0625rem;
#     text-transform: uppercase;
#     padding-left: 1.5rem; }
#     @media screen and (min-width: 48rem) {
#       .checkbox[_ngcontent-c3]   label[_ngcontent-c3] {
#         font-size: 0.8125rem;
#         line-height: 1.5rem; } }
#     @media screen and (min-width: 48rem) {
#       .checkbox[_ngcontent-c3]   label[_ngcontent-c3] {
#         margin-bottom: 0.75rem; } }
#     .checkbox[_ngcontent-c3]   label[_ngcontent-c3]   a[_ngcontent-c3] {
#       color: #7d97ad;
#       text-decoration: none;
#       border-bottom: 1px solid #91daee;
#       transition: color 0.3s ease; }
#       .checkbox[_ngcontent-c3]   label[_ngcontent-c3]   a[_ngcontent-c3]:hover {
#         color: #9db0c0; }
#     .checkbox[_ngcontent-c3]   label[_ngcontent-c3]::before, .checkbox[_ngcontent-c3]   label[_ngcontent-c3]::after {
#       content: '';
#       position: absolute;
#       top: 4px;
#       left: 0;
#       width: 16px;
#       height: 16px;
#       background: white;
#       border: 1px solid #dbe2e8;
#       box-shadow: 0 2px 5px 0 rgba(46, 61, 73, 0.08); }
#     .checkbox[_ngcontent-c3]   label[_ngcontent-c3]::after {
#       opacity: 0;
#       background-size: 20%;
#       background: image-url("svgs/check_blue.svg") no-repeat center;
#       transition: opacity 0.3s ease, background-size 0.3s ease; }
#
# input.form-error[_ngcontent-c3], select.form-error[_ngcontent-c3], textarea.form-error[_ngcontent-c3] {
#   color: #f95c3c;
#   background-color: rgba(249, 92, 60, 0.02);
#   border: 1px solid #f04546; }
#
# .error-container[_ngcontent-c3] {
#   height: 2.25rem;
#   position: absolute;
#   left: 0;
#   right: 0;
#   width: 90%;
#   margin: 0 auto;
#   display: block;
#   text-align: center;
#   top: -3rem;
#   background-color: #f04546;
#   border-radius: 0.25rem;
#   transition: all 0.3s ease;
#   opacity: 0; }
#   .error-container.filled[_ngcontent-c3] {
#     transition: all 0.3s ease;
#     opacity: 1; }
#   .error-container[_ngcontent-c3]:after {
#     content: '';
#     width: 0;
#     height: 0;
#     top: 18px;
#     position: relative;
#     border-style: solid;
#     border-width: 8px 6px 0;
#     border-color: #f04546 transparent transparent; }
#
# .error-text[_ngcontent-c3] {
#   font-size: 0.75rem;
#   line-height: 1.5rem;
#   position: relative;
#   top: 50%;
#   -webkit-transform: translateY(-50%);
#   -moz-transform: translateY(-50%);
#   -ms-transform: translateY(-50%);
#   -o-transform: translateY(-50%);
#   transform: translateY(-50%);
#   color: #fff;
#   display: block;
#   text-align: center; }
#   @media screen and (min-width: 48rem) {
#     .error-text[_ngcontent-c3] {
#       font-size: 0.75rem;
#       line-height: 1.5rem; } }
#
# button[_ngcontent-c3], input[type="button"][_ngcontent-c3], input[type="reset"][_ngcontent-c3], input[type="submit"][_ngcontent-c3], .button[_ngcontent-c3], .button--primary[_ngcontent-c3], .button--secondary[_ngcontent-c3], .button--outline[_ngcontent-c3], .button--white[_ngcontent-c3], .button--navigation[_ngcontent-c3], .button--turquoise[_ngcontent-c3], .button--team[_ngcontent-c3], ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]   #newsletter-signup-btn[_ngcontent-c3] {
#   display: block;
#   cursor: pointer;
#   appearance: none;
#   user-select: none;
#   text-align: center;
#   white-space: nowrap;
#   vertical-align: top;
#   text-decoration: none;
#   vertical-align: middle;
#   height: 3rem;
#   padding: 0 0.5rem;
#   text-transform: uppercase;
#   font-size: 16px;
#   font-weight: 600;
#   font-size: 0.8125rem;
#   line-height: 2.625rem;
#   -webkit-font-smoothing: antialiased;
#   border-radius: 0.25rem;
#   letter-spacing: 0.125rem;
#   transition: all 0.3s ease; }
#
# .button--primary[_ngcontent-c3], .button--secondary[_ngcontent-c3], .button--outline[_ngcontent-c3], .button--white[_ngcontent-c3], ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]   #newsletter-signup-btn[_ngcontent-c3] {
#   box-shadow: 8px 10px 20px 0px rgba(46, 61, 73, 0.15); }
#   .button--primary[_ngcontent-c3]:hover, .button--secondary[_ngcontent-c3]:hover, .button--outline[_ngcontent-c3]:hover, .button--white[_ngcontent-c3]:hover, ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]   #newsletter-signup-btn[_ngcontent-c3]:hover {
#     box-shadow: 2px 4px 8px 0px rgba(46, 61, 73, 0.2); }
#
# .button--primary[_ngcontent-c3] {
#   width: 13.75rem;
#   color: #fff;
#   background-color: #02b3e4;
#   border: 0.125rem solid transparent; }
#   .button--primary[_ngcontent-c3]:focus, .button--primary.focus[_ngcontent-c3], .button--primary[_ngcontent-c3]:hover {
#     outline: none;
#     color: white;
#     border-color: transparent;
#     background-color: #029fcb; }
#   .button--primary.disabled[_ngcontent-c3], .button--primary[disabled][_ngcontent-c3], fieldset[disabled][_ngcontent-c3]   .button--primary[_ngcontent-c3] {
#     box-shadow: none;
#     cursor: not-allowed;
#     border-color: #dbe2e8;
#     background-color: #dbe2e8; }
#   .button--primary.pending[_ngcontent-c3] {
#     cursor: progress;
#     box-shadow: none; }
#     .button--primary.pending[_ngcontent-c3]:hover {
#       background-color: #02b3e4; }
#   .button--primary.inline[_ngcontent-c3] {
#     display: inline-block; }
#   .button--primary.sm[_ngcontent-c3] {
#     width: 11.25rem; }
#   .button--primary.lg[_ngcontent-c3] {
#     width: 17.5rem; }
#     @media screen and (max-width: 20rem) {
#       .button--primary.lg[_ngcontent-c3] {
#         width: 100%; } }
#   .button--primary.full[_ngcontent-c3] {
#     width: 100%; }
#   .button--primary[_ngcontent-c3]    > svg[_ngcontent-c3] {
#     fill: currentcolor; }
#
# .button--secondary[_ngcontent-c3] {
#   width: 13.75rem;
#   color: #fff;
#   background-color: #7d97ad;
#   border: 0.125rem solid transparent; }
#   .button--secondary[_ngcontent-c3]:focus, .button--secondary.focus[_ngcontent-c3], .button--secondary[_ngcontent-c3]:hover {
#     outline: none;
#     color: white;
#     border-color: transparent;
#     background-color: #6d8aa3; }
#   .button--secondary.disabled[_ngcontent-c3], .button--secondary[disabled][_ngcontent-c3], fieldset[disabled][_ngcontent-c3]   .button--secondary[_ngcontent-c3] {
#     box-shadow: none;
#     cursor: not-allowed;
#     border-color: #dbe2e8;
#     background-color: #dbe2e8; }
#   .button--secondary.pending[_ngcontent-c3] {
#     cursor: progress;
#     box-shadow: none; }
#     .button--secondary.pending[_ngcontent-c3]:hover {
#       background-color: #7d97ad; }
#   .button--secondary.inline[_ngcontent-c3] {
#     display: inline-block; }
#   .button--secondary.sm[_ngcontent-c3] {
#     width: 11.25rem; }
#   .button--secondary.lg[_ngcontent-c3] {
#     width: 17.5rem; }
#     @media screen and (max-width: 20rem) {
#       .button--secondary.lg[_ngcontent-c3] {
#         width: 100%; } }
#   .button--secondary.full[_ngcontent-c3] {
#     width: 100%; }
#   .button--secondary[_ngcontent-c3]    > svg[_ngcontent-c3] {
#     fill: currentcolor; }
#
# .button--outline[_ngcontent-c3] {
#   width: 13.75rem;
#   color: #fff;
#   background-color: transparent;
#   border: 0.125rem solid #fff; }
#   .button--outline[_ngcontent-c3]:focus, .button--outline.focus[_ngcontent-c3], .button--outline[_ngcontent-c3]:hover {
#     outline: none;
#     color: white;
#     border-color: #fff;
#     background-color: transparent; }
#   .button--outline.disabled[_ngcontent-c3], .button--outline[disabled][_ngcontent-c3], fieldset[disabled][_ngcontent-c3]   .button--outline[_ngcontent-c3] {
#     box-shadow: none;
#     cursor: not-allowed;
#     border-color: #dbe2e8;
#     background-color: #dbe2e8; }
#   .button--outline.pending[_ngcontent-c3] {
#     cursor: progress;
#     box-shadow: none; }
#     .button--outline.pending[_ngcontent-c3]:hover {
#       background-color: transparent; }
#   .button--outline.inline[_ngcontent-c3] {
#     display: inline-block; }
#   .button--outline.sm[_ngcontent-c3] {
#     width: 11.25rem; }
#   .button--outline.lg[_ngcontent-c3] {
#     width: 17.5rem; }
#     @media screen and (max-width: 20rem) {
#       .button--outline.lg[_ngcontent-c3] {
#         width: 100%; } }
#   .button--outline.full[_ngcontent-c3] {
#     width: 100%; }
#   .button--outline[_ngcontent-c3]    > svg[_ngcontent-c3] {
#     fill: currentcolor; }
#
# .button--white[_ngcontent-c3] {
#   width: 13.75rem;
#   color: #02b3e4;
#   background-color: #fff;
#   border: 0.125rem solid transparent; }
#   .button--white[_ngcontent-c3]:focus, .button--white.focus[_ngcontent-c3], .button--white[_ngcontent-c3]:hover {
#     outline: none;
#     color: #1cccfd;
#     border-color: transparent;
#     background-color: #f2f2f2; }
#   .button--white.disabled[_ngcontent-c3], .button--white[disabled][_ngcontent-c3], fieldset[disabled][_ngcontent-c3]   .button--white[_ngcontent-c3] {
#     box-shadow: none;
#     cursor: not-allowed;
#     border-color: #dbe2e8;
#     background-color: #dbe2e8; }
#   .button--white.pending[_ngcontent-c3] {
#     cursor: progress;
#     box-shadow: none; }
#     .button--white.pending[_ngcontent-c3]:hover {
#       background-color: #fff; }
#   .button--white.inline[_ngcontent-c3] {
#     display: inline-block; }
#   .button--white.sm[_ngcontent-c3] {
#     width: 11.25rem; }
#   .button--white.lg[_ngcontent-c3] {
#     width: 17.5rem; }
#     @media screen and (max-width: 20rem) {
#       .button--white.lg[_ngcontent-c3] {
#         width: 100%; } }
#   .button--white.full[_ngcontent-c3] {
#     width: 100%; }
#   .button--white[_ngcontent-c3]    > svg[_ngcontent-c3] {
#     fill: currentcolor; }
#
# .button--navigation[_ngcontent-c3] {
#   color: #fff;
#   background-color: transparent;
#   border: 0.125rem solid transparent; }
#   .button--navigation[_ngcontent-c3]:focus, .button--navigation.focus[_ngcontent-c3], .button--navigation[_ngcontent-c3]:hover {
#     outline: none;
#     color: white;
#     border-color: transparent;
#     background-color: transparent; }
#   .button--navigation.disabled[_ngcontent-c3], .button--navigation[disabled][_ngcontent-c3], fieldset[disabled][_ngcontent-c3]   .button--navigation[_ngcontent-c3] {
#     box-shadow: none;
#     cursor: not-allowed;
#     border-color: #dbe2e8;
#     background-color: #dbe2e8; }
#   .button--navigation.pending[_ngcontent-c3] {
#     cursor: progress;
#     box-shadow: none; }
#     .button--navigation.pending[_ngcontent-c3]:hover {
#       background-color: transparent; }
#   .button--navigation.inline[_ngcontent-c3] {
#     display: inline-block; }
#   .button--navigation.sm[_ngcontent-c3] {
#     width: 11.25rem; }
#   .button--navigation.lg[_ngcontent-c3] {
#     width: 17.5rem; }
#     @media screen and (max-width: 20rem) {
#       .button--navigation.lg[_ngcontent-c3] {
#         width: 100%; } }
#   .button--navigation.full[_ngcontent-c3] {
#     width: 100%; }
#   .button--navigation[_ngcontent-c3]    > svg[_ngcontent-c3] {
#     fill: currentcolor; }
#
# .button--turquoise[_ngcontent-c3] {
#   color: #fff;
#   background-color: #02ccba;
#   border: 0.125rem solid transparent; }
#   .button--turquoise[_ngcontent-c3]:focus, .button--turquoise.focus[_ngcontent-c3], .button--turquoise[_ngcontent-c3]:hover {
#     outline: none;
#     color: white;
#     border-color: transparent;
#     background-color: #02b3a3; }
#   .button--turquoise.disabled[_ngcontent-c3], .button--turquoise[disabled][_ngcontent-c3], fieldset[disabled][_ngcontent-c3]   .button--turquoise[_ngcontent-c3] {
#     box-shadow: none;
#     cursor: not-allowed;
#     border-color: #dbe2e8;
#     background-color: #dbe2e8; }
#   .button--turquoise.pending[_ngcontent-c3] {
#     cursor: progress;
#     box-shadow: none; }
#     .button--turquoise.pending[_ngcontent-c3]:hover {
#       background-color: #02ccba; }
#   .button--turquoise.inline[_ngcontent-c3] {
#     display: inline-block; }
#   .button--turquoise.sm[_ngcontent-c3] {
#     width: 11.25rem; }
#   .button--turquoise.lg[_ngcontent-c3] {
#     width: 17.5rem; }
#     @media screen and (max-width: 20rem) {
#       .button--turquoise.lg[_ngcontent-c3] {
#         width: 100%; } }
#   .button--turquoise.full[_ngcontent-c3] {
#     width: 100%; }
#   .button--turquoise[_ngcontent-c3]    > svg[_ngcontent-c3] {
#     fill: currentcolor; }
#
# .button--team[_ngcontent-c3] {
#   color: #2e3d49;
#   background-color: transparent;
#   border: 0.125rem solid transparent; }
#   .button--team[_ngcontent-c3]:focus, .button--team.focus[_ngcontent-c3], .button--team[_ngcontent-c3]:hover {
#     outline: none;
#     color: #425768;
#     border-color: transparent;
#     background-color: transparent; }
#   .button--team.disabled[_ngcontent-c3], .button--team[disabled][_ngcontent-c3], fieldset[disabled][_ngcontent-c3]   .button--team[_ngcontent-c3] {
#     box-shadow: none;
#     cursor: not-allowed;
#     border-color: #dbe2e8;
#     background-color: #dbe2e8; }
#   .button--team.pending[_ngcontent-c3] {
#     cursor: progress;
#     box-shadow: none; }
#     .button--team.pending[_ngcontent-c3]:hover {
#       background-color: transparent; }
#   .button--team.inline[_ngcontent-c3] {
#     display: inline-block; }
#   .button--team.sm[_ngcontent-c3] {
#     width: 11.25rem; }
#   .button--team.lg[_ngcontent-c3] {
#     width: 17.5rem; }
#     @media screen and (max-width: 20rem) {
#       .button--team.lg[_ngcontent-c3] {
#         width: 100%; } }
#   .button--team.full[_ngcontent-c3] {
#     width: 100%; }
#   .button--team[_ngcontent-c3]    > svg[_ngcontent-c3] {
#     fill: currentcolor; }
#
# [_nghost-c3] {
#   display: block; }
#
# .hidden[_ngcontent-c3] {
#   display: none; }
#
# ir-modal[_ngcontent-c3]   header[_ngcontent-c3] {
#   text-align: center; }
#   ir-modal[_ngcontent-c3]   header[_ngcontent-c3]   img[_ngcontent-c3] {
#     margin-bottom: 1rem; }
#
# ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3] {
#   height: auto;
#   border: none;
#   box-shadow: none; }
#   ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]:hover {
#     box-shadow: none; }
#   ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]   fieldset[_ngcontent-c3] {
#     margin: 0; }
#     ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]   fieldset[_ngcontent-c3]::after {
#       clear: both;
#       content: "";
#       display: table; }
# ...
#                     <span _ngcontent-c114="" data-course-level-icon="" class="icon-level course-info-bar-icon icon-level-intermediate" className="icon-level course-info-bar-icon icon-level-intermediate"></span>
#                     <span _ngcontent-c114="" data-course-level-label="">intermediário</span>
#                   </span>
#                 </div>
#
#               </div>
#               <div _ngcontent-c114=""><span _ngcontent-c114="" innerHTML="The Time Series Forecasting course provides students with the foundational knowledge to build and apply time series forecasting models in a variety of business contexts.">The Time Series Forecasting course provides students with the foundational knowledge to build and apply time series forecasting models in a variety of business contexts.</span></div>
#               <!---->
#             </div>
#           </div><div _ngcontent-c114="" class="course-summary-card row row-gap-medium">
#             <div _ngcontent-c114="" class="col-sm-3">
#               <div _ngcontent-c114="" class="row">
#                 <div _ngcontent-c114="" class="col-xs-8 col-xs-offset-2 col-sm-12 col-sm-offset-0">
#                   <a _ngcontent-c114="" href="/course/segmentation-and-clustering--ud981">
#                     <img _ngcontent-c114="" class="img-responsive img-bordered center-block" height="170" width="290" src="https://d20vrrgs8k4bvw.cloudfront.net/images/course-catalog/pt-BR/segmentation-and-clustering--ud981.jpg" alt="Segmentation and Clustering">
#                   </a>
#                 </div>
#               </div>
#             </div>
#             <div _ngcontent-c114="" class="col-sm-9">
#               <div _ngcontent-c114="" class="row">
#                 <div _ngcontent-c114="" class="col-sm-8">
#                   <h3 _ngcontent-c114="" class="h-slim">
#                     <a _ngcontent-c114="" href="/course/segmentation-and-clustering--ud981"> Segmentation and Clustering</a>
#                     <span _ngcontent-c114="" class="badges">
#                       <!---->
#
#                     </span>
#                   </h3>
#                 </div>
#                 <div _ngcontent-c114="" class="col-sm-4 hidden-xs">
#                   <!----><span _ngcontent-c114="" class="caption text-right">
#                     <span _ngcontent-c114="" data-course-level-icon="" class="icon-level course-info-bar-icon icon-level-intermediate" className="icon-level course-info-bar-icon icon-level-intermediate"></span>
#                     <span _ngcontent-c114="" data-course-level-label="">intermediário</span>
#                   </span>
#                 </div>
#
#               </div>
#               <div _ngcontent-c114=""><span _ngcontent-c114="" innerHTML="The Segmentation &amp;amp; Clustering course provides students with the knowledge to build and apply clustering models to develop sophisticated segmentation in business contexts.">The Segmentation &amp; Clustering course provides students with the knowledge to build and apply clustering models to develop sophisticated segmentation in business contexts.</span></div>
#               <!---->
#             </div>
#           </div><div _ngcontent-c114="" class="course-summary-card row row-gap-medium">
#             <div _ngcontent-c114="" class="col-sm-3">
#               <div _ngcontent-c114="" class="row">
#                 <div _ngcontent-c114="" class="col-xs-8 col-xs-offset-2 col-sm-12 col-sm-offset-0">
#                   <a _ngcontent-c114="" href="/course/javascript-design-patterns--ud989">
#                     <img _ngcontent-c114="" class="img-responsive img-bordered center-block" height="170" width="290" src="https://d20vrrgs8k4bvw.cloudfront.net/images/course-catalog/pt-BR/javascript-design-patterns--ud989.jpg" alt="JavaScript Design Patterns">
#                   </a>
#                 </div>
#               </div>
#             </div>
#             <div _ngcontent-c114="" class="col-sm-9">
#               <div _ngcontent-c114="" class="row">
#                 <div _ngcontent-c114="" class="col-sm-8">
#                   <h3 _ngcontent-c114="" class="h-slim">
#                     <a _ngcontent-c114="" href="/course/javascript-design-patterns--ud989"> JavaScript Design Patterns</a>
#                     <span _ngcontent-c114="" class="badges">
#                       <!---->
#
#                     </span>
#                   </h3>
#                 </div>
#                 <div _ngcontent-c114="" class="col-sm-4 hidden-xs">
#                   <!----><span _ngcontent-c114="" class="caption text-right">
#                     <span _ngcontent-c114="" data-course-level-icon="" class="icon-level course-info-bar-icon icon-level-advanced" className="icon-level course-info-bar-icon icon-level-advanced"></span>
#                     <span _ngcontent-c114="" data-course-level-label="">avançado</span>
#                   </span>
#                 </div>
#
#               </div>
#               <div _ngcontent-c114=""><span _ngcontent-c114="" innerHTML="Saiba a import&amp;#226;ncia da organiza&amp;#231;&amp;#227;o de c&amp;#243;digo e como implement&amp;#225;-lo com qualquer JavaScript padr&amp;#227;o, biblioteca ou framework.">Saiba a importância da organização de código e como implementá-lo com qualquer JavaScript padrão, biblioteca ou framework.</span></div>
#               <!---->
#             </div>
#           </div>
#         </div>
#         <!----><!---->
#           <div _ngcontent-c114="" class="row row-gap-medium">
#             <div _ngcontent-c114="" class="col-sm-3"></div>
#             <div _ngcontent-c114="" class="col-sm-3"></div>
#             <ir-loading-spinner _ngcontent-c114="" class="col-sm-3" _nghost-c7=""><div _ngcontent-c7="" class="loading">
#   <strong _ngcontent-c7="">Please wait</strong><span _ngcontent-c7=""><i _ngcontent-c7="">Loading…</i></span>
# </div>
# </ir-loading-spinner>
#           </div>
#
#       </div>
#     </div>
#   </div>
# </section>
#
#
# </ir-course-catalog>
#
#   <ir-footer _ngcontent-c0="" _nghost-c5=""><footer _ngcontent-c5="" class="footer">
#   <div _ngcontent-c5="" class="contain contain--small">
#
#     <section _ngcontent-c5="" class="footer__logo">
#       <a _ngcontent-c5="" href="/" id="ga-71dc5f" title="Udacity">
#         <div _ngcontent-c5="" class="footer__logo__mark">
#           <svg _ngcontent-c5="" alt="Udacity" height="30" viewBox="0 0 30 30" width="30" xmlns="http://www.w3.org/2000/svg">
#             <path _ngcontent-c5="" d="M29 .5l1 .5v13c0 5.551887-2.8897 8.695692-5.995216 10.099885L24.0094 24.1l-7.620963 4.388562c-.05877.03456-.11776.068527-.176957.101902l-.08642.049764.001806-.00254C14.48289 29.545895 12.684682 30 11 30 6 30 0 26 0 18V6l2 1v11c0 8 6 10 9 10 1.858706 0 4.86901-.76773 6.89043-3.254517C14.181726 23.872636 10 20.678703 10 14V2.2L2 7 0 6l10-6 1 .5 1 .5v13c0 6.939958 4.515283 8.612086 7.017542 8.933368C19.625786 21.62159 20 19.997902 20 18V5l2 1v12c0 1.852645-.321777 3.49077-.878395 4.91438C23.648223 22.549217 28 20.813144 28 14V2.25L22 6l-2-1 8-5 1 .5z" fill="#02B3E4" fill-rule="evenodd" id="mark"></path>
#           </svg>
#         </div>
#       </a>
#     </section>
#
#     <nav _ngcontent-c5="" class="footer__primary" role="navigation">
#       <ul _ngcontent-c5="" class="footer__nav">
#
#         <!----><li _ngcontent-c5="" class="footer__nav__col">
#
#           <!---->
#             <ir-footer-nav _ngcontent-c5="" _nghost-c8=""><h6 _ngcontent-c8="">Programas Nanodegree em destaque</h6>
# <ul _ngcontent-c8="">
#   <!----><li _ngcontent-c8="" class="href text">
#     <a _ngcontent-c8="" href="/course/data-science-business--nd115">Data Science para Negócios</a>
#   </li><li _ngcontent-c8="" class="href text">
#     <a _ngcontent-c8="" href="/course/android-developer-nanodegree--nd801">Desenvolvedor Android</a>
#   </li><li _ngcontent-c8="" class="href text">
#     <a _ngcontent-c8="" href="/course/vr-developer-nanodegree--nd017">Desenvolvedor de Realidade Virtual</a>
#   </li><li _ngcontent-c8="" class="href text">
#     <a _ngcontent-c8="" href="/course/front-end-web-developer-nanodegree--nd001">Desenvolvedor Web Front-End</a>
#   </li><li _ngcontent-c8="" class="href text">
#     <a _ngcontent-c8="" href="/course/artificial-intelligence-nanodegree--nd889">Engenheiro de Inteligência Artificial</a>
#   </li><li _ngcontent-c8="" class="href text">
#     <a _ngcontent-c8="" href="/course/machine-learning-engineer-nanodegree--nd009">Engenheiro de Machine Learning</a>
#   </li><li _ngcontent-c8="" class="href text">
#     <a _ngcontent-c8="" href="/course/fundamentos-data-science-i-python--nd110">Fundamentos de Data Science I</a>
#   </li><li _ngcontent-c8="" class="href text">
#     <a _ngcontent-c8="" href="/course/fundamentos-data-science-ii--nd111/">Fundamentos de Data Science II</a>
#   </li><li _ngcontent-c8="" class="href text">
#     <a _ngcontent-c8="" href="/course/deep-learning-nanodegree-foundation--nd101">Fundamentos de Deep Learning</a>
#   </li>
# </ul>
# </ir-footer-nav>
#
#
#           <!---->
#
#         </li><li _ngcontent-c5="" class="footer__nav__col">
#
#           <!---->
#             <ir-footer-nav _ngcontent-c5="" _nghost-c8=""><h6 _ngcontent-c8="">Aprenda com a Udacity</h6>
# <ul _ngcontent-c8="">
#   <!----><li _ngcontent-c8="" class="href text">
#     <a _ngcontent-c8="" href="/course/intro-to-programming-nanodegree--nd000">Introdução à Programação</a>
#   </li><li _ngcontent-c8="" class="href text">
#     <a _ngcontent-c8="" href="/course/xcode-debugging--ud774">Xcode Debugging</a>
#   </li><li _ngcontent-c8="" class="href text">
#     <a _ngcontent-c8="" href="/course/javascript-basics--ud804">Aprenda JavaScript</a>
#   </li><li _ngcontent-c8="" class="href text">
#     <a _ngcontent-c8="" href="/course/how-to-make-an-ios-app--ud607">Como criar um aplicativo iOS</a>
#   </li><li _ngcontent-c8="" class="href text">
#     <a _ngcontent-c8="" href="/course/intro-to-html-and-css--ud304">Introdução ao HTML e CSS</a>
#   </li><li _ngcontent-c8="" class="href text">
#     <a _ngcontent-c8="" href="/course/vr-software-development--ud1014">Desenvolvimento de Software VR</a>
#   </li><li _ngcontent-c8="" class="href text">
#     <a _ngcontent-c8="" href="/course/object-oriented-javascript--ud015">JavaScript Orientado a Objetos</a>
#   </li><li _ngcontent-c8="" class="href text">
#     <a _ngcontent-c8="" href="/course/advanced-android-app-development--ud855">Desenvolvendo Apps Android</a>
#   </li><li _ngcontent-c8="" class="href text">
#     <a _ngcontent-c8="" href="/course/intro-to-data-analysis--ud170">Introdução à Análise de Dados</a>
#   </li>
# </ul>
# </ir-footer-nav>
#
#
#           <!---->
#
#         </li><li _ngcontent-c5="" class="footer__nav__col">
#
#           <!---->
#
#           <!---->
#
#               <!----><ir-footer-nav _ngcontent-c5="" _nghost-c8=""><h6 _ngcontent-c8="">Recursos para estudantes</h6>
# <ul _ngcontent-c8="">
#   <!----><li _ngcontent-c8="" class="href text">
#     <a _ngcontent-c8="" href="/courses/all">Catálogo</a>
#   </li><li _ngcontent-c8="" class="href text">
#     <a _ngcontent-c8="" href="/success">Histórias de Sucesso</a>
#   </li>
# </ul>
# </ir-footer-nav><ir-footer-nav _ngcontent-c5="" _nghost-c8=""><h6 _ngcontent-c8="">Empresas</h6>
# <ul _ngcontent-c8="">
#   <!----><li _ngcontent-c8="" class="href text">
#     <a _ngcontent-c8="" href="/business">Udacity para Empresas</a>
#   </li><li _ngcontent-c8="" class="href text">
#     <a _ngcontent-c8="" href="/hire-talent">Recrute graduados</a>
#   </li>
# </ul>
# </ir-footer-nav>
#
#
#
#         </li><li _ngcontent-c5="" class="footer__nav__col">
#
#           <!---->
#             <ir-footer-nav _ngcontent-c5="" _nghost-c8=""><h6 _ngcontent-c8="">Udacity</h6>
# <ul _ngcontent-c8="">
#   <!----><li _ngcontent-c8="" class="href text">
#     <a _ngcontent-c8="" href="/us">Sobre</a>
#   </li><li _ngcontent-c8="" class="href text">
#     <a _ngcontent-c8="" href="/press">Imprensa</a>
#   </li><li _ngcontent-c8="" class="href text">
#     <a _ngcontent-c8="" href="/events">Eventos</a>
#   </li><li _ngcontent-c8="" class="href text">
#     <a _ngcontent-c8="" href="/blog">Blog</a>
#   </li><li _ngcontent-c8="" class="href text">
#     <a _ngcontent-c8="" href="/jobs">Vagas</a>
#   </li><li _ngcontent-c8="" class="href text">
#     <a _ngcontent-c8="" href="http://www.udacity.com/georgia-tech">Georgia Tech (Inglês)</a>
#   </li><li _ngcontent-c8="" class="href text">
#     <a _ngcontent-c8="" href="https://play.google.com/store/apps/details?id=com.udacity.android">App Android</a>
#   </li><li _ngcontent-c8="" class="href text">
#     <a _ngcontent-c8="" href="https://itunes.apple.com/us/app/id819700933?mt=8">App iOs</a>
#   </li>
# </ul>
# </ir-footer-nav>
#
#
#           <!---->
#
#         </li><li _ngcontent-c5="" class="footer__nav__col">
#
#           <!---->
#             <ir-footer-nav _ngcontent-c5="" _nghost-c8=""><h6 _ngcontent-c8="">Consulta</h6>
# <ul _ngcontent-c8="">
#   <!----><li _ngcontent-c8="" class="href text">
#     <a _ngcontent-c8="" href="https://udacity-br.zendesk.com/hc/pt-br">Central de Ajuda</a>
#   </li><li _ngcontent-c8="" class="href text">
#     <a _ngcontent-c8="" href="https://udacity-br.zendesk.com/hc/pt-br/requests/new">Entre em contato</a>
#   </li><li _ngcontent-c8="" class="href text">
#     <a _ngcontent-c8="" href="http://status.udacity.com">Status do serviço</a>
#   </li><li _ngcontent-c8="" class="href text">
#     <a _ngcontent-c8="" href="/legal/privacy">Política de Privacidade</a>
#   </li><li _ngcontent-c8="" class="href text">
#     <a _ngcontent-c8="" href="/legal">Termos de Uso</a>
#   </li>
# </ul>
# </ir-footer-nav>
#
#
#           <!---->
#
#         </li>
#
#       </ul>
#     </nav>
#     <section _ngcontent-c5="" class="footer__secondary">
#       <div _ngcontent-c5="" class="footer__col">
#         <ul _ngcontent-c5="" class="fineprint">
#           <li _ngcontent-c5="">
#             <p _ngcontent-c5="" class="small mb-0">© 2011–2017 Udacity, Inc.</p>
#           </li>
#           <!---->
#           <!---->
#           <li _ngcontent-c5="" class="fineprint__link hidden-sm-down">
#             <a _ngcontent-c5="" href="/sitemap">Mapa do site</a>
#           </li>
#         </ul>
#          <!---->
#       </div>
#       <div _ngcontent-c5="" class="footer__col">
#
#         <!---->
#
#         <!----><ir-footer-social _ngcontent-c5="" _nghost-c11=""><!---->
#   <ul _ngcontent-c11="" class="social">
#     <!----><li _ngcontent-c11="">
#       <!---->
#         <a _ngcontent-c11="" rel="nofollow noopener noreferrer" target="_blank" id="ga-facebook" href="https://www.facebook.com/UdacityBrasil" title="Facebook">
#           <div _ngcontent-c11="" class="social__icon"></div>
#         </a>
#
#       <!---->
#     </li><li _ngcontent-c11="">
#       <!---->
#         <a _ngcontent-c11="" rel="nofollow noopener noreferrer" target="_blank" id="ga-twitter" href="https://twitter.com/UdacityBrasil" title="Twitter">
#           <div _ngcontent-c11="" class="social__icon"></div>
#         </a>
#
#       <!---->
#     </li><li _ngcontent-c11="">
#       <!---->
#         <a _ngcontent-c11="" rel="nofollow noopener noreferrer" target="_blank" id="ga-linkedin" href="https://www.linkedin.com/school/15199267/" title="LinkedIn">
#           <div _ngcontent-c11="" class="social__icon"></div>
#         </a>
#
#       <!---->
#     </li>
#   </ul>
#
#
# <!---->
# </ir-footer-social>
#
#       </div>
#     </section>
#     <section _ngcontent-c5="" class="text-center">
#       <p _ngcontent-c5="" class="micro mb-half">Nanodegree é marca registrada da Udacity © 2011–2017 Udacity, Inc.</p>
#       <p _ngcontent-c5="" class="micro legible center mb-0">A Udacity é uma empresa de tecnologia em educação que oferece cursos online em seu website, não se tratando de uma universidade no sentido tradicional da palavra.</p>
#     </section>
#   </div>
# </footer>
# </ir-footer>
#
#
# </ir-content>
# </ir-root><script type="text/javascript" src="inline.cee4f10f62a14a0c9523.bundle.js"></script><script type="text/javascript" src="polyfills.6f2e575c74c53d0e3198.bundle.js"></script><script type="text/javascript" src="scripts.b5fa9465d6307eb9e4c1.bundle.js"></script><script type="text/javascript" src="main.77decaec979cd0a47057.bundle.js"></script></body></html>

# %%
import re

# Remove HTML tags using RegEx
pattern = re.compile(r'<.*?>')  # tags look like <...>
print(pattern.sub('', r.text))  # replace them with blank
# Out:
# Udacity | Udacityhtml[_ngcontent-c0] {
#   box-sizing: border-box; }
#
# *[_ngcontent-c0], *[_ngcontent-c0]::after, *[_ngcontent-c0]::before {
#   box-sizing: inherit; }
#
# a[_ngcontent-c0] {
#   color: darkviolet; }
#
# body[_ngcontent-c0] {
#   color: #028bb1; }
#
# [_nghost-c0] {
#   display: block;
#   position: relative; }html[_ngcontent-c1] {
#   box-sizing: border-box; }
#
# *[_ngcontent-c1], *[_ngcontent-c1]::after, *[_ngcontent-c1]::before {
#   box-sizing: inherit; }
#
# .invisible[_ngcontent-c1] {
#   visibility: hidden !important; }
#
# .hide[_ngcontent-c1] {
#   display: none !important; }
#
# .show[_ngcontent-c1] {
#   display: block !important; }
#
# .sr-only[_ngcontent-c1] {
#   height: 1px;
#   width: 1px;
#   overflow: hidden;
#   position: absolute !important;
#   clip: rect(1px, 1px, 1px, 1px); }
#
# .hidden-xs-up[_ngcontent-c1] {
#   display: none !important; }
#
# @media (max-width: 479px) {
#   .hidden-xs-down[_ngcontent-c1] {
#     display: none !important; } }
#
# @media (min-width: 480px) {
#   .hidden-sm-up[_ngcontent-c1] {
#     display: none !important; } }
#
# @media (max-width: 767px) {
#   .hidden-sm-down[_ngcontent-c1] {
#     display: none !important; } }
#
# @media (min-width: 768px) {
#   .hidden-md-up[_ngcontent-c1] {
#     display: none !important; } }
#
# @media (max-width: 991px) {
#   .hidden-md-down[_ngcontent-c1] {
#     display: none !important; } }
#
# @media (min-width: 992px) {
#   .hidden-lg-up[_ngcontent-c1] {
#     display: none !important; } }
#
# @media (max-width: 1179px) {
#   .hidden-lg-down[_ngcontent-c1] {
#     display: none !important; } }
#
# @media (min-width: 1180px) {
#   .hidden-xl-up[_ngcontent-c1] {
#     display: none !important; } }
#
# .hidden-xl-down[_ngcontent-c1] {
#   display: none !important; }
#
# .visible-print-block[_ngcontent-c1] {
#   display: none !important; }
#   @media print {
#     .visible-print-block[_ngcontent-c1] {
#       display: block !important; } }
#
# .visible-print-inline[_ngcontent-c1] {
#   display: none !important; }
#   @media print {
#     .visible-print-inline[_ngcontent-c1] {
#       display: inline !important; } }
#
# .visible-print-inline-block[_ngcontent-c1] {
#   display: none !important; }
#   @media print {
#     .visible-print-inline-block[_ngcontent-c1] {
#       display: inline-block !important; } }
#
# @media print {
#   .hidden-print[_ngcontent-c1] {
#     display: none !important; } }
#
# #contain-all[_ngcontent-c1] {
#   width: 100%;
#   overflow: hidden;
#   background: #fff;
#   backface-visibility: hidden;
#   -webkit-transform-style: preserve-3d; }
#
# .outer_contain[_ngcontent-c1] {
#   margin: 0 auto;
#   max-width: 90rem; }
#
# .contain[_ngcontent-c1] {
#   max-width: 73.75rem;
#   margin-left: auto;
#   margin-right: auto;
#   padding-top: 3rem;
#   padding-bottom: 3rem;
#   padding-left: 1.5rem;
#   padding-right: 1.5rem; }
#   .contain[_ngcontent-c1]::after {
#     clear: both;
#     content: "";
#     display: table; }
#   @media screen and (min-width: 48rem) {
#     .contain[_ngcontent-c1] {
#       padding-top: 6rem;
#       padding-bottom: 6rem; } }
#   @media screen and (min-width: 73.75rem) {
#     .contain[_ngcontent-c1] {
#       padding-left: 0;
#       padding-right: 0; } }
#   .contain.no-padding[_ngcontent-c1] {
#     padding: 0; }
#   .contain.no-padding-top[_ngcontent-c1] {
#     padding-top: 0; }
#   .contain.no-padding-bottom[_ngcontent-c1] {
#     padding-bottom: 0; }
#   .contain--none[_ngcontent-c1] {
#     padding-top: 0rem;
#     padding-bottom: 0rem;
#     margin: 0 auto; }
#     @media screen and (min-width: 48rem) {
#       .contain--none[_ngcontent-c1] {
#         padding-top: 0rem;
#         padding-bottom: 0rem; } }
#   .contain--small[_ngcontent-c1] {
#     padding-top: 3rem;
#     padding-bottom: 3rem;
#     margin: 0 auto; }
#     @media screen and (min-width: 48rem) {
#       .contain--small[_ngcontent-c1] {
#         padding-top: 4.5rem;
#         padding-bottom: 4.5rem; } }
#
# .cards_contain[_ngcontent-c1] {
#   max-width: 73.75rem;
#   margin-left: auto;
#   margin-right: auto; }
#   .cards_contain[_ngcontent-c1]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# [_ngcontent-c1]:target:before {
#   content: '';
#   display: inline-block;
#   height: 130px;
#   margin: -130px 0 0; }
#
# .header[_ngcontent-c1] {
#   max-width: 100%;
#   margin-left: auto;
#   margin-right: auto; }
#   .header[_ngcontent-c1]::after {
#     clear: both;
#     content: "";
#     display: table; }
#   .header.header--clone[_ngcontent-c1] {
#     width: 100%;
#     top: -1000px; }
#     .header.header--clone[_ngcontent-c1]   .header__navbar[_ngcontent-c1] {
#       height: 4.5rem; }
#   .header.header--stick[_ngcontent-c1] {
#     top: 0;
#     background-color: #fff;
#     z-index: 8000;
#     box-shadow: 0px 1px 2px rgba(0, 0, 0, 0.1); }
#   .header__navbar[_ngcontent-c1] {
#     max-width: 73.75rem;
#     margin-left: auto;
#     margin-right: auto;
#     height: 4.5rem;
#     padding: 0 1.5em; }
#     .header__navbar[_ngcontent-c1]::after {
#       clear: both;
#       content: "";
#       display: table; }
#     @media screen and (min-width: 48rem) {
#       .header__navbar[_ngcontent-c1] {
#         height: 6rem; } }
#     @media screen and (min-width: 73.75rem) {
#       .header__navbar[_ngcontent-c1] {
#         padding: 0; } }
#     .header__navbar--toggle[_ngcontent-c1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       -moz-transform: translateY(-50%);
#       -ms-transform: translateY(-50%);
#       -o-transform: translateY(-50%);
#       transform: translateY(-50%);
#       float: left;
#       display: block;
#       margin-right: 1.69492%;
#       width: 15.25424%; }
#       .header__navbar--toggle[_ngcontent-c1]:last-child {
#         margin-right: 0; }
#       @media screen and (min-width: 30rem) {
#         .header__navbar--toggle[_ngcontent-c1] {
#           display: none; } }
#     .header__navbar--logo[_ngcontent-c1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       -moz-transform: translateY(-50%);
#       -ms-transform: translateY(-50%);
#       -o-transform: translateY(-50%);
#       transform: translateY(-50%);
#       float: left;
#       display: block;
#       margin-right: 1.69492%;
#       width: 66.10169%; }
#       .header__navbar--logo[_ngcontent-c1]:last-child {
#         margin-right: 0; }
#       @media screen and (min-width: 30rem) {
#         .header__navbar--logo[_ngcontent-c1] {
#           float: left;
#           display: block;
#           margin-right: 1.69492%;
#           width: 23.72881%; }
#           .header__navbar--logo[_ngcontent-c1]:last-child {
#             margin-right: 0; } }
#     .header__navbar--navigation[_ngcontent-c1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       -moz-transform: translateY(-50%);
#       -ms-transform: translateY(-50%);
#       -o-transform: translateY(-50%);
#       transform: translateY(-50%);
#       display: none; }
#       @media screen and (min-width: 30rem) {
#         .header__navbar--navigation[_ngcontent-c1] {
#           float: left;
#           display: block;
#           margin-right: 1.69492%;
#           width: 74.57627%; }
#           .header__navbar--navigation[_ngcontent-c1]:last-child {
#             margin-right: 0; } }
#   .header__navbar--logo[_ngcontent-c1] {
#     text-align: center; }
#     @media screen and (min-width: 30rem) {
#       .header__navbar--logo[_ngcontent-c1] {
#         text-align: left; } }
#     .header__navbar--logo[_ngcontent-c1]   .logo-wordmark[_ngcontent-c1] {
#       width: 11.25rem;
#       height: 1.875rem;
#       display: none; }
#       @media screen and (min-width: 30rem) {
#         .header__navbar--logo[_ngcontent-c1]   .logo-wordmark[_ngcontent-c1] {
#           display: block; } }
#     .header__navbar--logo[_ngcontent-c1]   .logo-mark[_ngcontent-c1] {
#       display: block;
#       margin: 0 auto;
#       width: 1.875rem;
#       height: 1.875rem; }
#       @media screen and (min-width: 30rem) {
#         .header__navbar--logo[_ngcontent-c1]   .logo-mark[_ngcontent-c1] {
#           display: none; } }
#   .header__navbar--toggle[_ngcontent-c1]   .nav-toggle[_ngcontent-c1] {
#     display: block;
#     width: 1.25rem;
#     height: 1.25rem;
#     cursor: pointer;
#     transition: transform .25s ease; }
#     .header__navbar--toggle[_ngcontent-c1]   .nav-toggle[_ngcontent-c1]   .bar[_ngcontent-c1] {
#       display: block;
#       width: 100%;
#       height: 0.1875rem;
#       margin-left: -0.5rem;
#       margin-top: 0.1875rem;
#       background: #02b3e4;
#       transition: opacity .25s ease, transform .25s ease;
#       user-select: none; }
#   .header__navbar--navigation[_ngcontent-c1]   nav[_ngcontent-c1] {
#     float: right; }
#   .header__navbar--navigation[_ngcontent-c1]   a[_ngcontent-c1], .header__navbar--navigation[_ngcontent-c1]   div[_ngcontent-c1] {
#     float: left; }
#   .header__navbar--navigation[_ngcontent-c1]   .button[_ngcontent-c1] {
#     display: none;
#     letter-spacing: 0;
#     font-size: 0.875rem;
#     text-transform: capitalize;
#     height: 2.25rem;
#     font-weight: 400;
#     margin-left: 2.5rem;
#     line-height: 1.9375rem; }
#     .header__navbar--navigation[_ngcontent-c1]   .button[_ngcontent-c1]:first-child {
#       margin-left: 0; }
#     @media screen and (min-width: 62rem) {
#       .header__navbar--navigation[_ngcontent-c1]   .button[_ngcontent-c1] {
#         display: block; } }
#     .header__navbar--navigation[_ngcontent-c1]   .button--navigation[_ngcontent-c1] {
#       padding: 0;
#       color: #525c65; }
#       .header__navbar--navigation[_ngcontent-c1]   .button--navigation[_ngcontent-c1]:hover {
#         color: #474f57; }
#     .header__navbar--navigation[_ngcontent-c1]   .button--primary[_ngcontent-c1], .header__navbar--navigation[_ngcontent-c1]   .button--turquoise[_ngcontent-c1] {
#       width: 7.75rem;
#       box-shadow: 8px 10px 20px 0px rgba(46, 61, 73, 0.15);
#       background-color: #02b3e4; }
#       .header__navbar--navigation[_ngcontent-c1]   .button--primary[_ngcontent-c1]:hover, .header__navbar--navigation[_ngcontent-c1]   .button--turquoise[_ngcontent-c1]:hover {
#         box-shadow: 2px 4px 8px 0px rgba(46, 61, 73, 0.2);
#         background-color: #02b7e9; }
#     .header__navbar--navigation[_ngcontent-c1]   .button--turquoise[_ngcontent-c1] {
#       background-color: #02ccba; }
#       .header__navbar--navigation[_ngcontent-c1]   .button--turquoise[_ngcontent-c1]:hover {
#         background-color: #02d1bf; }
#     .header__navbar--navigation[_ngcontent-c1]   .button--guest[_ngcontent-c1], .header__navbar--navigation[_ngcontent-c1]   .button--student[_ngcontent-c1] {
#       display: none; }
#   .header__navbar--navigation[_ngcontent-c1]   .divider[_ngcontent-c1] {
#     cursor: default; }
#     .header__navbar--navigation[_ngcontent-c1]   .divider[_ngcontent-c1]::before {
#       content: '';
#       border-left: 1px solid rgba(82, 92, 101, 0.4);
#       width: 0px;
#       height: 12px; }
#   .header__sidenav[_ngcontent-c1] {
#     background-color: #2e3d49; }
#     .header__sidenav--logo[_ngcontent-c1] {
#       height: 4.5rem;
#       display: block;
#       background-color: #1C262F; }
#       .header__sidenav--logo[_ngcontent-c1]::after {
#         clear: both;
#         content: "";
#         display: table; }
#       .header__sidenav--logo[_ngcontent-c1]   .logo-link[_ngcontent-c1] {
#         display: block;
#         width: 100%;
#         height: 100%; }
#         .header__sidenav--logo[_ngcontent-c1]   .logo-link[_ngcontent-c1]   .logo-wordmark[_ngcontent-c1] {
#           position: relative;
#           top: 50%;
#           -webkit-transform: translateY(-50%);
#           -moz-transform: translateY(-50%);
#           -ms-transform: translateY(-50%);
#           -o-transform: translateY(-50%);
#           transform: translateY(-50%);
#           padding-left: 1.5em;
#           width: 11.25rem;
#           height: 1.875rem; }
#         .header__sidenav--logo[_ngcontent-c1]   .logo-link[_ngcontent-c1]   #wordmark[_ngcontent-c1] {
#           fill: #fff; }
#     .header__sidenav--navigation[_ngcontent-c1] {
#       display: block; }
#       .header__sidenav--navigation[_ngcontent-c1]::after {
#         clear: both;
#         content: "";
#         display: table; }
#       .header__sidenav--navigation[_ngcontent-c1]   li[_ngcontent-c1] {
#         height: 4.5rem; }
#       .header__sidenav--navigation[_ngcontent-c1]   a[_ngcontent-c1] {
#         padding-top: 1.5rem;
#         padding-bottom: 1.5rem;
#         color: #fff;
#         display: block;
#         padding-left: 1.5em; }
#         @media screen and (min-width: 48rem) {
#           .header__sidenav--navigation[_ngcontent-c1]   a[_ngcontent-c1] {
#             padding-top: 1.5rem;
#             padding-bottom: 1.5rem; } }
#         .header__sidenav--navigation[_ngcontent-c1]   a[_ngcontent-c1]:hover {
#           color: #cccccc; }
#       .header__sidenav--navigation[_ngcontent-c1]   .guest[_ngcontent-c1], .header__sidenav--navigation[_ngcontent-c1]   .student[_ngcontent-c1] {
#         display: none; }
#         .header__sidenav--navigation[_ngcontent-c1]   .guest[_ngcontent-c1]   a[_ngcontent-c1], .header__sidenav--navigation[_ngcontent-c1]   .student[_ngcontent-c1]   a[_ngcontent-c1] {
#           color: #02b3e4; }
#           .header__sidenav--navigation[_ngcontent-c1]   .guest[_ngcontent-c1]   a[_ngcontent-c1]:hover, .header__sidenav--navigation[_ngcontent-c1]   .student[_ngcontent-c1]   a[_ngcontent-c1]:hover {
#             color: #01647f; }
#
# [_nghost-c1] {
#   background: #2e3d49;
#   position: fixed;
#   top: 0;
#   left: 0;
#   height: 100vh;
#   display: block;
#   overflow-y: auto;
#   z-index: -1000;
#   width: 16.25rem;
#   -webkit-overflow-scrolling: touch;
#   display: block; }
#   @media screen and (min-width: 30rem) {
#     [_nghost-c1] {
#       display: none; } }
#   [_nghost-c1]   .logo-link[_ngcontent-c1] {
#     height: 4.5rem;
#     display: block;
#     background-color: #1C262F; }
#     [_nghost-c1]   .logo-link[_ngcontent-c1]::after {
#       clear: both;
#       content: "";
#       display: table; }
#     [_nghost-c1]   .logo-link[_ngcontent-c1]   .logo-wordmark[_ngcontent-c1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       -moz-transform: translateY(-50%);
#       -ms-transform: translateY(-50%);
#       -o-transform: translateY(-50%);
#       transform: translateY(-50%);
#       padding-left: 1.5em;
#       width: 11.25rem;
#       height: 1.875rem; }
#     [_nghost-c1]   .logo-link[_ngcontent-c1]   #wordmark[_ngcontent-c1] {
#       fill: #fff; }
#   [_nghost-c1]   ul[_ngcontent-c1] {
#     list-style: none;
#     padding: 0; }html[_ngcontent-c2] {
#   box-sizing: border-box; }
#
# *[_ngcontent-c2], *[_ngcontent-c2]::after, *[_ngcontent-c2]::before {
#   box-sizing: inherit; }
#
# [_nghost-c2] {
#   position: absolute;
#   width: 100%;
#   top: 0;
#   left: 0;
#   min-height: 100vh;
#   z-index: 0;
#   transition: transform 0.3s ease;
#   background: #fff; }
#
# .menu--open[_nghost-c2], .menu--open   [_nghost-c2] {
#   transform: translateX(16.25rem);
#   height: 100vh;
#   overflow: hidden; }
#   @media screen and (min-width: 30rem) {
#     .menu--open[_nghost-c2], .menu--open   [_nghost-c2] {
#       overflow: auto;
#       transform: none;
#       height: auto; } }
#
# .sticky[_nghost-c2], .sticky   [_nghost-c2] {
#   padding-top: 4.5rem; }
#   @media screen and (min-width: 48rem) {
#     .sticky[_nghost-c2], .sticky   [_nghost-c2] {
#       padding-top: 6rem; } }
#
# .nd101-cn[_nghost-c2], .nd101-cn   [_nghost-c2], .nd101[_nghost-c2]:not(.page-in), .nd101:not(.page-in)   [_nghost-c2] {
#   background-color: #000;
#   background-repeat: no-repeat;
#   background-size: 100%;
#   background-attachment: scroll;
#   background-position: center top;
#   background-image: url("/assets/images/nanodegree-overview/shared/nd-hero-video/hero-bg-nd101.jpg"); }html[_ngcontent-c3] {
#   box-sizing: border-box; }
#
# *[_ngcontent-c3], *[_ngcontent-c3]::after, *[_ngcontent-c3]::before {
#   box-sizing: inherit; }
#
# .page-homepage[_nghost-c3]   .banner[_ngcontent-c3]   p[_ngcontent-c3], .page-homepage   [_nghost-c3]   .banner[_ngcontent-c3]   p[_ngcontent-c3], .page-homepage[_nghost-c3]   .banner[_ngcontent-c3]   a[_ngcontent-c3], .page-homepage   [_nghost-c3]   .banner[_ngcontent-c3]   a[_ngcontent-c3], .page-homepage[_nghost-c3]   .banner[_ngcontent-c3]   .close[_ngcontent-c3], .page-homepage   [_nghost-c3]   .banner[_ngcontent-c3]   .close[_ngcontent-c3] {
#   color: #02b3e4; }
#
# .page-homepage[_nghost-c3]   .banner.featured[_ngcontent-c3], .page-homepage   [_nghost-c3]   .banner.featured[_ngcontent-c3] {
#   background-color: #fff; }
#
# .page-homepage[_nghost-c3]   .banner[_ngcontent-c3]   #close-icon[_ngcontent-c3], .page-homepage   [_nghost-c3]   .banner[_ngcontent-c3]   #close-icon[_ngcontent-c3] {
#   fill: #02b3e4; }
#
# .banner[_ngcontent-c3] {
#   width: 100%;
#   color: #fff;
#   position: relative;
#   text-align: center;
#   padding: 0.75rem 1.5rem;
#   background-color: #7d97ad; }
#   .banner.featured[_ngcontent-c3] {
#     border-radius: 0;
#     background-color: #02b3e4; }
#   .banner[_ngcontent-c3]   p[_ngcontent-c3], .banner[_ngcontent-c3]   a[_ngcontent-c3] {
#     color: #fff;
#     display: inline-block;
#     margin: 0; }
#   .banner[_ngcontent-c3]   .close[_ngcontent-c3] {
#     position: absolute;
#     display: inline;
#     color: #fff;
#     right: 0;
#     top: 0;
#     height: 100%;
#     background-color: transparent;
#     border: none;
#     outline: none;
#     opacity: 0.75;
#     transition: opacity 0.3s ease; }
#     .banner[_ngcontent-c3]   .close[_ngcontent-c3]   svg[_ngcontent-c3] {
#       height: 13px;
#       width: auto;
#       top: 50%;
#       position: absolute;
#       right: 1rem;
#       transform: translateY(-50%); }
#     .banner[_ngcontent-c3]   .close[_ngcontent-c3]:hover {
#       opacity: 1; }html[_ngcontent-c3] {
#   box-sizing: border-box; }
#
# *[_ngcontent-c3], *[_ngcontent-c3]::after, *[_ngcontent-c3]::before {
#   box-sizing: inherit; }
#
# .invisible[_ngcontent-c3] {
#   visibility: hidden !important; }
#
# .hide[_ngcontent-c3] {
#   display: none !important; }
#
# .show[_ngcontent-c3] {
#   display: block !important; }
#
# .sr-only[_ngcontent-c3] {
#   height: 1px;
#   width: 1px;
#   overflow: hidden;
#   position: absolute !important;
#   clip: rect(1px, 1px, 1px, 1px); }
#
# .hidden-xs-up[_ngcontent-c3] {
#   display: none !important; }
#
# @media (max-width: 479px) {
#   .hidden-xs-down[_ngcontent-c3] {
#     display: none !important; } }
#
# @media (min-width: 480px) {
#   .hidden-sm-up[_ngcontent-c3] {
#     display: none !important; } }
#
# @media (max-width: 767px) {
#   .hidden-sm-down[_ngcontent-c3] {
#     display: none !important; } }
#
# @media (min-width: 768px) {
#   .hidden-md-up[_ngcontent-c3] {
#     display: none !important; } }
#
# @media (max-width: 991px) {
#   .hidden-md-down[_ngcontent-c3] {
#     display: none !important; } }
#
# @media (min-width: 992px) {
#   .hidden-lg-up[_ngcontent-c3] {
#     display: none !important; } }
#
# @media (max-width: 1179px) {
#   .hidden-lg-down[_ngcontent-c3] {
#     display: none !important; } }
#
# @media (min-width: 1180px) {
#   .hidden-xl-up[_ngcontent-c3] {
#     display: none !important; } }
#
# .hidden-xl-down[_ngcontent-c3] {
#   display: none !important; }
#
# .visible-print-block[_ngcontent-c3] {
#   display: none !important; }
#   @media print {
#     .visible-print-block[_ngcontent-c3] {
#       display: block !important; } }
#
# .visible-print-inline[_ngcontent-c3] {
#   display: none !important; }
#   @media print {
#     .visible-print-inline[_ngcontent-c3] {
#       display: inline !important; } }
#
# .visible-print-inline-block[_ngcontent-c3] {
#   display: none !important; }
#   @media print {
#     .visible-print-inline-block[_ngcontent-c3] {
#       display: inline-block !important; } }
#
# @media print {
#   .hidden-print[_ngcontent-c3] {
#     display: none !important; } }
#
# html[_ngcontent-c3] {
#   box-sizing: border-box; }
#
# *[_ngcontent-c3], *[_ngcontent-c3]::after, *[_ngcontent-c3]::before {
#   box-sizing: inherit; }
#
# ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3], input[type="color"][_ngcontent-c3], input[type="date"][_ngcontent-c3], input[type="datetime"][_ngcontent-c3], input[type="datetime-local"][_ngcontent-c3], input[type="email"][_ngcontent-c3], input[type="month"][_ngcontent-c3], input[type="number"][_ngcontent-c3], input[type="password"][_ngcontent-c3], input[type="search"][_ngcontent-c3], input[type="tel"][_ngcontent-c3], input[type="text"][_ngcontent-c3], input[type="time"][_ngcontent-c3], input[type="url"][_ngcontent-c3], input[type="week"][_ngcontent-c3], input[_ngcontent-c3]:not([type]), textarea[_ngcontent-c3], select[multiple][_ngcontent-c3] {
#   margin-top: 0;
#   margin-bottom: 0.75rem;
#   width: 100%;
#   outline: none;
#   color: #7d97ad;
#   vertical-align: top;
#   height: 3rem;
#   border: 1px solid #dbe2e8;
#   padding: 0 1.25rem;
#   box-sizing: border-box;
#   font-size: 0.875rem;
#   box-shadow: 5px 5px 10px 0 rgba(46, 61, 73, 0.05);
#   border-radius: 0.25rem;
#   transition: box-shadow 0.3s ease, border 0.3s ease; }
#   @media screen and (min-width: 48rem) {
#     ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3], input[type="color"][_ngcontent-c3], input[type="date"][_ngcontent-c3], input[type="datetime"][_ngcontent-c3], input[type="datetime-local"][_ngcontent-c3], input[type="email"][_ngcontent-c3], input[type="month"][_ngcontent-c3], input[type="number"][_ngcontent-c3], input[type="password"][_ngcontent-c3], input[type="search"][_ngcontent-c3], input[type="tel"][_ngcontent-c3], input[type="text"][_ngcontent-c3], input[type="time"][_ngcontent-c3], input[type="url"][_ngcontent-c3], input[type="week"][_ngcontent-c3], input[_ngcontent-c3]:not([type]), textarea[_ngcontent-c3], select[multiple][_ngcontent-c3] {
#       margin-bottom: 1.5rem; } }
#   ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]:hover, ir-modal[_ngcontent-c3]   .hover.newsletter-form[_ngcontent-c3], input[type="color"][_ngcontent-c3]:hover, input[type="color"].hover[_ngcontent-c3], input[type="date"][_ngcontent-c3]:hover, input[type="date"].hover[_ngcontent-c3], input[type="datetime"][_ngcontent-c3]:hover, input[type="datetime"].hover[_ngcontent-c3], input[type="datetime-local"][_ngcontent-c3]:hover, input[type="datetime-local"].hover[_ngcontent-c3], input[type="email"][_ngcontent-c3]:hover, input[type="email"].hover[_ngcontent-c3], input[type="month"][_ngcontent-c3]:hover, input[type="month"].hover[_ngcontent-c3], input[type="number"][_ngcontent-c3]:hover, input[type="number"].hover[_ngcontent-c3], input[type="password"][_ngcontent-c3]:hover, input[type="password"].hover[_ngcontent-c3], input[type="search"][_ngcontent-c3]:hover, input[type="search"].hover[_ngcontent-c3], input[type="tel"][_ngcontent-c3]:hover, input[type="tel"].hover[_ngcontent-c3], input[type="text"][_ngcontent-c3]:hover, input[type="text"].hover[_ngcontent-c3], input[type="time"][_ngcontent-c3]:hover, input[type="time"].hover[_ngcontent-c3], input[type="url"][_ngcontent-c3]:hover, input[type="url"].hover[_ngcontent-c3], input[type="week"][_ngcontent-c3]:hover, input[type="week"].hover[_ngcontent-c3], input[_ngcontent-c3]:not([type]):hover, input[_ngcontent-c3]:not([type]).hover, textarea[_ngcontent-c3]:hover, textarea.hover[_ngcontent-c3], select[multiple][_ngcontent-c3]:hover, select[multiple].hover[_ngcontent-c3] {
#     box-shadow: 0 4px 8px 0 rgba(46, 61, 73, 0.12); }
#   ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]:focus, ir-modal[_ngcontent-c3]   .focus.newsletter-form[_ngcontent-c3], input[type="color"][_ngcontent-c3]:focus, input[type="color"].focus[_ngcontent-c3], input[type="date"][_ngcontent-c3]:focus, input[type="date"].focus[_ngcontent-c3], input[type="datetime"][_ngcontent-c3]:focus, input[type="datetime"].focus[_ngcontent-c3], input[type="datetime-local"][_ngcontent-c3]:focus, input[type="datetime-local"].focus[_ngcontent-c3], input[type="email"][_ngcontent-c3]:focus, input[type="email"].focus[_ngcontent-c3], input[type="month"][_ngcontent-c3]:focus, input[type="month"].focus[_ngcontent-c3], input[type="number"][_ngcontent-c3]:focus, input[type="number"].focus[_ngcontent-c3], input[type="password"][_ngcontent-c3]:focus, input[type="password"].focus[_ngcontent-c3], input[type="search"][_ngcontent-c3]:focus, input[type="search"].focus[_ngcontent-c3], input[type="tel"][_ngcontent-c3]:focus, input[type="tel"].focus[_ngcontent-c3], input[type="text"][_ngcontent-c3]:focus, input[type="text"].focus[_ngcontent-c3], input[type="time"][_ngcontent-c3]:focus, input[type="time"].focus[_ngcontent-c3], input[type="url"][_ngcontent-c3]:focus, input[type="url"].focus[_ngcontent-c3], input[type="week"][_ngcontent-c3]:focus, input[type="week"].focus[_ngcontent-c3], input[_ngcontent-c3]:not([type]):focus, input[_ngcontent-c3]:not([type]).focus, textarea[_ngcontent-c3]:focus, textarea.focus[_ngcontent-c3], select[multiple][_ngcontent-c3]:focus, select[multiple].focus[_ngcontent-c3] {
#     border-color: #02b3e4;
#     box-shadow: 5px 5px 10px 0 rgba(46, 61, 73, 0.05); }
#   ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]:disabled, ir-modal[_ngcontent-c3]   .disabled.newsletter-form[_ngcontent-c3], input[type="color"][_ngcontent-c3]:disabled, input[type="color"].disabled[_ngcontent-c3], input[type="date"][_ngcontent-c3]:disabled, input[type="date"].disabled[_ngcontent-c3], input[type="datetime"][_ngcontent-c3]:disabled, input[type="datetime"].disabled[_ngcontent-c3], input[type="datetime-local"][_ngcontent-c3]:disabled, input[type="datetime-local"].disabled[_ngcontent-c3], input[type="email"][_ngcontent-c3]:disabled, input[type="email"].disabled[_ngcontent-c3], input[type="month"][_ngcontent-c3]:disabled, input[type="month"].disabled[_ngcontent-c3], input[type="number"][_ngcontent-c3]:disabled, input[type="number"].disabled[_ngcontent-c3], input[type="password"][_ngcontent-c3]:disabled, input[type="password"].disabled[_ngcontent-c3], input[type="search"][_ngcontent-c3]:disabled, input[type="search"].disabled[_ngcontent-c3], input[type="tel"][_ngcontent-c3]:disabled, input[type="tel"].disabled[_ngcontent-c3], input[type="text"][_ngcontent-c3]:disabled, input[type="text"].disabled[_ngcontent-c3], input[type="time"][_ngcontent-c3]:disabled, input[type="time"].disabled[_ngcontent-c3], input[type="url"][_ngcontent-c3]:disabled, input[type="url"].disabled[_ngcontent-c3], input[type="week"][_ngcontent-c3]:disabled, input[type="week"].disabled[_ngcontent-c3], input[_ngcontent-c3]:not([type]):disabled, input[_ngcontent-c3]:not([type]).disabled, textarea[_ngcontent-c3]:disabled, textarea.disabled[_ngcontent-c3], select[multiple][_ngcontent-c3]:disabled, select[multiple].disabled[_ngcontent-c3] {
#     opacity: 0.5;
#     cursor: not-allowed;
#     pointer-events: none; }
#     ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]:disabled:hover, ir-modal[_ngcontent-c3]   .disabled.newsletter-form[_ngcontent-c3]:hover, input[type="color"][_ngcontent-c3]:disabled:hover, input[type="color"].disabled[_ngcontent-c3]:hover, input[type="date"][_ngcontent-c3]:disabled:hover, input[type="date"].disabled[_ngcontent-c3]:hover, input[type="datetime"][_ngcontent-c3]:disabled:hover, input[type="datetime"].disabled[_ngcontent-c3]:hover, input[type="datetime-local"][_ngcontent-c3]:disabled:hover, input[type="datetime-local"].disabled[_ngcontent-c3]:hover, input[type="email"][_ngcontent-c3]:disabled:hover, input[type="email"].disabled[_ngcontent-c3]:hover, input[type="month"][_ngcontent-c3]:disabled:hover, input[type="month"].disabled[_ngcontent-c3]:hover, input[type="number"][_ngcontent-c3]:disabled:hover, input[type="number"].disabled[_ngcontent-c3]:hover, input[type="password"][_ngcontent-c3]:disabled:hover, input[type="password"].disabled[_ngcontent-c3]:hover, input[type="search"][_ngcontent-c3]:disabled:hover, input[type="search"].disabled[_ngcontent-c3]:hover, input[type="tel"][_ngcontent-c3]:disabled:hover, input[type="tel"].disabled[_ngcontent-c3]:hover, input[type="text"][_ngcontent-c3]:disabled:hover, input[type="text"].disabled[_ngcontent-c3]:hover, input[type="time"][_ngcontent-c3]:disabled:hover, input[type="time"].disabled[_ngcontent-c3]:hover, input[type="url"][_ngcontent-c3]:disabled:hover, input[type="url"].disabled[_ngcontent-c3]:hover, input[type="week"][_ngcontent-c3]:disabled:hover, input[type="week"].disabled[_ngcontent-c3]:hover, input[_ngcontent-c3]:not([type]):disabled:hover, input[_ngcontent-c3]:not([type]).disabled:hover, textarea[_ngcontent-c3]:disabled:hover, textarea.disabled[_ngcontent-c3]:hover, select[multiple][_ngcontent-c3]:disabled:hover, select[multiple].disabled[_ngcontent-c3]:hover {
#       box-shadow: 5px 5px 10px 0 rgba(46, 61, 73, 0.05); }
#   ir-modal[_ngcontent-c3]   .inline.newsletter-form[_ngcontent-c3], input[type="color"].inline[_ngcontent-c3], input[type="date"].inline[_ngcontent-c3], input[type="datetime"].inline[_ngcontent-c3], input[type="datetime-local"].inline[_ngcontent-c3], input[type="email"].inline[_ngcontent-c3], input[type="month"].inline[_ngcontent-c3], input[type="number"].inline[_ngcontent-c3], input[type="password"].inline[_ngcontent-c3], input[type="search"].inline[_ngcontent-c3], input[type="tel"].inline[_ngcontent-c3], input[type="text"].inline[_ngcontent-c3], input[type="time"].inline[_ngcontent-c3], input[type="url"].inline[_ngcontent-c3], input[type="week"].inline[_ngcontent-c3], input[_ngcontent-c3]:not([type]).inline, textarea.inline[_ngcontent-c3], select[multiple].inline[_ngcontent-c3] {
#     display: inline-block;
#     margin-right: 0.75rem; }
#     ir-modal[_ngcontent-c3]   .inline.newsletter-form[_ngcontent-c3]:last-child, input[type="color"].inline[_ngcontent-c3]:last-child, input[type="date"].inline[_ngcontent-c3]:last-child, input[type="datetime"].inline[_ngcontent-c3]:last-child, input[type="datetime-local"].inline[_ngcontent-c3]:last-child, input[type="email"].inline[_ngcontent-c3]:last-child, input[type="month"].inline[_ngcontent-c3]:last-child, input[type="number"].inline[_ngcontent-c3]:last-child, input[type="password"].inline[_ngcontent-c3]:last-child, input[type="search"].inline[_ngcontent-c3]:last-child, input[type="tel"].inline[_ngcontent-c3]:last-child, input[type="text"].inline[_ngcontent-c3]:last-child, input[type="time"].inline[_ngcontent-c3]:last-child, input[type="url"].inline[_ngcontent-c3]:last-child, input[type="week"].inline[_ngcontent-c3]:last-child, input[_ngcontent-c3]:not([type]).inline:last-child, textarea.inline[_ngcontent-c3]:last-child, select[multiple].inline[_ngcontent-c3]:last-child {
#       margin-right: 0; }
#     @media screen and (min-width: 48rem) {
#       ir-modal[_ngcontent-c3]   .inline.newsletter-form[_ngcontent-c3], input[type="color"].inline[_ngcontent-c3], input[type="date"].inline[_ngcontent-c3], input[type="datetime"].inline[_ngcontent-c3], input[type="datetime-local"].inline[_ngcontent-c3], input[type="email"].inline[_ngcontent-c3], input[type="month"].inline[_ngcontent-c3], input[type="number"].inline[_ngcontent-c3], input[type="password"].inline[_ngcontent-c3], input[type="search"].inline[_ngcontent-c3], input[type="tel"].inline[_ngcontent-c3], input[type="text"].inline[_ngcontent-c3], input[type="time"].inline[_ngcontent-c3], input[type="url"].inline[_ngcontent-c3], input[type="week"].inline[_ngcontent-c3], input[_ngcontent-c3]:not([type]).inline, textarea.inline[_ngcontent-c3], select[multiple].inline[_ngcontent-c3] {
#         margin-top: 0;
#         margin-bottom: 0; } }
#   @media screen and (min-width: 48rem) and (min-width: 48rem) {
#     ir-modal[_ngcontent-c3]   .inline.newsletter-form[_ngcontent-c3], input[type="color"].inline[_ngcontent-c3], input[type="date"].inline[_ngcontent-c3], input[type="datetime"].inline[_ngcontent-c3], input[type="datetime-local"].inline[_ngcontent-c3], input[type="email"].inline[_ngcontent-c3], input[type="month"].inline[_ngcontent-c3], input[type="number"].inline[_ngcontent-c3], input[type="password"].inline[_ngcontent-c3], input[type="search"].inline[_ngcontent-c3], input[type="tel"].inline[_ngcontent-c3], input[type="text"].inline[_ngcontent-c3], input[type="time"].inline[_ngcontent-c3], input[type="url"].inline[_ngcontent-c3], input[type="week"].inline[_ngcontent-c3], input[_ngcontent-c3]:not([type]).inline, textarea.inline[_ngcontent-c3], select[multiple].inline[_ngcontent-c3] {
#       margin-bottom: 0; } }
#
# fieldset[_ngcontent-c3] {
#   margin-top: 0;
#   margin-bottom: 0.75rem;
#   border: 0;
#   padding: 0;
#   background-color: transparent; }
#   @media screen and (min-width: 48rem) {
#     fieldset[_ngcontent-c3] {
#       margin-bottom: 1.5rem; } }
#
# legend[_ngcontent-c3] {
#   margin-top: 0;
#   margin-bottom: 0.75rem;
#   padding: 0; }
#   @media screen and (min-width: 48rem) {
#     legend[_ngcontent-c3] {
#       margin-bottom: 1.5rem; } }
#
# label[_ngcontent-c3] {
#   margin-top: 0;
#   margin-bottom: 0.75rem;
#   display: block; }
#   @media screen and (min-width: 48rem) {
#     label[_ngcontent-c3] {
#       margin-bottom: 1.5rem; } }
#
# textarea[_ngcontent-c3] {
#   padding: 0.6875rem 1.25rem; }
#
# input[type="number"][_ngcontent-c3] {
#   -moz-appearance: textfield; }
#
# input[_ngcontent-c3]::-webkit-outer-spin-button, input[_ngcontent-c3]::-webkit-inner-spin-button {
#   -webkit-appearance: none; }
#
# [type="search"][_ngcontent-c3] {
#   appearance: none; }
#
# [type="radio"][_ngcontent-c3] {
#   display: inline;
#   margin-right: 0.75rem; }
#
# [type="file"][_ngcontent-c3] {
#   margin-top: 0;
#   margin-bottom: 0.75rem;
#   width: 100%; }
#   @media screen and (min-width: 48rem) {
#     [type="file"][_ngcontent-c3] {
#       margin-bottom: 1.5rem; } }
#
# select[_ngcontent-c3] {
#   margin-top: 0;
#   margin-bottom: 0.75rem;
#   max-width: 100%;
#   width: auto; }
#   @media screen and (min-width: 48rem) {
#     select[_ngcontent-c3] {
#       margin-bottom: 1.5rem; } }
#
# .checkbox[_ngcontent-c3] {
#   position: relative; }
#   .checkbox[_ngcontent-c3]   input[type=checkbox][_ngcontent-c3] {
#     display: none !important; }
#     .checkbox[_ngcontent-c3]   input[type=checkbox][_ngcontent-c3]:checked    + label[_ngcontent-c3]::after {
#       background-size: 60%;
#       opacity: 1; }
#     .checkbox[_ngcontent-c3]   input[type=checkbox][_ngcontent-c3]:disabled    + label[_ngcontent-c3] {
#       opacity: .5; }
#   .checkbox[_ngcontent-c3]   label[_ngcontent-c3] {
#     font-size: 0.8125rem;
#     line-height: 1.5rem;
#     margin-top: 0;
#     margin-bottom: 0.75rem;
#     clear: left;
#     display: block;
#     position: relative;
#     color: #7d97ad;
#     letter-spacing: 0.0625rem;
#     text-transform: uppercase;
#     padding-left: 1.5rem; }
#     @media screen and (min-width: 48rem) {
#       .checkbox[_ngcontent-c3]   label[_ngcontent-c3] {
#         font-size: 0.8125rem;
#         line-height: 1.5rem; } }
#     @media screen and (min-width: 48rem) {
#       .checkbox[_ngcontent-c3]   label[_ngcontent-c3] {
#         margin-bottom: 0.75rem; } }
#     .checkbox[_ngcontent-c3]   label[_ngcontent-c3]   a[_ngcontent-c3] {
#       color: #7d97ad;
#       text-decoration: none;
#       border-bottom: 1px solid #91daee;
#       transition: color 0.3s ease; }
#       .checkbox[_ngcontent-c3]   label[_ngcontent-c3]   a[_ngcontent-c3]:hover {
#         color: #9db0c0; }
#     .checkbox[_ngcontent-c3]   label[_ngcontent-c3]::before, .checkbox[_ngcontent-c3]   label[_ngcontent-c3]::after {
#       content: '';
#       position: absolute;
#       top: 4px;
#       left: 0;
#       width: 16px;
#       height: 16px;
#       background: white;
#       border: 1px solid #dbe2e8;
#       box-shadow: 0 2px 5px 0 rgba(46, 61, 73, 0.08); }
#     .checkbox[_ngcontent-c3]   label[_ngcontent-c3]::after {
#       opacity: 0;
#       background-size: 20%;
#       background: image-url("svgs/check_blue.svg") no-repeat center;
#       transition: opacity 0.3s ease, background-size 0.3s ease; }
#
# input.form-error[_ngcontent-c3], select.form-error[_ngcontent-c3], textarea.form-error[_ngcontent-c3] {
#   color: #f95c3c;
#   background-color: rgba(249, 92, 60, 0.02);
#   border: 1px solid #f04546; }
#
# .error-container[_ngcontent-c3] {
#   height: 2.25rem;
#   position: absolute;
#   left: 0;
#   right: 0;
#   width: 90%;
#   margin: 0 auto;
#   display: block;
#   text-align: center;
#   top: -3rem;
#   background-color: #f04546;
#   border-radius: 0.25rem;
#   transition: all 0.3s ease;
#   opacity: 0; }
#   .error-container.filled[_ngcontent-c3] {
#     transition: all 0.3s ease;
#     opacity: 1; }
#   .error-container[_ngcontent-c3]:after {
#     content: '';
#     width: 0;
#     height: 0;
#     top: 18px;
#     position: relative;
#     border-style: solid;
#     border-width: 8px 6px 0;
#     border-color: #f04546 transparent transparent; }
#
# .error-text[_ngcontent-c3] {
#   font-size: 0.75rem;
#   line-height: 1.5rem;
#   position: relative;
#   top: 50%;
#   -webkit-transform: translateY(-50%);
#   -moz-transform: translateY(-50%);
#   -ms-transform: translateY(-50%);
#   -o-transform: translateY(-50%);
#   transform: translateY(-50%);
#   color: #fff;
#   display: block;
#   text-align: center; }
#   @media screen and (min-width: 48rem) {
#     .error-text[_ngcontent-c3] {
#       font-size: 0.75rem;
#       line-height: 1.5rem; } }
#
# button[_ngcontent-c3], input[type="button"][_ngcontent-c3], input[type="reset"][_ngcontent-c3], input[type="submit"][_ngcontent-c3], .button[_ngcontent-c3], .button--primary[_ngcontent-c3], .button--secondary[_ngcontent-c3], .button--outline[_ngcontent-c3], .button--white[_ngcontent-c3], .button--navigation[_ngcontent-c3], .button--turquoise[_ngcontent-c3], .button--team[_ngcontent-c3], ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]   #newsletter-signup-btn[_ngcontent-c3] {
#   display: block;
#   cursor: pointer;
#   appearance: none;
#   user-select: none;
#   text-align: center;
#   white-space: nowrap;
#   vertical-align: top;
#   text-decoration: none;
#   vertical-align: middle;
#   height: 3rem;
#   padding: 0 0.5rem;
#   text-transform: uppercase;
#   font-size: 16px;
#   font-weight: 600;
#   font-size: 0.8125rem;
#   line-height: 2.625rem;
#   -webkit-font-smoothing: antialiased;
#   border-radius: 0.25rem;
#   letter-spacing: 0.125rem;
#   transition: all 0.3s ease; }
#
# .button--primary[_ngcontent-c3], .button--secondary[_ngcontent-c3], .button--outline[_ngcontent-c3], .button--white[_ngcontent-c3], ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]   #newsletter-signup-btn[_ngcontent-c3] {
#   box-shadow: 8px 10px 20px 0px rgba(46, 61, 73, 0.15); }
#   .button--primary[_ngcontent-c3]:hover, .button--secondary[_ngcontent-c3]:hover, .button--outline[_ngcontent-c3]:hover, .button--white[_ngcontent-c3]:hover, ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]   #newsletter-signup-btn[_ngcontent-c3]:hover {
#     box-shadow: 2px 4px 8px 0px rgba(46, 61, 73, 0.2); }
#
# .button--primary[_ngcontent-c3] {
#   width: 13.75rem;
#   color: #fff;
#   background-color: #02b3e4;
#   border: 0.125rem solid transparent; }
#   .button--primary[_ngcontent-c3]:focus, .button--primary.focus[_ngcontent-c3], .button--primary[_ngcontent-c3]:hover {
#     outline: none;
#     color: white;
#     border-color: transparent;
#     background-color: #029fcb; }
#   .button--primary.disabled[_ngcontent-c3], .button--primary[disabled][_ngcontent-c3], fieldset[disabled][_ngcontent-c3]   .button--primary[_ngcontent-c3] {
#     box-shadow: none;
#     cursor: not-allowed;
#     border-color: #dbe2e8;
#     background-color: #dbe2e8; }
#   .button--primary.pending[_ngcontent-c3] {
#     cursor: progress;
#     box-shadow: none; }
#     .button--primary.pending[_ngcontent-c3]:hover {
#       background-color: #02b3e4; }
#   .button--primary.inline[_ngcontent-c3] {
#     display: inline-block; }
#   .button--primary.sm[_ngcontent-c3] {
#     width: 11.25rem; }
#   .button--primary.lg[_ngcontent-c3] {
#     width: 17.5rem; }
#     @media screen and (max-width: 20rem) {
#       .button--primary.lg[_ngcontent-c3] {
#         width: 100%; } }
#   .button--primary.full[_ngcontent-c3] {
#     width: 100%; }
#   .button--primary[_ngcontent-c3]    > svg[_ngcontent-c3] {
#     fill: currentcolor; }
#
# .button--secondary[_ngcontent-c3] {
#   width: 13.75rem;
#   color: #fff;
#   background-color: #7d97ad;
#   border: 0.125rem solid transparent; }
#   .button--secondary[_ngcontent-c3]:focus, .button--secondary.focus[_ngcontent-c3], .button--secondary[_ngcontent-c3]:hover {
#     outline: none;
#     color: white;
#     border-color: transparent;
#     background-color: #6d8aa3; }
#   .button--secondary.disabled[_ngcontent-c3], .button--secondary[disabled][_ngcontent-c3], fieldset[disabled][_ngcontent-c3]   .button--secondary[_ngcontent-c3] {
#     box-shadow: none;
#     cursor: not-allowed;
#     border-color: #dbe2e8;
#     background-color: #dbe2e8; }
#   .button--secondary.pending[_ngcontent-c3] {
#     cursor: progress;
#     box-shadow: none; }
#     .button--secondary.pending[_ngcontent-c3]:hover {
#       background-color: #7d97ad; }
#   .button--secondary.inline[_ngcontent-c3] {
#     display: inline-block; }
#   .button--secondary.sm[_ngcontent-c3] {
#     width: 11.25rem; }
#   .button--secondary.lg[_ngcontent-c3] {
#     width: 17.5rem; }
#     @media screen and (max-width: 20rem) {
#       .button--secondary.lg[_ngcontent-c3] {
#         width: 100%; } }
#   .button--secondary.full[_ngcontent-c3] {
#     width: 100%; }
#   .button--secondary[_ngcontent-c3]    > svg[_ngcontent-c3] {
#     fill: currentcolor; }
#
# .button--outline[_ngcontent-c3] {
#   width: 13.75rem;
#   color: #fff;
#   background-color: transparent;
#   border: 0.125rem solid #fff; }
#   .button--outline[_ngcontent-c3]:focus, .button--outline.focus[_ngcontent-c3], .button--outline[_ngcontent-c3]:hover {
#     outline: none;
#     color: white;
#     border-color: #fff;
#     background-color: transparent; }
#   .button--outline.disabled[_ngcontent-c3], .button--outline[disabled][_ngcontent-c3], fieldset[disabled][_ngcontent-c3]   .button--outline[_ngcontent-c3] {
#     box-shadow: none;
#     cursor: not-allowed;
#     border-color: #dbe2e8;
#     background-color: #dbe2e8; }
#   .button--outline.pending[_ngcontent-c3] {
#     cursor: progress;
#     box-shadow: none; }
#     .button--outline.pending[_ngcontent-c3]:hover {
#       background-color: transparent; }
#   .button--outline.inline[_ngcontent-c3] {
#     display: inline-block; }
#   .button--outline.sm[_ngcontent-c3] {
#     width: 11.25rem; }
#   .button--outline.lg[_ngcontent-c3] {
#     width: 17.5rem; }
#     @media screen and (max-width: 20rem) {
#       .button--outline.lg[_ngcontent-c3] {
#         width: 100%; } }
#   .button--outline.full[_ngcontent-c3] {
#     width: 100%; }
#   .button--outline[_ngcontent-c3]    > svg[_ngcontent-c3] {
#     fill: currentcolor; }
#
# .button--white[_ngcontent-c3] {
#   width: 13.75rem;
#   color: #02b3e4;
#   background-color: #fff;
#   border: 0.125rem solid transparent; }
#   .button--white[_ngcontent-c3]:focus, .button--white.focus[_ngcontent-c3], .button--white[_ngcontent-c3]:hover {
#     outline: none;
#     color: #1cccfd;
#     border-color: transparent;
#     background-color: #f2f2f2; }
#   .button--white.disabled[_ngcontent-c3], .button--white[disabled][_ngcontent-c3], fieldset[disabled][_ngcontent-c3]   .button--white[_ngcontent-c3] {
#     box-shadow: none;
#     cursor: not-allowed;
#     border-color: #dbe2e8;
#     background-color: #dbe2e8; }
#   .button--white.pending[_ngcontent-c3] {
#     cursor: progress;
#     box-shadow: none; }
#     .button--white.pending[_ngcontent-c3]:hover {
#       background-color: #fff; }
#   .button--white.inline[_ngcontent-c3] {
#     display: inline-block; }
#   .button--white.sm[_ngcontent-c3] {
#     width: 11.25rem; }
#   .button--white.lg[_ngcontent-c3] {
#     width: 17.5rem; }
#     @media screen and (max-width: 20rem) {
#       .button--white.lg[_ngcontent-c3] {
#         width: 100%; } }
#   .button--white.full[_ngcontent-c3] {
#     width: 100%; }
#   .button--white[_ngcontent-c3]    > svg[_ngcontent-c3] {
#     fill: currentcolor; }
#
# .button--navigation[_ngcontent-c3] {
#   color: #fff;
#   background-color: transparent;
#   border: 0.125rem solid transparent; }
#   .button--navigation[_ngcontent-c3]:focus, .button--navigation.focus[_ngcontent-c3], .button--navigation[_ngcontent-c3]:hover {
#     outline: none;
#     color: white;
#     border-color: transparent;
#     background-color: transparent; }
#   .button--navigation.disabled[_ngcontent-c3], .button--navigation[disabled][_ngcontent-c3], fieldset[disabled][_ngcontent-c3]   .button--navigation[_ngcontent-c3] {
#     box-shadow: none;
#     cursor: not-allowed;
#     border-color: #dbe2e8;
#     background-color: #dbe2e8; }
#   .button--navigation.pending[_ngcontent-c3] {
#     cursor: progress;
#     box-shadow: none; }
#     .button--navigation.pending[_ngcontent-c3]:hover {
#       background-color: transparent; }
#   .button--navigation.inline[_ngcontent-c3] {
#     display: inline-block; }
#   .button--navigation.sm[_ngcontent-c3] {
#     width: 11.25rem; }
#   .button--navigation.lg[_ngcontent-c3] {
#     width: 17.5rem; }
#     @media screen and (max-width: 20rem) {
#       .button--navigation.lg[_ngcontent-c3] {
#         width: 100%; } }
#   .button--navigation.full[_ngcontent-c3] {
#     width: 100%; }
#   .button--navigation[_ngcontent-c3]    > svg[_ngcontent-c3] {
#     fill: currentcolor; }
#
# .button--turquoise[_ngcontent-c3] {
#   color: #fff;
#   background-color: #02ccba;
#   border: 0.125rem solid transparent; }
#   .button--turquoise[_ngcontent-c3]:focus, .button--turquoise.focus[_ngcontent-c3], .button--turquoise[_ngcontent-c3]:hover {
#     outline: none;
#     color: white;
#     border-color: transparent;
#     background-color: #02b3a3; }
#   .button--turquoise.disabled[_ngcontent-c3], .button--turquoise[disabled][_ngcontent-c3], fieldset[disabled][_ngcontent-c3]   .button--turquoise[_ngcontent-c3] {
#     box-shadow: none;
#     cursor: not-allowed;
#     border-color: #dbe2e8;
#     background-color: #dbe2e8; }
#   .button--turquoise.pending[_ngcontent-c3] {
#     cursor: progress;
#     box-shadow: none; }
#     .button--turquoise.pending[_ngcontent-c3]:hover {
#       background-color: #02ccba; }
#   .button--turquoise.inline[_ngcontent-c3] {
#     display: inline-block; }
#   .button--turquoise.sm[_ngcontent-c3] {
#     width: 11.25rem; }
#   .button--turquoise.lg[_ngcontent-c3] {
#     width: 17.5rem; }
#     @media screen and (max-width: 20rem) {
#       .button--turquoise.lg[_ngcontent-c3] {
#         width: 100%; } }
#   .button--turquoise.full[_ngcontent-c3] {
#     width: 100%; }
#   .button--turquoise[_ngcontent-c3]    > svg[_ngcontent-c3] {
#     fill: currentcolor; }
#
# .button--team[_ngcontent-c3] {
#   color: #2e3d49;
#   background-color: transparent;
#   border: 0.125rem solid transparent; }
#   .button--team[_ngcontent-c3]:focus, .button--team.focus[_ngcontent-c3], .button--team[_ngcontent-c3]:hover {
#     outline: none;
#     color: #425768;
#     border-color: transparent;
#     background-color: transparent; }
#   .button--team.disabled[_ngcontent-c3], .button--team[disabled][_ngcontent-c3], fieldset[disabled][_ngcontent-c3]   .button--team[_ngcontent-c3] {
#     box-shadow: none;
#     cursor: not-allowed;
#     border-color: #dbe2e8;
#     background-color: #dbe2e8; }
#   .button--team.pending[_ngcontent-c3] {
#     cursor: progress;
#     box-shadow: none; }
#     .button--team.pending[_ngcontent-c3]:hover {
#       background-color: transparent; }
#   .button--team.inline[_ngcontent-c3] {
#     display: inline-block; }
#   .button--team.sm[_ngcontent-c3] {
#     width: 11.25rem; }
#   .button--team.lg[_ngcontent-c3] {
#     width: 17.5rem; }
#     @media screen and (max-width: 20rem) {
#       .button--team.lg[_ngcontent-c3] {
#         width: 100%; } }
#   .button--team.full[_ngcontent-c3] {
#     width: 100%; }
#   .button--team[_ngcontent-c3]    > svg[_ngcontent-c3] {
#     fill: currentcolor; }
#
# [_nghost-c3] {
#   display: block; }
#
# .hidden[_ngcontent-c3] {
#   display: none; }
#
# ir-modal[_ngcontent-c3]   header[_ngcontent-c3] {
#   text-align: center; }
#   ir-modal[_ngcontent-c3]   header[_ngcontent-c3]   img[_ngcontent-c3] {
#     margin-bottom: 1rem; }
#
# ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3] {
#   height: auto;
#   border: none;
#   box-shadow: none; }
#   ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]:hover {
#     box-shadow: none; }
#   ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]   fieldset[_ngcontent-c3] {
#     margin: 0; }
#     ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]   fieldset[_ngcontent-c3]::after {
#       clear: both;
#       content: "";
#       display: table; }
#   ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]   label[_ngcontent-c3] {
#     text-align: left;
#     color: #2e3d49; }
#   ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]   .personal[_ngcontent-c3] {
#     margin-top: 2rem; }
#   ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]   .mailing-lists[_ngcontent-c3] {
#     border-radius: 0.25rem;
#     margin-top: 1rem;
#     margin-bottom: 1rem;
#     border: 1px solid #dbe2e8;
#     padding: 2rem;
#     box-shadow: 5px 5px 10px 0 rgba(46, 61, 73, 0.05); }
# ...
#                 Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                      Web Tooling &amp; Automation
#
#                       New
#
#
#
#
#
#
#
#                     intermediário
#
#
#
#
#               In this course, you’ll learn how to setup your development environment and save a lot of time and effort with automatic optimization.
#
#                 Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                      Fundamentos do Design Responsivo para a Web
#
#
#
#
#
#
#
#
#
#                     intermediário
#
#
#
#
#               Aprenda e pratique estratégias para o desenvolvimento de websites que se adaptam a todos os dispositivos! Desenvolvido com Pete LePage do Google.
#
#                 Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                      Front End Frameworks
#
#                       New
#
#
#
#
#
#
#
#                     avançado
#
#
#
#
#               Explore and build interactive, single-page applications with popular JavaScript frameworks!
#
#                 Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                      Client-Server Communication
#
#                       New
#
#
#
#
#
#
#
#                     avançado
#
#
#
#
#               Learn how a client communicates with a server, including HTTP's request and response cycle, HTTP/2 and HTTPs.
#
#                 Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                      JavaScript Promises
#
#                       New
#
#
#
#
#
#
#
#                     avançado
#
#
#
#
#               Learn how to simplify asynchronous work with Native JavaScript Promises!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                      Offline Web Applications
#
#                       New
#
#
#
#
#
#
#
#                     intermediário
#
#
#
#
#               Learn how to develop offline-first web application using Service Workers and IndexedDB.
#
#                 Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                      Learn Swift Programming Syntax
#
#                       New
#
#
#
#
#
#
#
#                     intermediário
#
#
#
#
#               This course focuses on the syntax of the Swift programming language. By the end of the course, you'll be able to apply Swift essentials to building iOS apps.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                      Educational Technology
#
#
#
#
#
#
#
#
#
#                     beginner
#
#
#
#
#               This class is an an introductory course about educational technology offered as CS6460 at Georgia Tech where it is a part of the Online Masters Degree (OMS).
#
#                 Em colaboração com: Georgia Institute of Technology
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                      Model Building and Validation
#
#
#
#
#
#
#
#
#
#                     avançado
#
#
#
#
#               This course will teach you how to start from scratch in understanding and paying attention to what is important in the data and how to answer questions about data
#
#                 Em colaboração com: AT&amp;T
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                      Introduction to Operating Systems
#
#
#
#
#
#
#
#
#
#                     intermediário
#
#
#
#
#               Introduction to Operating Systems teaches the basic operating system abstractions, mechanisms, and their implementations.
#
#                 Em colaboração com: Georgia Institute of Technology
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                      Linear Algebra Refresher Course
#
#
#
#
#
#
#
#
#
#                     intermediário
#
#
#
#
#               Learn linear algebra by doing: you will code your own library of linear algebra functions!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                      Computational Photography
#
#
#
#
#
#
#
#
#
#                     intermediário
#
#
#
#
#               This class explores how computation impacts the entire workflow of photography, which is traditionally aimed at capturing light from a 3D scene to form a 2D image.
#
#                 Em colaboração com: Georgia Institute of Technology
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                      Problem Solving with Advanced Analytics
#
#
#
#
#
#
#
#
#
#                     beginner
#
#
#
#
#               Learn a scientific approach to solving problems with data, a foundational skill for anyone interested in making data driven decisions in a business context.
#
#                 Em colaboração com: Alteryx
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                      Creating an Analytical Dataset
#
#
#
#
#
#
#
#
#
#                     beginner
#
#
#
#
#               Learn how to prepare data to ensure the efficacy of your analysis while improving fluency in Alteryx.
#
#                 Em colaboração com: Alteryx
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                      A/B Testing for Business Analysts
#
#
#
#
#
#
#
#
#
#                     intermediário
#
#
#
#
#               The A/B Testing course provides students with the foundational knowledge to design and analyze A/B tests to create business insights and support decision making.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                      Time Series Forecasting
#
#
#
#
#
#
#
#
#
#                     intermediário
#
#
#
#
#               The Time Series Forecasting course provides students with the foundational knowledge to build and apply time series forecasting models in a variety of business contexts.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                      Segmentation and Clustering
#
#
#
#
#
#
#
#
#
#                     intermediário
#
#
#
#
#               The Segmentation &amp; Clustering course provides students with the knowledge to build and apply clustering models to develop sophisticated segmentation in business contexts.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                      JavaScript Design Patterns
#
#
#
#
#
#
#
#
#
#                     avançado
#
#
#
#
#               Saiba a importância da organização de código e como implementá-lo com qualquer JavaScript padrão, biblioteca ou framework.
#
#
#
#
#
#
#
#
#
#   Please waitLoading…
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             Programas Nanodegree em destaque
#
#
#     Data Science para Negócios
#
#     Desenvolvedor Android
#
#     Desenvolvedor de Realidade Virtual
#
#     Desenvolvedor Web Front-End
#
#     Engenheiro de Inteligência Artificial
#
#     Engenheiro de Machine Learning
#
#     Fundamentos de Data Science I
#
#     Fundamentos de Data Science II
#
#     Fundamentos de Deep Learning
#
#
#
#
#
#
#
#
#
#
#             Aprenda com a Udacity
#
#
#     Introdução à Programação
#
#     Xcode Debugging
#
#     Aprenda JavaScript
#
#     Como criar um aplicativo iOS
#
#     Introdução ao HTML e CSS
#
#     Desenvolvimento de Software VR
#
#     JavaScript Orientado a Objetos
#
#     Desenvolvendo Apps Android
#
#     Introdução à Análise de Dados
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Recursos para estudantes
#
#
#     Catálogo
#
#     Histórias de Sucesso
#
#
# Empresas
#
#
#     Udacity para Empresas
#
#     Recrute graduados
#
#
#
#
#
#
#
#
#
#             Udacity
#
#
#     Sobre
#
#     Imprensa
#
#     Eventos
#
#     Blog
#
#     Vagas
#
#     Georgia Tech (Inglês)
#
#     App Android
#
#     App iOs
#
#
#
#
#
#
#
#
#
#
#             Consulta
#
#
#     Central de Ajuda
#
#     Entre em contato
#
#     Status do serviço
#
#     Política de Privacidade
#
#     Termos de Uso
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             © 2011–2017 Udacity, Inc.
#
#
#
#
#             Mapa do site
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       Nanodegree é marca registrada da Udacity © 2011–2017 Udacity, Inc.
#       A Udacity é uma empresa de tecnologia em educação que oferece cursos online em seu website, não se tratando de uma universidade no sentido tradicional da palavra.

# %%
from bs4 import BeautifulSoup

# Remove HTML tags using Beautiful Soup library
soup = BeautifulSoup(r.text, "fast")
print(soup.get_text())
# Out:
# Udacity | Udacityhtml[_ngcontent-c0] {
#   box-sizing: border-box; }
#
# *[_ngcontent-c0], *[_ngcontent-c0]::after, *[_ngcontent-c0]::before {
#   box-sizing: inherit; }
#
# a[_ngcontent-c0] {
#   color: darkviolet; }
#
# body[_ngcontent-c0] {
#   color: #028bb1; }
#
# [_nghost-c0] {
#   display: block;
#   position: relative; }html[_ngcontent-c1] {
#   box-sizing: border-box; }
#
# *[_ngcontent-c1], *[_ngcontent-c1]::after, *[_ngcontent-c1]::before {
#   box-sizing: inherit; }
#
# .invisible[_ngcontent-c1] {
#   visibility: hidden !important; }
#
# .hide[_ngcontent-c1] {
#   display: none !important; }
#
# .show[_ngcontent-c1] {
#   display: block !important; }
#
# .sr-only[_ngcontent-c1] {
#   height: 1px;
#   width: 1px;
#   overflow: hidden;
#   position: absolute !important;
#   clip: rect(1px, 1px, 1px, 1px); }
#
# .hidden-xs-up[_ngcontent-c1] {
#   display: none !important; }
#
# @media (max-width: 479px) {
#   .hidden-xs-down[_ngcontent-c1] {
#     display: none !important; } }
#
# @media (min-width: 480px) {
#   .hidden-sm-up[_ngcontent-c1] {
#     display: none !important; } }
#
# @media (max-width: 767px) {
#   .hidden-sm-down[_ngcontent-c1] {
#     display: none !important; } }
#
# @media (min-width: 768px) {
#   .hidden-md-up[_ngcontent-c1] {
#     display: none !important; } }
#
# @media (max-width: 991px) {
#   .hidden-md-down[_ngcontent-c1] {
#     display: none !important; } }
#
# @media (min-width: 992px) {
#   .hidden-lg-up[_ngcontent-c1] {
#     display: none !important; } }
#
# @media (max-width: 1179px) {
#   .hidden-lg-down[_ngcontent-c1] {
#     display: none !important; } }
#
# @media (min-width: 1180px) {
#   .hidden-xl-up[_ngcontent-c1] {
#     display: none !important; } }
#
# .hidden-xl-down[_ngcontent-c1] {
#   display: none !important; }
#
# .visible-print-block[_ngcontent-c1] {
#   display: none !important; }
#   @media print {
#     .visible-print-block[_ngcontent-c1] {
#       display: block !important; } }
#
# .visible-print-inline[_ngcontent-c1] {
#   display: none !important; }
#   @media print {
#     .visible-print-inline[_ngcontent-c1] {
#       display: inline !important; } }
#
# .visible-print-inline-block[_ngcontent-c1] {
#   display: none !important; }
#   @media print {
#     .visible-print-inline-block[_ngcontent-c1] {
#       display: inline-block !important; } }
#
# @media print {
#   .hidden-print[_ngcontent-c1] {
#     display: none !important; } }
#
# #contain-all[_ngcontent-c1] {
#   width: 100%;
#   overflow: hidden;
#   background: #fff;
#   backface-visibility: hidden;
#   -webkit-transform-style: preserve-3d; }
#
# .outer_contain[_ngcontent-c1] {
#   margin: 0 auto;
#   max-width: 90rem; }
#
# .contain[_ngcontent-c1] {
#   max-width: 73.75rem;
#   margin-left: auto;
#   margin-right: auto;
#   padding-top: 3rem;
#   padding-bottom: 3rem;
#   padding-left: 1.5rem;
#   padding-right: 1.5rem; }
#   .contain[_ngcontent-c1]::after {
#     clear: both;
#     content: "";
#     display: table; }
#   @media screen and (min-width: 48rem) {
#     .contain[_ngcontent-c1] {
#       padding-top: 6rem;
#       padding-bottom: 6rem; } }
#   @media screen and (min-width: 73.75rem) {
#     .contain[_ngcontent-c1] {
#       padding-left: 0;
#       padding-right: 0; } }
#   .contain.no-padding[_ngcontent-c1] {
#     padding: 0; }
#   .contain.no-padding-top[_ngcontent-c1] {
#     padding-top: 0; }
#   .contain.no-padding-bottom[_ngcontent-c1] {
#     padding-bottom: 0; }
#   .contain--none[_ngcontent-c1] {
#     padding-top: 0rem;
#     padding-bottom: 0rem;
#     margin: 0 auto; }
#     @media screen and (min-width: 48rem) {
#       .contain--none[_ngcontent-c1] {
#         padding-top: 0rem;
#         padding-bottom: 0rem; } }
#   .contain--small[_ngcontent-c1] {
#     padding-top: 3rem;
#     padding-bottom: 3rem;
#     margin: 0 auto; }
#     @media screen and (min-width: 48rem) {
#       .contain--small[_ngcontent-c1] {
#         padding-top: 4.5rem;
#         padding-bottom: 4.5rem; } }
#
# .cards_contain[_ngcontent-c1] {
#   max-width: 73.75rem;
#   margin-left: auto;
#   margin-right: auto; }
#   .cards_contain[_ngcontent-c1]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# [_ngcontent-c1]:target:before {
#   content: '';
#   display: inline-block;
#   height: 130px;
#   margin: -130px 0 0; }
#
# .header[_ngcontent-c1] {
#   max-width: 100%;
#   margin-left: auto;
#   margin-right: auto; }
#   .header[_ngcontent-c1]::after {
#     clear: both;
#     content: "";
#     display: table; }
#   .header.header--clone[_ngcontent-c1] {
#     width: 100%;
#     top: -1000px; }
#     .header.header--clone[_ngcontent-c1]   .header__navbar[_ngcontent-c1] {
#       height: 4.5rem; }
#   .header.header--stick[_ngcontent-c1] {
#     top: 0;
#     background-color: #fff;
#     z-index: 8000;
#     box-shadow: 0px 1px 2px rgba(0, 0, 0, 0.1); }
#   .header__navbar[_ngcontent-c1] {
#     max-width: 73.75rem;
#     margin-left: auto;
#     margin-right: auto;
#     height: 4.5rem;
#     padding: 0 1.5em; }
#     .header__navbar[_ngcontent-c1]::after {
#       clear: both;
#       content: "";
#       display: table; }
#     @media screen and (min-width: 48rem) {
#       .header__navbar[_ngcontent-c1] {
#         height: 6rem; } }
#     @media screen and (min-width: 73.75rem) {
#       .header__navbar[_ngcontent-c1] {
#         padding: 0; } }
#     .header__navbar--toggle[_ngcontent-c1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       -moz-transform: translateY(-50%);
#       -ms-transform: translateY(-50%);
#       -o-transform: translateY(-50%);
#       transform: translateY(-50%);
#       float: left;
#       display: block;
#       margin-right: 1.69492%;
#       width: 15.25424%; }
#       .header__navbar--toggle[_ngcontent-c1]:last-child {
#         margin-right: 0; }
#       @media screen and (min-width: 30rem) {
#         .header__navbar--toggle[_ngcontent-c1] {
#           display: none; } }
#     .header__navbar--logo[_ngcontent-c1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       -moz-transform: translateY(-50%);
#       -ms-transform: translateY(-50%);
#       -o-transform: translateY(-50%);
#       transform: translateY(-50%);
#       float: left;
#       display: block;
#       margin-right: 1.69492%;
#       width: 66.10169%; }
#       .header__navbar--logo[_ngcontent-c1]:last-child {
#         margin-right: 0; }
#       @media screen and (min-width: 30rem) {
#         .header__navbar--logo[_ngcontent-c1] {
#           float: left;
#           display: block;
#           margin-right: 1.69492%;
#           width: 23.72881%; }
#           .header__navbar--logo[_ngcontent-c1]:last-child {
#             margin-right: 0; } }
#     .header__navbar--navigation[_ngcontent-c1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       -moz-transform: translateY(-50%);
#       -ms-transform: translateY(-50%);
#       -o-transform: translateY(-50%);
#       transform: translateY(-50%);
#       display: none; }
#       @media screen and (min-width: 30rem) {
#         .header__navbar--navigation[_ngcontent-c1] {
#           float: left;
#           display: block;
#           margin-right: 1.69492%;
#           width: 74.57627%; }
#           .header__navbar--navigation[_ngcontent-c1]:last-child {
#             margin-right: 0; } }
#   .header__navbar--logo[_ngcontent-c1] {
#     text-align: center; }
#     @media screen and (min-width: 30rem) {
#       .header__navbar--logo[_ngcontent-c1] {
#         text-align: left; } }
#     .header__navbar--logo[_ngcontent-c1]   .logo-wordmark[_ngcontent-c1] {
#       width: 11.25rem;
#       height: 1.875rem;
#       display: none; }
#       @media screen and (min-width: 30rem) {
#         .header__navbar--logo[_ngcontent-c1]   .logo-wordmark[_ngcontent-c1] {
#           display: block; } }
#     .header__navbar--logo[_ngcontent-c1]   .logo-mark[_ngcontent-c1] {
#       display: block;
#       margin: 0 auto;
#       width: 1.875rem;
#       height: 1.875rem; }
#       @media screen and (min-width: 30rem) {
#         .header__navbar--logo[_ngcontent-c1]   .logo-mark[_ngcontent-c1] {
#           display: none; } }
#   .header__navbar--toggle[_ngcontent-c1]   .nav-toggle[_ngcontent-c1] {
#     display: block;
#     width: 1.25rem;
#     height: 1.25rem;
#     cursor: pointer;
#     transition: transform .25s ease; }
#     .header__navbar--toggle[_ngcontent-c1]   .nav-toggle[_ngcontent-c1]   .bar[_ngcontent-c1] {
#       display: block;
#       width: 100%;
#       height: 0.1875rem;
#       margin-left: -0.5rem;
#       margin-top: 0.1875rem;
#       background: #02b3e4;
#       transition: opacity .25s ease, transform .25s ease;
#       user-select: none; }
#   .header__navbar--navigation[_ngcontent-c1]   nav[_ngcontent-c1] {
#     float: right; }
#   .header__navbar--navigation[_ngcontent-c1]   a[_ngcontent-c1], .header__navbar--navigation[_ngcontent-c1]   div[_ngcontent-c1] {
#     float: left; }
#   .header__navbar--navigation[_ngcontent-c1]   .button[_ngcontent-c1] {
#     display: none;
#     letter-spacing: 0;
#     font-size: 0.875rem;
#     text-transform: capitalize;
#     height: 2.25rem;
#     font-weight: 400;
#     margin-left: 2.5rem;
#     line-height: 1.9375rem; }
#     .header__navbar--navigation[_ngcontent-c1]   .button[_ngcontent-c1]:first-child {
#       margin-left: 0; }
#     @media screen and (min-width: 62rem) {
#       .header__navbar--navigation[_ngcontent-c1]   .button[_ngcontent-c1] {
#         display: block; } }
#     .header__navbar--navigation[_ngcontent-c1]   .button--navigation[_ngcontent-c1] {
#       padding: 0;
#       color: #525c65; }
#       .header__navbar--navigation[_ngcontent-c1]   .button--navigation[_ngcontent-c1]:hover {
#         color: #474f57; }
#     .header__navbar--navigation[_ngcontent-c1]   .button--primary[_ngcontent-c1], .header__navbar--navigation[_ngcontent-c1]   .button--turquoise[_ngcontent-c1] {
#       width: 7.75rem;
#       box-shadow: 8px 10px 20px 0px rgba(46, 61, 73, 0.15);
#       background-color: #02b3e4; }
#       .header__navbar--navigation[_ngcontent-c1]   .button--primary[_ngcontent-c1]:hover, .header__navbar--navigation[_ngcontent-c1]   .button--turquoise[_ngcontent-c1]:hover {
#         box-shadow: 2px 4px 8px 0px rgba(46, 61, 73, 0.2);
#         background-color: #02b7e9; }
#     .header__navbar--navigation[_ngcontent-c1]   .button--turquoise[_ngcontent-c1] {
#       background-color: #02ccba; }
#       .header__navbar--navigation[_ngcontent-c1]   .button--turquoise[_ngcontent-c1]:hover {
#         background-color: #02d1bf; }
#     .header__navbar--navigation[_ngcontent-c1]   .button--guest[_ngcontent-c1], .header__navbar--navigation[_ngcontent-c1]   .button--student[_ngcontent-c1] {
#       display: none; }
#   .header__navbar--navigation[_ngcontent-c1]   .divider[_ngcontent-c1] {
#     cursor: default; }
#     .header__navbar--navigation[_ngcontent-c1]   .divider[_ngcontent-c1]::before {
#       content: '';
#       border-left: 1px solid rgba(82, 92, 101, 0.4);
#       width: 0px;
#       height: 12px; }
#   .header__sidenav[_ngcontent-c1] {
#     background-color: #2e3d49; }
#     .header__sidenav--logo[_ngcontent-c1] {
#       height: 4.5rem;
#       display: block;
#       background-color: #1C262F; }
#       .header__sidenav--logo[_ngcontent-c1]::after {
#         clear: both;
#         content: "";
#         display: table; }
#       .header__sidenav--logo[_ngcontent-c1]   .logo-link[_ngcontent-c1] {
#         display: block;
#         width: 100%;
#         height: 100%; }
#         .header__sidenav--logo[_ngcontent-c1]   .logo-link[_ngcontent-c1]   .logo-wordmark[_ngcontent-c1] {
#           position: relative;
#           top: 50%;
#           -webkit-transform: translateY(-50%);
#           -moz-transform: translateY(-50%);
#           -ms-transform: translateY(-50%);
#           -o-transform: translateY(-50%);
#           transform: translateY(-50%);
#           padding-left: 1.5em;
#           width: 11.25rem;
#           height: 1.875rem; }
#         .header__sidenav--logo[_ngcontent-c1]   .logo-link[_ngcontent-c1]   #wordmark[_ngcontent-c1] {
#           fill: #fff; }
#     .header__sidenav--navigation[_ngcontent-c1] {
#       display: block; }
#       .header__sidenav--navigation[_ngcontent-c1]::after {
#         clear: both;
#         content: "";
#         display: table; }
#       .header__sidenav--navigation[_ngcontent-c1]   li[_ngcontent-c1] {
#         height: 4.5rem; }
#       .header__sidenav--navigation[_ngcontent-c1]   a[_ngcontent-c1] {
#         padding-top: 1.5rem;
#         padding-bottom: 1.5rem;
#         color: #fff;
#         display: block;
#         padding-left: 1.5em; }
#         @media screen and (min-width: 48rem) {
#           .header__sidenav--navigation[_ngcontent-c1]   a[_ngcontent-c1] {
#             padding-top: 1.5rem;
#             padding-bottom: 1.5rem; } }
#         .header__sidenav--navigation[_ngcontent-c1]   a[_ngcontent-c1]:hover {
#           color: #cccccc; }
#       .header__sidenav--navigation[_ngcontent-c1]   .guest[_ngcontent-c1], .header__sidenav--navigation[_ngcontent-c1]   .student[_ngcontent-c1] {
#         display: none; }
#         .header__sidenav--navigation[_ngcontent-c1]   .guest[_ngcontent-c1]   a[_ngcontent-c1], .header__sidenav--navigation[_ngcontent-c1]   .student[_ngcontent-c1]   a[_ngcontent-c1] {
#           color: #02b3e4; }
#           .header__sidenav--navigation[_ngcontent-c1]   .guest[_ngcontent-c1]   a[_ngcontent-c1]:hover, .header__sidenav--navigation[_ngcontent-c1]   .student[_ngcontent-c1]   a[_ngcontent-c1]:hover {
#             color: #01647f; }
#
# [_nghost-c1] {
#   background: #2e3d49;
#   position: fixed;
#   top: 0;
#   left: 0;
#   height: 100vh;
#   display: block;
#   overflow-y: auto;
#   z-index: -1000;
#   width: 16.25rem;
#   -webkit-overflow-scrolling: touch;
#   display: block; }
#   @media screen and (min-width: 30rem) {
#     [_nghost-c1] {
#       display: none; } }
#   [_nghost-c1]   .logo-link[_ngcontent-c1] {
#     height: 4.5rem;
#     display: block;
#     background-color: #1C262F; }
#     [_nghost-c1]   .logo-link[_ngcontent-c1]::after {
#       clear: both;
#       content: "";
#       display: table; }
#     [_nghost-c1]   .logo-link[_ngcontent-c1]   .logo-wordmark[_ngcontent-c1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       -moz-transform: translateY(-50%);
#       -ms-transform: translateY(-50%);
#       -o-transform: translateY(-50%);
#       transform: translateY(-50%);
#       padding-left: 1.5em;
#       width: 11.25rem;
#       height: 1.875rem; }
#     [_nghost-c1]   .logo-link[_ngcontent-c1]   #wordmark[_ngcontent-c1] {
#       fill: #fff; }
#   [_nghost-c1]   ul[_ngcontent-c1] {
#     list-style: none;
#     padding: 0; }html[_ngcontent-c2] {
#   box-sizing: border-box; }
#
# *[_ngcontent-c2], *[_ngcontent-c2]::after, *[_ngcontent-c2]::before {
#   box-sizing: inherit; }
#
# [_nghost-c2] {
#   position: absolute;
#   width: 100%;
#   top: 0;
#   left: 0;
#   min-height: 100vh;
#   z-index: 0;
#   transition: transform 0.3s ease;
#   background: #fff; }
#
# .menu--open[_nghost-c2], .menu--open   [_nghost-c2] {
#   transform: translateX(16.25rem);
#   height: 100vh;
#   overflow: hidden; }
#   @media screen and (min-width: 30rem) {
#     .menu--open[_nghost-c2], .menu--open   [_nghost-c2] {
#       overflow: auto;
#       transform: none;
#       height: auto; } }
#
# .sticky[_nghost-c2], .sticky   [_nghost-c2] {
#   padding-top: 4.5rem; }
#   @media screen and (min-width: 48rem) {
#     .sticky[_nghost-c2], .sticky   [_nghost-c2] {
#       padding-top: 6rem; } }
#
# .nd101-cn[_nghost-c2], .nd101-cn   [_nghost-c2], .nd101[_nghost-c2]:not(.page-in), .nd101:not(.page-in)   [_nghost-c2] {
#   background-color: #000;
#   background-repeat: no-repeat;
#   background-size: 100%;
#   background-attachment: scroll;
#   background-position: center top;
#   background-image: url("/assets/images/nanodegree-overview/shared/nd-hero-video/hero-bg-nd101.jpg"); }html[_ngcontent-c3] {
#   box-sizing: border-box; }
#
# *[_ngcontent-c3], *[_ngcontent-c3]::after, *[_ngcontent-c3]::before {
#   box-sizing: inherit; }
#
# .page-homepage[_nghost-c3]   .banner[_ngcontent-c3]   p[_ngcontent-c3], .page-homepage   [_nghost-c3]   .banner[_ngcontent-c3]   p[_ngcontent-c3], .page-homepage[_nghost-c3]   .banner[_ngcontent-c3]   a[_ngcontent-c3], .page-homepage   [_nghost-c3]   .banner[_ngcontent-c3]   a[_ngcontent-c3], .page-homepage[_nghost-c3]   .banner[_ngcontent-c3]   .close[_ngcontent-c3], .page-homepage   [_nghost-c3]   .banner[_ngcontent-c3]   .close[_ngcontent-c3] {
#   color: #02b3e4; }
#
# .page-homepage[_nghost-c3]   .banner.featured[_ngcontent-c3], .page-homepage   [_nghost-c3]   .banner.featured[_ngcontent-c3] {
#   background-color: #fff; }
#
# .page-homepage[_nghost-c3]   .banner[_ngcontent-c3]   #close-icon[_ngcontent-c3], .page-homepage   [_nghost-c3]   .banner[_ngcontent-c3]   #close-icon[_ngcontent-c3] {
#   fill: #02b3e4; }
#
# .banner[_ngcontent-c3] {
#   width: 100%;
#   color: #fff;
#   position: relative;
#   text-align: center;
#   padding: 0.75rem 1.5rem;
#   background-color: #7d97ad; }
#   .banner.featured[_ngcontent-c3] {
#     border-radius: 0;
#     background-color: #02b3e4; }
#   .banner[_ngcontent-c3]   p[_ngcontent-c3], .banner[_ngcontent-c3]   a[_ngcontent-c3] {
#     color: #fff;
#     display: inline-block;
#     margin: 0; }
#   .banner[_ngcontent-c3]   .close[_ngcontent-c3] {
#     position: absolute;
#     display: inline;
#     color: #fff;
#     right: 0;
#     top: 0;
#     height: 100%;
#     background-color: transparent;
#     border: none;
#     outline: none;
#     opacity: 0.75;
#     transition: opacity 0.3s ease; }
#     .banner[_ngcontent-c3]   .close[_ngcontent-c3]   svg[_ngcontent-c3] {
#       height: 13px;
#       width: auto;
#       top: 50%;
#       position: absolute;
#       right: 1rem;
#       transform: translateY(-50%); }
#     .banner[_ngcontent-c3]   .close[_ngcontent-c3]:hover {
#       opacity: 1; }html[_ngcontent-c3] {
#   box-sizing: border-box; }
#
# *[_ngcontent-c3], *[_ngcontent-c3]::after, *[_ngcontent-c3]::before {
#   box-sizing: inherit; }
#
# .invisible[_ngcontent-c3] {
#   visibility: hidden !important; }
#
# .hide[_ngcontent-c3] {
#   display: none !important; }
#
# .show[_ngcontent-c3] {
#   display: block !important; }
#
# .sr-only[_ngcontent-c3] {
#   height: 1px;
#   width: 1px;
#   overflow: hidden;
#   position: absolute !important;
#   clip: rect(1px, 1px, 1px, 1px); }
#
# .hidden-xs-up[_ngcontent-c3] {
#   display: none !important; }
#
# @media (max-width: 479px) {
#   .hidden-xs-down[_ngcontent-c3] {
#     display: none !important; } }
#
# @media (min-width: 480px) {
#   .hidden-sm-up[_ngcontent-c3] {
#     display: none !important; } }
#
# @media (max-width: 767px) {
#   .hidden-sm-down[_ngcontent-c3] {
#     display: none !important; } }
#
# @media (min-width: 768px) {
#   .hidden-md-up[_ngcontent-c3] {
#     display: none !important; } }
#
# @media (max-width: 991px) {
#   .hidden-md-down[_ngcontent-c3] {
#     display: none !important; } }
#
# @media (min-width: 992px) {
#   .hidden-lg-up[_ngcontent-c3] {
#     display: none !important; } }
#
# @media (max-width: 1179px) {
#   .hidden-lg-down[_ngcontent-c3] {
#     display: none !important; } }
#
# @media (min-width: 1180px) {
#   .hidden-xl-up[_ngcontent-c3] {
#     display: none !important; } }
#
# .hidden-xl-down[_ngcontent-c3] {
#   display: none !important; }
#
# .visible-print-block[_ngcontent-c3] {
#   display: none !important; }
#   @media print {
#     .visible-print-block[_ngcontent-c3] {
#       display: block !important; } }
#
# .visible-print-inline[_ngcontent-c3] {
#   display: none !important; }
#   @media print {
#     .visible-print-inline[_ngcontent-c3] {
#       display: inline !important; } }
#
# .visible-print-inline-block[_ngcontent-c3] {
#   display: none !important; }
#   @media print {
#     .visible-print-inline-block[_ngcontent-c3] {
#       display: inline-block !important; } }
#
# @media print {
#   .hidden-print[_ngcontent-c3] {
#     display: none !important; } }
#
# html[_ngcontent-c3] {
#   box-sizing: border-box; }
#
# *[_ngcontent-c3], *[_ngcontent-c3]::after, *[_ngcontent-c3]::before {
#   box-sizing: inherit; }
#
# ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3], input[type="color"][_ngcontent-c3], input[type="date"][_ngcontent-c3], input[type="datetime"][_ngcontent-c3], input[type="datetime-local"][_ngcontent-c3], input[type="email"][_ngcontent-c3], input[type="month"][_ngcontent-c3], input[type="number"][_ngcontent-c3], input[type="password"][_ngcontent-c3], input[type="search"][_ngcontent-c3], input[type="tel"][_ngcontent-c3], input[type="text"][_ngcontent-c3], input[type="time"][_ngcontent-c3], input[type="url"][_ngcontent-c3], input[type="week"][_ngcontent-c3], input[_ngcontent-c3]:not([type]), textarea[_ngcontent-c3], select[multiple][_ngcontent-c3] {
#   margin-top: 0;
#   margin-bottom: 0.75rem;
#   width: 100%;
#   outline: none;
#   color: #7d97ad;
#   vertical-align: top;
#   height: 3rem;
#   border: 1px solid #dbe2e8;
#   padding: 0 1.25rem;
#   box-sizing: border-box;
#   font-size: 0.875rem;
#   box-shadow: 5px 5px 10px 0 rgba(46, 61, 73, 0.05);
#   border-radius: 0.25rem;
#   transition: box-shadow 0.3s ease, border 0.3s ease; }
#   @media screen and (min-width: 48rem) {
#     ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3], input[type="color"][_ngcontent-c3], input[type="date"][_ngcontent-c3], input[type="datetime"][_ngcontent-c3], input[type="datetime-local"][_ngcontent-c3], input[type="email"][_ngcontent-c3], input[type="month"][_ngcontent-c3], input[type="number"][_ngcontent-c3], input[type="password"][_ngcontent-c3], input[type="search"][_ngcontent-c3], input[type="tel"][_ngcontent-c3], input[type="text"][_ngcontent-c3], input[type="time"][_ngcontent-c3], input[type="url"][_ngcontent-c3], input[type="week"][_ngcontent-c3], input[_ngcontent-c3]:not([type]), textarea[_ngcontent-c3], select[multiple][_ngcontent-c3] {
#       margin-bottom: 1.5rem; } }
#   ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]:hover, ir-modal[_ngcontent-c3]   .hover.newsletter-form[_ngcontent-c3], input[type="color"][_ngcontent-c3]:hover, input[type="color"].hover[_ngcontent-c3], input[type="date"][_ngcontent-c3]:hover, input[type="date"].hover[_ngcontent-c3], input[type="datetime"][_ngcontent-c3]:hover, input[type="datetime"].hover[_ngcontent-c3], input[type="datetime-local"][_ngcontent-c3]:hover, input[type="datetime-local"].hover[_ngcontent-c3], input[type="email"][_ngcontent-c3]:hover, input[type="email"].hover[_ngcontent-c3], input[type="month"][_ngcontent-c3]:hover, input[type="month"].hover[_ngcontent-c3], input[type="number"][_ngcontent-c3]:hover, input[type="number"].hover[_ngcontent-c3], input[type="password"][_ngcontent-c3]:hover, input[type="password"].hover[_ngcontent-c3], input[type="search"][_ngcontent-c3]:hover, input[type="search"].hover[_ngcontent-c3], input[type="tel"][_ngcontent-c3]:hover, input[type="tel"].hover[_ngcontent-c3], input[type="text"][_ngcontent-c3]:hover, input[type="text"].hover[_ngcontent-c3], input[type="time"][_ngcontent-c3]:hover, input[type="time"].hover[_ngcontent-c3], input[type="url"][_ngcontent-c3]:hover, input[type="url"].hover[_ngcontent-c3], input[type="week"][_ngcontent-c3]:hover, input[type="week"].hover[_ngcontent-c3], input[_ngcontent-c3]:not([type]):hover, input[_ngcontent-c3]:not([type]).hover, textarea[_ngcontent-c3]:hover, textarea.hover[_ngcontent-c3], select[multiple][_ngcontent-c3]:hover, select[multiple].hover[_ngcontent-c3] {
#     box-shadow: 0 4px 8px 0 rgba(46, 61, 73, 0.12); }
#   ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]:focus, ir-modal[_ngcontent-c3]   .focus.newsletter-form[_ngcontent-c3], input[type="color"][_ngcontent-c3]:focus, input[type="color"].focus[_ngcontent-c3], input[type="date"][_ngcontent-c3]:focus, input[type="date"].focus[_ngcontent-c3], input[type="datetime"][_ngcontent-c3]:focus, input[type="datetime"].focus[_ngcontent-c3], input[type="datetime-local"][_ngcontent-c3]:focus, input[type="datetime-local"].focus[_ngcontent-c3], input[type="email"][_ngcontent-c3]:focus, input[type="email"].focus[_ngcontent-c3], input[type="month"][_ngcontent-c3]:focus, input[type="month"].focus[_ngcontent-c3], input[type="number"][_ngcontent-c3]:focus, input[type="number"].focus[_ngcontent-c3], input[type="password"][_ngcontent-c3]:focus, input[type="password"].focus[_ngcontent-c3], input[type="search"][_ngcontent-c3]:focus, input[type="search"].focus[_ngcontent-c3], input[type="tel"][_ngcontent-c3]:focus, input[type="tel"].focus[_ngcontent-c3], input[type="text"][_ngcontent-c3]:focus, input[type="text"].focus[_ngcontent-c3], input[type="time"][_ngcontent-c3]:focus, input[type="time"].focus[_ngcontent-c3], input[type="url"][_ngcontent-c3]:focus, input[type="url"].focus[_ngcontent-c3], input[type="week"][_ngcontent-c3]:focus, input[type="week"].focus[_ngcontent-c3], input[_ngcontent-c3]:not([type]):focus, input[_ngcontent-c3]:not([type]).focus, textarea[_ngcontent-c3]:focus, textarea.focus[_ngcontent-c3], select[multiple][_ngcontent-c3]:focus, select[multiple].focus[_ngcontent-c3] {
#     border-color: #02b3e4;
#     box-shadow: 5px 5px 10px 0 rgba(46, 61, 73, 0.05); }
#   ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]:disabled, ir-modal[_ngcontent-c3]   .disabled.newsletter-form[_ngcontent-c3], input[type="color"][_ngcontent-c3]:disabled, input[type="color"].disabled[_ngcontent-c3], input[type="date"][_ngcontent-c3]:disabled, input[type="date"].disabled[_ngcontent-c3], input[type="datetime"][_ngcontent-c3]:disabled, input[type="datetime"].disabled[_ngcontent-c3], input[type="datetime-local"][_ngcontent-c3]:disabled, input[type="datetime-local"].disabled[_ngcontent-c3], input[type="email"][_ngcontent-c3]:disabled, input[type="email"].disabled[_ngcontent-c3], input[type="month"][_ngcontent-c3]:disabled, input[type="month"].disabled[_ngcontent-c3], input[type="number"][_ngcontent-c3]:disabled, input[type="number"].disabled[_ngcontent-c3], input[type="password"][_ngcontent-c3]:disabled, input[type="password"].disabled[_ngcontent-c3], input[type="search"][_ngcontent-c3]:disabled, input[type="search"].disabled[_ngcontent-c3], input[type="tel"][_ngcontent-c3]:disabled, input[type="tel"].disabled[_ngcontent-c3], input[type="text"][_ngcontent-c3]:disabled, input[type="text"].disabled[_ngcontent-c3], input[type="time"][_ngcontent-c3]:disabled, input[type="time"].disabled[_ngcontent-c3], input[type="url"][_ngcontent-c3]:disabled, input[type="url"].disabled[_ngcontent-c3], input[type="week"][_ngcontent-c3]:disabled, input[type="week"].disabled[_ngcontent-c3], input[_ngcontent-c3]:not([type]):disabled, input[_ngcontent-c3]:not([type]).disabled, textarea[_ngcontent-c3]:disabled, textarea.disabled[_ngcontent-c3], select[multiple][_ngcontent-c3]:disabled, select[multiple].disabled[_ngcontent-c3] {
#     opacity: 0.5;
#     cursor: not-allowed;
#     pointer-events: none; }
#     ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]:disabled:hover, ir-modal[_ngcontent-c3]   .disabled.newsletter-form[_ngcontent-c3]:hover, input[type="color"][_ngcontent-c3]:disabled:hover, input[type="color"].disabled[_ngcontent-c3]:hover, input[type="date"][_ngcontent-c3]:disabled:hover, input[type="date"].disabled[_ngcontent-c3]:hover, input[type="datetime"][_ngcontent-c3]:disabled:hover, input[type="datetime"].disabled[_ngcontent-c3]:hover, input[type="datetime-local"][_ngcontent-c3]:disabled:hover, input[type="datetime-local"].disabled[_ngcontent-c3]:hover, input[type="email"][_ngcontent-c3]:disabled:hover, input[type="email"].disabled[_ngcontent-c3]:hover, input[type="month"][_ngcontent-c3]:disabled:hover, input[type="month"].disabled[_ngcontent-c3]:hover, input[type="number"][_ngcontent-c3]:disabled:hover, input[type="number"].disabled[_ngcontent-c3]:hover, input[type="password"][_ngcontent-c3]:disabled:hover, input[type="password"].disabled[_ngcontent-c3]:hover, input[type="search"][_ngcontent-c3]:disabled:hover, input[type="search"].disabled[_ngcontent-c3]:hover, input[type="tel"][_ngcontent-c3]:disabled:hover, input[type="tel"].disabled[_ngcontent-c3]:hover, input[type="text"][_ngcontent-c3]:disabled:hover, input[type="text"].disabled[_ngcontent-c3]:hover, input[type="time"][_ngcontent-c3]:disabled:hover, input[type="time"].disabled[_ngcontent-c3]:hover, input[type="url"][_ngcontent-c3]:disabled:hover, input[type="url"].disabled[_ngcontent-c3]:hover, input[type="week"][_ngcontent-c3]:disabled:hover, input[type="week"].disabled[_ngcontent-c3]:hover, input[_ngcontent-c3]:not([type]):disabled:hover, input[_ngcontent-c3]:not([type]).disabled:hover, textarea[_ngcontent-c3]:disabled:hover, textarea.disabled[_ngcontent-c3]:hover, select[multiple][_ngcontent-c3]:disabled:hover, select[multiple].disabled[_ngcontent-c3]:hover {
#       box-shadow: 5px 5px 10px 0 rgba(46, 61, 73, 0.05); }
#   ir-modal[_ngcontent-c3]   .inline.newsletter-form[_ngcontent-c3], input[type="color"].inline[_ngcontent-c3], input[type="date"].inline[_ngcontent-c3], input[type="datetime"].inline[_ngcontent-c3], input[type="datetime-local"].inline[_ngcontent-c3], input[type="email"].inline[_ngcontent-c3], input[type="month"].inline[_ngcontent-c3], input[type="number"].inline[_ngcontent-c3], input[type="password"].inline[_ngcontent-c3], input[type="search"].inline[_ngcontent-c3], input[type="tel"].inline[_ngcontent-c3], input[type="text"].inline[_ngcontent-c3], input[type="time"].inline[_ngcontent-c3], input[type="url"].inline[_ngcontent-c3], input[type="week"].inline[_ngcontent-c3], input[_ngcontent-c3]:not([type]).inline, textarea.inline[_ngcontent-c3], select[multiple].inline[_ngcontent-c3] {
#     display: inline-block;
#     margin-right: 0.75rem; }
#     ir-modal[_ngcontent-c3]   .inline.newsletter-form[_ngcontent-c3]:last-child, input[type="color"].inline[_ngcontent-c3]:last-child, input[type="date"].inline[_ngcontent-c3]:last-child, input[type="datetime"].inline[_ngcontent-c3]:last-child, input[type="datetime-local"].inline[_ngcontent-c3]:last-child, input[type="email"].inline[_ngcontent-c3]:last-child, input[type="month"].inline[_ngcontent-c3]:last-child, input[type="number"].inline[_ngcontent-c3]:last-child, input[type="password"].inline[_ngcontent-c3]:last-child, input[type="search"].inline[_ngcontent-c3]:last-child, input[type="tel"].inline[_ngcontent-c3]:last-child, input[type="text"].inline[_ngcontent-c3]:last-child, input[type="time"].inline[_ngcontent-c3]:last-child, input[type="url"].inline[_ngcontent-c3]:last-child, input[type="week"].inline[_ngcontent-c3]:last-child, input[_ngcontent-c3]:not([type]).inline:last-child, textarea.inline[_ngcontent-c3]:last-child, select[multiple].inline[_ngcontent-c3]:last-child {
#       margin-right: 0; }
#     @media screen and (min-width: 48rem) {
#       ir-modal[_ngcontent-c3]   .inline.newsletter-form[_ngcontent-c3], input[type="color"].inline[_ngcontent-c3], input[type="date"].inline[_ngcontent-c3], input[type="datetime"].inline[_ngcontent-c3], input[type="datetime-local"].inline[_ngcontent-c3], input[type="email"].inline[_ngcontent-c3], input[type="month"].inline[_ngcontent-c3], input[type="number"].inline[_ngcontent-c3], input[type="password"].inline[_ngcontent-c3], input[type="search"].inline[_ngcontent-c3], input[type="tel"].inline[_ngcontent-c3], input[type="text"].inline[_ngcontent-c3], input[type="time"].inline[_ngcontent-c3], input[type="url"].inline[_ngcontent-c3], input[type="week"].inline[_ngcontent-c3], input[_ngcontent-c3]:not([type]).inline, textarea.inline[_ngcontent-c3], select[multiple].inline[_ngcontent-c3] {
#         margin-top: 0;
#         margin-bottom: 0; } }
#   @media screen and (min-width: 48rem) and (min-width: 48rem) {
#     ir-modal[_ngcontent-c3]   .inline.newsletter-form[_ngcontent-c3], input[type="color"].inline[_ngcontent-c3], input[type="date"].inline[_ngcontent-c3], input[type="datetime"].inline[_ngcontent-c3], input[type="datetime-local"].inline[_ngcontent-c3], input[type="email"].inline[_ngcontent-c3], input[type="month"].inline[_ngcontent-c3], input[type="number"].inline[_ngcontent-c3], input[type="password"].inline[_ngcontent-c3], input[type="search"].inline[_ngcontent-c3], input[type="tel"].inline[_ngcontent-c3], input[type="text"].inline[_ngcontent-c3], input[type="time"].inline[_ngcontent-c3], input[type="url"].inline[_ngcontent-c3], input[type="week"].inline[_ngcontent-c3], input[_ngcontent-c3]:not([type]).inline, textarea.inline[_ngcontent-c3], select[multiple].inline[_ngcontent-c3] {
#       margin-bottom: 0; } }
#
# fieldset[_ngcontent-c3] {
#   margin-top: 0;
#   margin-bottom: 0.75rem;
#   border: 0;
#   padding: 0;
#   background-color: transparent; }
#   @media screen and (min-width: 48rem) {
#     fieldset[_ngcontent-c3] {
#       margin-bottom: 1.5rem; } }
#
# legend[_ngcontent-c3] {
#   margin-top: 0;
#   margin-bottom: 0.75rem;
#   padding: 0; }
#   @media screen and (min-width: 48rem) {
#     legend[_ngcontent-c3] {
#       margin-bottom: 1.5rem; } }
#
# label[_ngcontent-c3] {
#   margin-top: 0;
#   margin-bottom: 0.75rem;
#   display: block; }
#   @media screen and (min-width: 48rem) {
#     label[_ngcontent-c3] {
#       margin-bottom: 1.5rem; } }
#
# textarea[_ngcontent-c3] {
#   padding: 0.6875rem 1.25rem; }
#
# input[type="number"][_ngcontent-c3] {
#   -moz-appearance: textfield; }
#
# input[_ngcontent-c3]::-webkit-outer-spin-button, input[_ngcontent-c3]::-webkit-inner-spin-button {
#   -webkit-appearance: none; }
#
# [type="search"][_ngcontent-c3] {
#   appearance: none; }
#
# [type="radio"][_ngcontent-c3] {
#   display: inline;
#   margin-right: 0.75rem; }
#
# [type="file"][_ngcontent-c3] {
#   margin-top: 0;
#   margin-bottom: 0.75rem;
#   width: 100%; }
#   @media screen and (min-width: 48rem) {
#     [type="file"][_ngcontent-c3] {
#       margin-bottom: 1.5rem; } }
#
# select[_ngcontent-c3] {
#   margin-top: 0;
#   margin-bottom: 0.75rem;
#   max-width: 100%;
#   width: auto; }
#   @media screen and (min-width: 48rem) {
#     select[_ngcontent-c3] {
#       margin-bottom: 1.5rem; } }
#
# .checkbox[_ngcontent-c3] {
#   position: relative; }
#   .checkbox[_ngcontent-c3]   input[type=checkbox][_ngcontent-c3] {
#     display: none !important; }
#     .checkbox[_ngcontent-c3]   input[type=checkbox][_ngcontent-c3]:checked    + label[_ngcontent-c3]::after {
#       background-size: 60%;
#       opacity: 1; }
#     .checkbox[_ngcontent-c3]   input[type=checkbox][_ngcontent-c3]:disabled    + label[_ngcontent-c3] {
#       opacity: .5; }
#   .checkbox[_ngcontent-c3]   label[_ngcontent-c3] {
#     font-size: 0.8125rem;
#     line-height: 1.5rem;
#     margin-top: 0;
#     margin-bottom: 0.75rem;
#     clear: left;
#     display: block;
#     position: relative;
#     color: #7d97ad;
#     letter-spacing: 0.0625rem;
#     text-transform: uppercase;
#     padding-left: 1.5rem; }
#     @media screen and (min-width: 48rem) {
#       .checkbox[_ngcontent-c3]   label[_ngcontent-c3] {
#         font-size: 0.8125rem;
#         line-height: 1.5rem; } }
#     @media screen and (min-width: 48rem) {
#       .checkbox[_ngcontent-c3]   label[_ngcontent-c3] {
#         margin-bottom: 0.75rem; } }
#     .checkbox[_ngcontent-c3]   label[_ngcontent-c3]   a[_ngcontent-c3] {
#       color: #7d97ad;
#       text-decoration: none;
#       border-bottom: 1px solid #91daee;
#       transition: color 0.3s ease; }
#       .checkbox[_ngcontent-c3]   label[_ngcontent-c3]   a[_ngcontent-c3]:hover {
#         color: #9db0c0; }
#     .checkbox[_ngcontent-c3]   label[_ngcontent-c3]::before, .checkbox[_ngcontent-c3]   label[_ngcontent-c3]::after {
#       content: '';
#       position: absolute;
#       top: 4px;
#       left: 0;
#       width: 16px;
#       height: 16px;
#       background: white;
#       border: 1px solid #dbe2e8;
#       box-shadow: 0 2px 5px 0 rgba(46, 61, 73, 0.08); }
#     .checkbox[_ngcontent-c3]   label[_ngcontent-c3]::after {
#       opacity: 0;
#       background-size: 20%;
#       background: image-url("svgs/check_blue.svg") no-repeat center;
#       transition: opacity 0.3s ease, background-size 0.3s ease; }
#
# input.form-error[_ngcontent-c3], select.form-error[_ngcontent-c3], textarea.form-error[_ngcontent-c3] {
#   color: #f95c3c;
#   background-color: rgba(249, 92, 60, 0.02);
#   border: 1px solid #f04546; }
#
# .error-container[_ngcontent-c3] {
#   height: 2.25rem;
#   position: absolute;
#   left: 0;
#   right: 0;
#   width: 90%;
#   margin: 0 auto;
#   display: block;
#   text-align: center;
#   top: -3rem;
#   background-color: #f04546;
#   border-radius: 0.25rem;
#   transition: all 0.3s ease;
#   opacity: 0; }
#   .error-container.filled[_ngcontent-c3] {
#     transition: all 0.3s ease;
#     opacity: 1; }
#   .error-container[_ngcontent-c3]:after {
#     content: '';
#     width: 0;
#     height: 0;
#     top: 18px;
#     position: relative;
#     border-style: solid;
#     border-width: 8px 6px 0;
#     border-color: #f04546 transparent transparent; }
#
# .error-text[_ngcontent-c3] {
#   font-size: 0.75rem;
#   line-height: 1.5rem;
#   position: relative;
#   top: 50%;
#   -webkit-transform: translateY(-50%);
#   -moz-transform: translateY(-50%);
#   -ms-transform: translateY(-50%);
#   -o-transform: translateY(-50%);
#   transform: translateY(-50%);
#   color: #fff;
#   display: block;
#   text-align: center; }
#   @media screen and (min-width: 48rem) {
#     .error-text[_ngcontent-c3] {
#       font-size: 0.75rem;
#       line-height: 1.5rem; } }
#
# button[_ngcontent-c3], input[type="button"][_ngcontent-c3], input[type="reset"][_ngcontent-c3], input[type="submit"][_ngcontent-c3], .button[_ngcontent-c3], .button--primary[_ngcontent-c3], .button--secondary[_ngcontent-c3], .button--outline[_ngcontent-c3], .button--white[_ngcontent-c3], .button--navigation[_ngcontent-c3], .button--turquoise[_ngcontent-c3], .button--team[_ngcontent-c3], ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]   #newsletter-signup-btn[_ngcontent-c3] {
#   display: block;
#   cursor: pointer;
#   appearance: none;
#   user-select: none;
#   text-align: center;
#   white-space: nowrap;
#   vertical-align: top;
#   text-decoration: none;
#   vertical-align: middle;
#   height: 3rem;
#   padding: 0 0.5rem;
#   text-transform: uppercase;
#   font-size: 16px;
#   font-weight: 600;
#   font-size: 0.8125rem;
#   line-height: 2.625rem;
#   -webkit-font-smoothing: antialiased;
#   border-radius: 0.25rem;
#   letter-spacing: 0.125rem;
#   transition: all 0.3s ease; }
#
# .button--primary[_ngcontent-c3], .button--secondary[_ngcontent-c3], .button--outline[_ngcontent-c3], .button--white[_ngcontent-c3], ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]   #newsletter-signup-btn[_ngcontent-c3] {
#   box-shadow: 8px 10px 20px 0px rgba(46, 61, 73, 0.15); }
#   .button--primary[_ngcontent-c3]:hover, .button--secondary[_ngcontent-c3]:hover, .button--outline[_ngcontent-c3]:hover, .button--white[_ngcontent-c3]:hover, ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]   #newsletter-signup-btn[_ngcontent-c3]:hover {
#     box-shadow: 2px 4px 8px 0px rgba(46, 61, 73, 0.2); }
#
# .button--primary[_ngcontent-c3] {
#   width: 13.75rem;
#   color: #fff;
#   background-color: #02b3e4;
#   border: 0.125rem solid transparent; }
#   .button--primary[_ngcontent-c3]:focus, .button--primary.focus[_ngcontent-c3], .button--primary[_ngcontent-c3]:hover {
#     outline: none;
#     color: white;
#     border-color: transparent;
#     background-color: #029fcb; }
#   .button--primary.disabled[_ngcontent-c3], .button--primary[disabled][_ngcontent-c3], fieldset[disabled][_ngcontent-c3]   .button--primary[_ngcontent-c3] {
#     box-shadow: none;
#     cursor: not-allowed;
#     border-color: #dbe2e8;
#     background-color: #dbe2e8; }
#   .button--primary.pending[_ngcontent-c3] {
#     cursor: progress;
#     box-shadow: none; }
#     .button--primary.pending[_ngcontent-c3]:hover {
#       background-color: #02b3e4; }
#   .button--primary.inline[_ngcontent-c3] {
#     display: inline-block; }
#   .button--primary.sm[_ngcontent-c3] {
#     width: 11.25rem; }
#   .button--primary.lg[_ngcontent-c3] {
#     width: 17.5rem; }
#     @media screen and (max-width: 20rem) {
#       .button--primary.lg[_ngcontent-c3] {
#         width: 100%; } }
#   .button--primary.full[_ngcontent-c3] {
#     width: 100%; }
#   .button--primary[_ngcontent-c3]    > svg[_ngcontent-c3] {
#     fill: currentcolor; }
#
# .button--secondary[_ngcontent-c3] {
#   width: 13.75rem;
#   color: #fff;
#   background-color: #7d97ad;
#   border: 0.125rem solid transparent; }
#   .button--secondary[_ngcontent-c3]:focus, .button--secondary.focus[_ngcontent-c3], .button--secondary[_ngcontent-c3]:hover {
#     outline: none;
#     color: white;
#     border-color: transparent;
#     background-color: #6d8aa3; }
#   .button--secondary.disabled[_ngcontent-c3], .button--secondary[disabled][_ngcontent-c3], fieldset[disabled][_ngcontent-c3]   .button--secondary[_ngcontent-c3] {
#     box-shadow: none;
#     cursor: not-allowed;
#     border-color: #dbe2e8;
#     background-color: #dbe2e8; }
#   .button--secondary.pending[_ngcontent-c3] {
#     cursor: progress;
#     box-shadow: none; }
#     .button--secondary.pending[_ngcontent-c3]:hover {
#       background-color: #7d97ad; }
#   .button--secondary.inline[_ngcontent-c3] {
#     display: inline-block; }
#   .button--secondary.sm[_ngcontent-c3] {
#     width: 11.25rem; }
#   .button--secondary.lg[_ngcontent-c3] {
#     width: 17.5rem; }
#     @media screen and (max-width: 20rem) {
#       .button--secondary.lg[_ngcontent-c3] {
#         width: 100%; } }
#   .button--secondary.full[_ngcontent-c3] {
#     width: 100%; }
#   .button--secondary[_ngcontent-c3]    > svg[_ngcontent-c3] {
#     fill: currentcolor; }
#
# .button--outline[_ngcontent-c3] {
#   width: 13.75rem;
#   color: #fff;
#   background-color: transparent;
#   border: 0.125rem solid #fff; }
#   .button--outline[_ngcontent-c3]:focus, .button--outline.focus[_ngcontent-c3], .button--outline[_ngcontent-c3]:hover {
#     outline: none;
#     color: white;
#     border-color: #fff;
#     background-color: transparent; }
#   .button--outline.disabled[_ngcontent-c3], .button--outline[disabled][_ngcontent-c3], fieldset[disabled][_ngcontent-c3]   .button--outline[_ngcontent-c3] {
#     box-shadow: none;
#     cursor: not-allowed;
#     border-color: #dbe2e8;
#     background-color: #dbe2e8; }
#   .button--outline.pending[_ngcontent-c3] {
#     cursor: progress;
#     box-shadow: none; }
#     .button--outline.pending[_ngcontent-c3]:hover {
#       background-color: transparent; }
#   .button--outline.inline[_ngcontent-c3] {
#     display: inline-block; }
#   .button--outline.sm[_ngcontent-c3] {
#     width: 11.25rem; }
#   .button--outline.lg[_ngcontent-c3] {
#     width: 17.5rem; }
#     @media screen and (max-width: 20rem) {
#       .button--outline.lg[_ngcontent-c3] {
#         width: 100%; } }
#   .button--outline.full[_ngcontent-c3] {
#     width: 100%; }
#   .button--outline[_ngcontent-c3]    > svg[_ngcontent-c3] {
#     fill: currentcolor; }
#
# .button--white[_ngcontent-c3] {
#   width: 13.75rem;
#   color: #02b3e4;
#   background-color: #fff;
#   border: 0.125rem solid transparent; }
#   .button--white[_ngcontent-c3]:focus, .button--white.focus[_ngcontent-c3], .button--white[_ngcontent-c3]:hover {
#     outline: none;
#     color: #1cccfd;
#     border-color: transparent;
#     background-color: #f2f2f2; }
#   .button--white.disabled[_ngcontent-c3], .button--white[disabled][_ngcontent-c3], fieldset[disabled][_ngcontent-c3]   .button--white[_ngcontent-c3] {
#     box-shadow: none;
#     cursor: not-allowed;
#     border-color: #dbe2e8;
#     background-color: #dbe2e8; }
#   .button--white.pending[_ngcontent-c3] {
#     cursor: progress;
#     box-shadow: none; }
#     .button--white.pending[_ngcontent-c3]:hover {
#       background-color: #fff; }
#   .button--white.inline[_ngcontent-c3] {
#     display: inline-block; }
#   .button--white.sm[_ngcontent-c3] {
#     width: 11.25rem; }
#   .button--white.lg[_ngcontent-c3] {
#     width: 17.5rem; }
#     @media screen and (max-width: 20rem) {
#       .button--white.lg[_ngcontent-c3] {
#         width: 100%; } }
#   .button--white.full[_ngcontent-c3] {
#     width: 100%; }
#   .button--white[_ngcontent-c3]    > svg[_ngcontent-c3] {
#     fill: currentcolor; }
#
# .button--navigation[_ngcontent-c3] {
#   color: #fff;
#   background-color: transparent;
#   border: 0.125rem solid transparent; }
#   .button--navigation[_ngcontent-c3]:focus, .button--navigation.focus[_ngcontent-c3], .button--navigation[_ngcontent-c3]:hover {
#     outline: none;
#     color: white;
#     border-color: transparent;
#     background-color: transparent; }
#   .button--navigation.disabled[_ngcontent-c3], .button--navigation[disabled][_ngcontent-c3], fieldset[disabled][_ngcontent-c3]   .button--navigation[_ngcontent-c3] {
#     box-shadow: none;
#     cursor: not-allowed;
#     border-color: #dbe2e8;
#     background-color: #dbe2e8; }
#   .button--navigation.pending[_ngcontent-c3] {
#     cursor: progress;
#     box-shadow: none; }
#     .button--navigation.pending[_ngcontent-c3]:hover {
#       background-color: transparent; }
#   .button--navigation.inline[_ngcontent-c3] {
#     display: inline-block; }
#   .button--navigation.sm[_ngcontent-c3] {
#     width: 11.25rem; }
#   .button--navigation.lg[_ngcontent-c3] {
#     width: 17.5rem; }
#     @media screen and (max-width: 20rem) {
#       .button--navigation.lg[_ngcontent-c3] {
#         width: 100%; } }
#   .button--navigation.full[_ngcontent-c3] {
#     width: 100%; }
#   .button--navigation[_ngcontent-c3]    > svg[_ngcontent-c3] {
#     fill: currentcolor; }
#
# .button--turquoise[_ngcontent-c3] {
#   color: #fff;
#   background-color: #02ccba;
#   border: 0.125rem solid transparent; }
#   .button--turquoise[_ngcontent-c3]:focus, .button--turquoise.focus[_ngcontent-c3], .button--turquoise[_ngcontent-c3]:hover {
#     outline: none;
#     color: white;
#     border-color: transparent;
#     background-color: #02b3a3; }
#   .button--turquoise.disabled[_ngcontent-c3], .button--turquoise[disabled][_ngcontent-c3], fieldset[disabled][_ngcontent-c3]   .button--turquoise[_ngcontent-c3] {
#     box-shadow: none;
#     cursor: not-allowed;
#     border-color: #dbe2e8;
#     background-color: #dbe2e8; }
#   .button--turquoise.pending[_ngcontent-c3] {
#     cursor: progress;
#     box-shadow: none; }
#     .button--turquoise.pending[_ngcontent-c3]:hover {
#       background-color: #02ccba; }
#   .button--turquoise.inline[_ngcontent-c3] {
#     display: inline-block; }
#   .button--turquoise.sm[_ngcontent-c3] {
#     width: 11.25rem; }
#   .button--turquoise.lg[_ngcontent-c3] {
#     width: 17.5rem; }
#     @media screen and (max-width: 20rem) {
#       .button--turquoise.lg[_ngcontent-c3] {
#         width: 100%; } }
#   .button--turquoise.full[_ngcontent-c3] {
#     width: 100%; }
#   .button--turquoise[_ngcontent-c3]    > svg[_ngcontent-c3] {
#     fill: currentcolor; }
#
# .button--team[_ngcontent-c3] {
#   color: #2e3d49;
#   background-color: transparent;
#   border: 0.125rem solid transparent; }
#   .button--team[_ngcontent-c3]:focus, .button--team.focus[_ngcontent-c3], .button--team[_ngcontent-c3]:hover {
#     outline: none;
#     color: #425768;
#     border-color: transparent;
#     background-color: transparent; }
#   .button--team.disabled[_ngcontent-c3], .button--team[disabled][_ngcontent-c3], fieldset[disabled][_ngcontent-c3]   .button--team[_ngcontent-c3] {
#     box-shadow: none;
#     cursor: not-allowed;
#     border-color: #dbe2e8;
#     background-color: #dbe2e8; }
#   .button--team.pending[_ngcontent-c3] {
#     cursor: progress;
#     box-shadow: none; }
#     .button--team.pending[_ngcontent-c3]:hover {
#       background-color: transparent; }
#   .button--team.inline[_ngcontent-c3] {
#     display: inline-block; }
#   .button--team.sm[_ngcontent-c3] {
#     width: 11.25rem; }
#   .button--team.lg[_ngcontent-c3] {
#     width: 17.5rem; }
#     @media screen and (max-width: 20rem) {
#       .button--team.lg[_ngcontent-c3] {
#         width: 100%; } }
#   .button--team.full[_ngcontent-c3] {
#     width: 100%; }
#   .button--team[_ngcontent-c3]    > svg[_ngcontent-c3] {
#     fill: currentcolor; }
#
# [_nghost-c3] {
#   display: block; }
#
# .hidden[_ngcontent-c3] {
#   display: none; }
#
# ir-modal[_ngcontent-c3]   header[_ngcontent-c3] {
#   text-align: center; }
#   ir-modal[_ngcontent-c3]   header[_ngcontent-c3]   img[_ngcontent-c3] {
#     margin-bottom: 1rem; }
#
# ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3] {
#   height: auto;
#   border: none;
#   box-shadow: none; }
#   ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]:hover {
#     box-shadow: none; }
#   ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]   fieldset[_ngcontent-c3] {
#     margin: 0; }
#     ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]   fieldset[_ngcontent-c3]::after {
#       clear: both;
#       content: "";
#       display: table; }
#   ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]   label[_ngcontent-c3] {
#     text-align: left;
#     color: #2e3d49; }
#   ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]   .personal[_ngcontent-c3] {
#     margin-top: 2rem; }
#   ir-modal[_ngcontent-c3]   .newsletter-form[_ngcontent-c3]   .mailing-lists[_ngcontent-c3] {
#     border-radius: 0.25rem;
#     margin-top: 1rem;
#     margin-bottom: 1rem;
#     border: 1px solid #dbe2e8;
#     padding: 2rem;
#     box-shadow: 5px 5px 10px 0 rgba(46, 61, 73, 0.05); }
# ...
#
# Em colaboração com: Facebook
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  App Marketing
#
#
#
#
#
#
#
#
# intermediário
#
#
#
# This course will help you organize a strategy of identifying your perfect user, and teach you how to grow your user base by focusing your product on their needs.
#
# Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Rapid Prototyping
#
# New
#
#
#
#
#
#
# intermediário
#
#
#
# Learning to prototype will save you time and money in the development process. You’ll create quality apps faster and have confidence in the viability of your products.
#
# Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Deep Learning
#
# New
#
#
#
#
#
#
# avançado
#
#
#
# Vamos mostrar-lhe como treinar e otimizar redes neurais básicas, redes neurais convolucionais e redes longas de memória de curto prazo.
#
# Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  CSE 8803 Special Topics: Big Data
#
# New
#
#
#
#
#
#
# avançado
#
#
#
# In this course, we introduce the characteristics of medical data and associated data mining challenges on dealing with such data. We cover various algorithms and systems.
#
# Em colaboração com: Georgia Tech
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Xcode Debugging
#
#
#
#
#
#
#
#
# avançado
#
#
#
# In this course, you'll learn standard methodologies for debugging software, and how to use Xcode's debugging tools to find and squash bugs.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Como Usar o Git e o GitHub
#
#
#
#
#
#
#
#
# beginner
#
#
#
# Aprenda a usar o controle de versão, uma ferramenta importante para qualquer desenvolvedor. O curso se concentrará no Git, um sistema específico de controle de versão, e GitHub, uma plataforma de colaboração.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Writing READMEs
#
# New
#
#
#
#
#
#
# beginner
#
#
#
# Documentation is an important part of the development process. Learn to write READMEs using Markdown so your code can be used by other humans!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  UIKit Fundamentals
#
#
#
#
#
#
#
#
# intermediário
#
#
#
# Learn the iOS UIKit framework, which is the cornerstone of creating user interfaces in all iOS apps and crucial for any iOS Developer to be intimately familiar with.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Introdução à JavaScript
#
# New
#
#
#
#
#
#
# iniciante
#
#
#
# Learn the fundamentals of JavaScript, the most popular programming language in web development.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Software Development Process
#
#
#
#
#
#
#
#
# intermediário
#
#
#
# Software Development Processes explores requirements engineering, architecture and design, testing, and software quality in general.
#
# Em colaboração com: Georgia Institute of Technology
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Get Your Startup Started
#
# New
#
#
#
#
#
#
# intermediário
#
#
#
# Acquire the know-how necessary to see your business grow towards its next milestone.
#
# Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Health Informatics in the Cloud
#
#
#
#
#
#
#
#
# beginner
#
#
#
# This survey course provides a broad, forward-facing overview of contemporary health informatics within the context of the US healthcare delivery system.
#
# Em colaboração com: Georgia Institute of Technology
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Introduction to Computer Vision
#
#
#
#
#
#
#
#
# intermediário
#
#
#
# This course provides an introduction to computer vision including fundamentals, methods for application and machine learning classification.
#
# Em colaboração com: Georgia Institute of Technology
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Intro to Progressive Web Apps
#
# New
#
#
#
#
#
#
# intermediário
#
#
#
# In this course you’ll get started working on your very first Progressive Web App - a web app that can take advantage of many features native applications have enjoyed!
#
# Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Software Architecture & Design
#
#
#
#
#
#
#
#
# intermediário
#
#
#
# Software Architecture and Design teaches the principles and concepts involved in the analysis and design of large software systems.
#
# Em colaboração com: Georgia Institute of Technology
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Android Performance
#
#
#
#
#
#
#
#
# avançado
#
#
#
# Performance matters to users, so it must matter to you. Learn how to identify and fix bottlenecks in your Android applications, and ensure a smooth user experience.
#
# Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Introdução à Estatística Descritiva
#
#
#
#
#
#
#
#
# beginner
#
#
#
# Introdução à Estatística Descritiva vai te ensinar os conceitos básicos de estatísticas que podem ser usadas para extrair informações de dados.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Introduction to Health Informatics
#
#
#
#
#
#
#
#
#
# This survey course provides a broad, forward-facing overview of contemporary health informatics within the context of the US healthcare delivery system.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Android Basics: User Input
#
#
#
#
#
#
#
#
# beginner
#
#
#
# Learn how to make your apps interactive using buttons and text! In this course you'll learn the basics of the Java programming language and how to apply them to Android.
#
# Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Desenvolvimento Android para Iniciantes
#
#
#
#
#
#
#
#
# beginner
#
#
#
# Aprenda os conceitos básicos de Android e programação Java, e dê o primeiro passo em sua jornada para se tornar um desenvolvedor Android!
#
# Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Android Basics: Multi-screen Apps
#
# New
#
#
#
#
#
#
# beginner
#
#
#
# Learn to build multiscreen apps using the foundation of Android for Beginners!
#
# Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Android Basics: Networking
#
# New
#
#
#
#
#
#
# beginner
#
#
#
# This class teaches the basics of networking using Android, and is a part of the Android Basics Nanodegree by Google.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Android Basics: Data Storage
#
# New
#
#
#
#
#
#
# beginner
#
#
#
# In this course, you'll learn the basics of data storage in Andriod, building your first database and an app that could be used for any small business!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Desenvolvendo Apps Android
#
#
#
#
#
#
#
#
# intermediário
#
#
#
# Construa um app Android conectado à nuvem, e aprenda as ferramentas, princípios e melhores práticas de desenvolvimento móvel e Android que você vai aplicar aos seus próprios projetos.
#
# Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  New Android Fundamentals
#
#
#
#
#
#
#
#
# intermediário
#
#
#
# Build a cloud-connected Android app, and learn the tools, principles, and best practices of mobile and Android development that you'll apply to your own projects.
#
# Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Desenvolvendo Apps Android
#
#
#
#
#
#
#
#
# intermediário
#
#
#
# Construa um app Android conectado à nuvem, e aprenda as ferramentas, princípios e melhores práticas de desenvolvimento móvel e Android que você vai aplicar aos seus próprios projetos.
#
# Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Desenvolvendo Apps Android
#
#
#
#
#
#
#
#
# intermediário
#
#
#
# Construa um app Android conectado à nuvem, e aprenda as ferramentas, princípios e melhores práticas de desenvolvimento móvel e Android que você vai aplicar aos seus próprios projetos.
#
# Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Desenvolvimento de Apps Android Avançado
#
#
#
#
#
#
#
#
# avançado
#
#
#
# Prepare seu app para produção aplicando recursos avançados como integração de biblioteca, material design, widgets, recebimento de mensagens da nuvem e mais!
#
# Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Developing Scalable Apps in Java
#
#
#
#
#
#
#
#
# avançado
#
#
#
# You will learn about challenges of building applications that can serve hundreds of thousands of users, and how you can prepare for them as a developer.
#
# Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Otimização de Renderização no Browser
#
#
#
#
#
#
#
#
# avançado
#
#
#
# Este curso irá desmistificar o pipeline de processamento do navegador e tornar fácil a construção de aplicações web de alta performance.
#
# Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Material Design para Desenvolvedores Android
#
#
#
#
#
#
#
#
# intermediário
#
#
#
# Aprenda e aplique os princípios do material design que definem a linguagem visual dos seus apps.
#
# Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Google Maps APIs
#
# New
#
#
#
#
#
#
# intermediário
#
#
#
# This course will introduce you to the content available through the Google Maps APIs through building a real-estate listings web application step-by-step.
#
# Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Gradle para Android e Java
#
#
#
#
#
#
#
#
# avançado
#
#
#
# Construa Apps Android e Java Maiores e Melhores Usando a Ferramenta de Compilação Gradle.
#
# Em colaboração com: Google Gradle
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Android TV e Desenvolvimento Google Cast
#
#
#
#
#
#
#
#
# avançado
#
#
#
# Vá onde os usuários são: a sala de estar! Este curso mostra como estender seu aplicativo Android já existente para também trabalhar no Android TV, e/ou com o Google Cast.
#
# Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Desenvolvimento Android Auto
#
#
#
#
#
#
#
#
# avançado
#
#
#
# Alcançe seus usuários, enquanto eles estão por dirigindo, estendendo os seus aplicativos de mídia ou mensagens para o Android Auto!
#
# Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Google Location Services on Android
#
#
#
#
#
#
#
#
# intermediário
#
#
#
# Enhance your apps with Google's Fused Location Provider, Activity Recognition, and Geofencing API capabilities.
#
# Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Monetize Your Android App with Ads
#
#
#
#
#
#
#
#
# intermediário
#
#
#
# Learn how to monetize apps using Google's AdMob to display banner and interstitial ads!
#
# Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Add Google Maps to your Android App
#
#
#
#
#
#
#
#
# intermediário
#
#
#
# Maps on mobile devices have changed the world for millions of users. Learn how to use the Google Maps API to extend this functionality to your apps.
#
# Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Imagens Responsivas
#
#
#
#
#
#
#
#
# intermediário
#
#
#
# Vá além das tags de imagem! Aprenda como incluir imagens no fluxo de trabalho de projetos responsivos.
#
# Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Otimização de Performance de Website
#
#
#
#
#
#
#
#
# intermediário
#
#
#
# Aprenda como browsers convertem HTML, CSS e JavaScript em websites enquanto faz testes com o Chrome Developer Tools para medir e otimizar a velocidade de websites!
#
# Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Building High Conversion Web Forms
#
# New
#
#
#
#
#
#
# intermediário
#
#
#
# Increase conversions with best practices for fast, efficient forms! Learn how to design and build web forms for users on any device.
#
# Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Web Accessibility
#
# New
#
#
#
#
#
#
# avançado
#
#
#
# Get hands-on experience making web applications accessible. You’ll understand when and why users need accessibility, then you’ll dive into how to implement.
#
# Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Web Tooling & Automation
#
# New
#
#
#
#
#
#
# intermediário
#
#
#
# In this course, you’ll learn how to setup your development environment and save a lot of time and effort with automatic optimization.
#
# Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Fundamentos do Design Responsivo para a Web
#
#
#
#
#
#
#
#
# intermediário
#
#
#
# Aprenda e pratique estratégias para o desenvolvimento de websites que se adaptam a todos os dispositivos! Desenvolvido com Pete LePage do Google.
#
# Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Front End Frameworks
#
# New
#
#
#
#
#
#
# avançado
#
#
#
# Explore and build interactive, single-page applications with popular JavaScript frameworks!
#
# Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Client-Server Communication
#
# New
#
#
#
#
#
#
# avançado
#
#
#
# Learn how a client communicates with a server, including HTTP's request and response cycle, HTTP/2 and HTTPs.
#
# Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  JavaScript Promises
#
# New
#
#
#
#
#
#
# avançado
#
#
#
# Learn how to simplify asynchronous work with Native JavaScript Promises!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Offline Web Applications
#
# New
#
#
#
#
#
#
# intermediário
#
#
#
# Learn how to develop offline-first web application using Service Workers and IndexedDB.
#
# Em colaboração com: Google
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Learn Swift Programming Syntax
#
# New
#
#
#
#
#
#
# intermediário
#
#
#
# This course focuses on the syntax of the Swift programming language. By the end of the course, you'll be able to apply Swift essentials to building iOS apps.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Educational Technology
#
#
#
#
#
#
#
#
# beginner
#
#
#
# This class is an an introductory course about educational technology offered as CS6460 at Georgia Tech where it is a part of the Online Masters Degree (OMS).
#
# Em colaboração com: Georgia Institute of Technology
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Model Building and Validation
#
#
#
#
#
#
#
#
# avançado
#
#
#
# This course will teach you how to start from scratch in understanding and paying attention to what is important in the data and how to answer questions about data
#
# Em colaboração com: AT&T
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Introduction to Operating Systems
#
#
#
#
#
#
#
#
# intermediário
#
#
#
# Introduction to Operating Systems teaches the basic operating system abstractions, mechanisms, and their implementations.
#
# Em colaboração com: Georgia Institute of Technology
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Linear Algebra Refresher Course
#
#
#
#
#
#
#
#
# intermediário
#
#
#
# Learn linear algebra by doing: you will code your own library of linear algebra functions!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Computational Photography
#
#
#
#
#
#
#
#
# intermediário
#
#
#
# This class explores how computation impacts the entire workflow of photography, which is traditionally aimed at capturing light from a 3D scene to form a 2D image.
#
# Em colaboração com: Georgia Institute of Technology
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Problem Solving with Advanced Analytics
#
#
#
#
#
#
#
#
# beginner
#
#
#
# Learn a scientific approach to solving problems with data, a foundational skill for anyone interested in making data driven decisions in a business context.
#
# Em colaboração com: Alteryx
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Creating an Analytical Dataset
#
#
#
#
#
#
#
#
# beginner
#
#
#
# Learn how to prepare data to ensure the efficacy of your analysis while improving fluency in Alteryx.
#
# Em colaboração com: Alteryx
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  A/B Testing for Business Analysts
#
#
#
#
#
#
#
#
# intermediário
#
#
#
# The A/B Testing course provides students with the foundational knowledge to design and analyze A/B tests to create business insights and support decision making.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Time Series Forecasting
#
#
#
#
#
#
#
#
# intermediário
#
#
#
# The Time Series Forecasting course provides students with the foundational knowledge to build and apply time series forecasting models in a variety of business contexts.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Segmentation and Clustering
#
#
#
#
#
#
#
#
# intermediário
#
#
#
# The Segmentation & Clustering course provides students with the knowledge to build and apply clustering models to develop sophisticated segmentation in business contexts.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  JavaScript Design Patterns
#
#
#
#
#
#
#
#
# avançado
#
#
#
# Saiba a importância da organização de código e como implementá-lo com qualquer JavaScript padrão, biblioteca ou framework.
#
#
#
#
#
#
#
#
#
# Please waitLoading…
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Programas Nanodegree em destaque
#
#
# Data Science para Negócios
#
# Desenvolvedor Android
#
# Desenvolvedor de Realidade Virtual
#
# Desenvolvedor Web Front-End
#
# Engenheiro de Inteligência Artificial
#
# Engenheiro de Machine Learning
#
# Fundamentos de Data Science I
#
# Fundamentos de Data Science II
#
# Fundamentos de Deep Learning
#
#
#
#
#
#
# Aprenda com a Udacity
#
#
# Introdução à Programação
#
# Xcode Debugging
#
# Aprenda JavaScript
#
# Como criar um aplicativo iOS
#
# Introdução ao HTML e CSS
#
# Desenvolvimento de Software VR
#
# JavaScript Orientado a Objetos
#
# Desenvolvendo Apps Android
#
# Introdução à Análise de Dados
#
#
#
#
#
#
#
# Recursos para estudantes
#
#
# Catálogo
#
# Histórias de Sucesso
#
#
# Empresas
#
#
# Udacity para Empresas
#
# Recrute graduados
#
#
#
#
#
# Udacity
#
#
# Sobre
#
# Imprensa
#
# Eventos
#
# Blog
#
# Vagas
#
# Georgia Tech (Inglês)
#
# App Android
#
# App iOs
#
#
#
#
#
#
# Consulta
#
#
# Central de Ajuda
#
# Entre em contato
#
# Status do serviço
#
# Política de Privacidade
#
# Termos de Uso
#
#
#
#
#
#
#
#
#
#
#
# © 2011–2017 Udacity, Inc.
#
#
#
#
# Mapa do site
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Nanodegree é marca registrada da Udacity © 2011–2017 Udacity, Inc.
# A Udacity é uma empresa de tecnologia em educação que oferece cursos online em seu website, não se tratando de uma universidade no sentido tradicional da palavra.
# /opt/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /opt/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
# Find all course summaries
summaries = soup.find_all("div", class_="course-summary-card")
summaries[0]
# Out:
# <div _ngcontent-c114="" class="course-summary-card row row-gap-medium">
# <div _ngcontent-c114="" class="col-sm-3">
# <div _ngcontent-c114="" class="row">
# <div _ngcontent-c114="" class="col-xs-8 col-xs-offset-2 col-sm-12 col-sm-offset-0">
# <a _ngcontent-c114="" href="/course/intro-to-programming-nanodegree--nd000">
# <img _ngcontent-c114="" alt="Aprenda a programar" class="img-responsive img-bordered center-block" height="170" src="/assets/images/shared/nd-cards/nd000@2x.jpg" width="290"/>
# </a>
# </div>
# </div>
# </div>
# <div _ngcontent-c114="" class="col-sm-9">
# <div _ngcontent-c114="" class="row">
# <div _ngcontent-c114="" class="col-sm-8">
# <h3 _ngcontent-c114="" class="h-slim">
# <a _ngcontent-c114="" href="/course/intro-to-programming-nanodegree--nd000"> Aprenda a programar</a>
# <span _ngcontent-c114="" class="badges">
# <!-- -->
# </span>
# </h3>
# </div>
# <div _ngcontent-c114="" class="col-sm-4 hidden-xs">
# <!-- --><span _ngcontent-c114="" class="caption text-right">
# <span _ngcontent-c114="" class="icon-level course-info-bar-icon icon-level-beginner" classname="icon-level course-info-bar-icon icon-level-beginner" data-course-level-icon=""></span>
# <span _ngcontent-c114="" data-course-level-label="">iniciante</span>
# </span>
# </div>
# </div>
# <div _ngcontent-c114=""><span _ngcontent-c114="" innerhtml="Bem-vindo ao mundo da programa&amp;#231;&amp;#227;o. Aprenda as compet&amp;#234;ncias b&amp;#225;sicas que todos programadores usam quando eles programam aplicativos para celular, criam p&amp;#225;ginas na Web, ou analisam dados.">Bem-vindo ao mundo da programação. Aprenda as competências básicas que todos programadores usam quando eles programam aplicativos para celular, criam páginas na Web, ou analisam dados.</span></div>
# <!-- -->
# </div>
# </div>

# %%
# Extract title
summaries[0].select_one("h3 a").get_text().strip()
# Out:
# 'Aprenda a programar'

# %%
# Extract description
summaries[0].select_one("div[data-course-short-summary]").get_text().strip()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-4b2077b1abc4> in <module>()
#       1 # Extract description
# ----> 2 summaries[0].select_one("div['data-course-short-summary']").get_text().strip()
#
# AttributeError: 'NoneType' object has no attribute 'get_text'

# %%
# Find all course summaries, extract title and description
courses = []
summaries = soup.find_all("div", class_="course-summary-card")
for summary in summaries:
    title = summary.select_one("h3 a").get_text().strip()
    description = summary.select_one("div[data-course-short-summary]").get_text().strip()
    courses.append((title, description))

print(len(courses), "course summaries found. Sample:")
print(courses[0][0])
print(courses[0][1])

# %% [markdown]
# ## Normalization

# %% [markdown]
# ### Case Normalization

# %%
# Sample text
text = "The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war ? Is AI a bad thing ?"
print(text)
# Out:
# The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war ? Is AI a bad thing ?

# %%
# Convert to lowercase
text = text.lower() 
print(text)
# Out:
# the first time you see the second renaissance it may look boring. look at it at least twice and definitely watch part 2. it will change your view of the matrix. are the human people the ones who started the war ? is ai a bad thing ?

# %% [markdown]
# ### Punctuation Removal

# %%
import re

# Remove punctuation characters
text = re.sub(r"[^a-zA-Z0-9]", " ", text) 
print(text)
# Out:
# the first time you see the second renaissance it may look boring  look at it at least twice and definitely watch part 2  it will change your view of the matrix  are the human people the ones who started the war   is ai a bad thing

# %% [markdown]
# ## Tokenization

# %%
# Split text into tokens (words)
words = text.split()
print(words)
# Out:
# ['the', 'first', 'time', 'you', 'see', 'the', 'second', 'renaissance', 'it', 'may', 'look', 'boring', 'look', 'at', 'it', 'at', 'least', 'twice', 'and', 'definitely', 'watch', 'part', '2', 'it', 'will', 'change', 'your', 'view', 'of', 'the', 'matrix', 'are', 'the', 'human', 'people', 'the', 'ones', 'who', 'started', 'the', 'war', 'is', 'ai', 'a', 'bad', 'thing']

# %% [markdown]
# ### NLTK: Natural Language ToolKit

# %%
# Another sample text
text = "Dr. Smith graduated from the University of Washington. He later started an analytics firm called Lux, which catered to enterprise customers."
print(text)
# Out:
# Dr. Smith graduated from the University of Washington. He later started an analytics firm called Lux, which catered to enterprise customers.

# %%
from nltk.tokenize import word_tokenize

# Split text into words using NLTK
words = word_tokenize(text)
print(words)
# Out:
# ['Dr.', 'Smith', 'graduated', 'from', 'the', 'University', 'of', 'Washington', '.', 'He', 'later', 'started', 'an', 'analytics', 'firm', 'called', 'Lux', ',', 'which', 'catered', 'to', 'enterprise', 'customers', '.']

# %%
from nltk.tokenize import sent_tokenize

# Split text into sentences
sentences = sent_tokenize(text)
print(sentences)
# Out:
# ['Dr. Smith graduated from the University of Washington.', 'He later started an analytics firm called Lux, which catered to enterprise customers.']

# %%
# List stop words
from nltk.corpus import stopwords
print(stopwords.words("english"))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should', 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'couldn', 'didn', 'doesn', 'hadn', 'hasn', 'haven', 'isn', 'ma', 'mightn', 'mustn', 'needn', 'shan', 'shouldn', 'wasn', 'weren', 'won', 'wouldn']

# %%
# Reset text
text = "The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war ? Is AI a bad thing ?"

# Normalize it
text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower())

# Tokenize it
words = text.split()
print(words)
# Out:
# ['the', 'first', 'time', 'you', 'see', 'the', 'second', 'renaissance', 'it', 'may', 'look', 'boring', 'look', 'at', 'it', 'at', 'least', 'twice', 'and', 'definitely', 'watch', 'part', '2', 'it', 'will', 'change', 'your', 'view', 'of', 'the', 'matrix', 'are', 'the', 'human', 'people', 'the', 'ones', 'who', 'started', 'the', 'war', 'is', 'ai', 'a', 'bad', 'thing']

# %%
# Remove stop words
words = [w for w in words if w not in stopwords.words("english")]
print(words)
# Out:
# ['first', 'time', 'see', 'second', 'renaissance', 'may', 'look', 'boring', 'look', 'least', 'twice', 'definitely', 'watch', 'part', '2', 'change', 'view', 'matrix', 'human', 'people', 'ones', 'started', 'war', 'ai', 'bad', 'thing']

# %% [markdown]
# ## Part-of-Speech Tagging

# %%
from nltk import pos_tag

# Tag parts of speech (PoS)
sentence = word_tokenize("I always lie down to tell a lie.")
pos_tag(sentence)
# Out:
# [('I', 'PRP'),
#  ('always', 'RB'),
#  ('lie', 'VBP'),
#  ('down', 'RP'),
#  ('to', 'TO'),
#  ('tell', 'VB'),
#  ('a', 'DT'),
#  ('lie', 'NN'),
#  ('.', '.')]

# %% [markdown]
# ### Sentence Parsing

# %%
import nltk

# Define a custom grammar
my_grammar = nltk.CFG.fromstring("""
S -> NP VP
PP -> P NP
NP -> Det N | Det N PP | 'I'
VP -> V NP | VP PP
Det -> 'an' | 'my'
N -> 'elephant' | 'pajamas'
V -> 'shot'
P -> 'in'
""")
parser = nltk.ChartParser(my_grammar)

# Parse a sentence
sentence = word_tokenize("I shot an elephant in my pajamas")
for tree in parser.parse(sentence):
    print(tree)
# Out:
# (S
#   (NP I)
#   (VP
#     (VP (V shot) (NP (Det an) (N elephant)))
#     (PP (P in) (NP (Det my) (N pajamas)))))
# (S
#   (NP I)
#   (VP
#     (V shot)
#     (NP (Det an) (N elephant) (PP (P in) (NP (Det my) (N pajamas))))))

# %%
import IPython  # for displaying parse trees inline

# Visualize parse trees
for tree in parser.parse(sentence):
    IPython.display.display(tree)  # instead of tree.draw()
# Out:
# Tree('S', [Tree('NP', ['I']), Tree('VP', [Tree('VP', [Tree('V', ['shot']), Tree('NP', [Tree('Det', ['an']), Tree('N', ['elephant'])])]), Tree('PP', [Tree('P', ['in']), Tree('NP', [Tree('Det', ['my']), Tree('N', ['pajamas'])])])])])
# Tree('S', [Tree('NP', ['I']), Tree('VP', [Tree('V', ['shot']), Tree('NP', [Tree('Det', ['an']), Tree('N', ['elephant']), Tree('PP', [Tree('P', ['in']), Tree('NP', [Tree('Det', ['my']), Tree('N', ['pajamas'])])])])])])

# %%
from nltk import pos_tag, ne_chunk
from nltk.tokenize import word_tokenize

# Recognize named entities in a tagged sentence
tree = ne_chunk(pos_tag(word_tokenize("Antonio joined Udacity Inc. in California.")))
IPython.display.display(tree)
# Out:
# Tree('S', [Tree('PERSON', [('Antonio', 'NNP')]), ('joined', 'VBD'), Tree('ORGANIZATION', [('Udacity', 'NNP'), ('Inc.', 'NNP')]), ('in', 'IN'), Tree('GPE', [('California', 'NNP')]), ('.', '.')])

# %% [markdown]
# ## Stemming & Lemmatization
#
# ### Stemming

# %%
from nltk.stem.porter import PorterStemmer

# Reduce words to their stems
stemmed = [PorterStemmer().stem(w) for w in words]
print(stemmed)
# Out:
# ['first', 'time', 'see', 'second', 'renaiss', 'may', 'look', 'bore', 'look', 'least', 'twice', 'definit', 'watch', 'part', '2', 'chang', 'view', 'matrix', 'human', 'peopl', 'one', 'start', 'war', 'ai', 'bad', 'thing']

# %% [markdown]
# ### Lemmatization

# %%
from nltk.stem.wordnet import WordNetLemmatizer

# Reduce words to their root form
lemmed = [WordNetLemmatizer().lemmatize(w) for w in words]
print(lemmed)

# %%
# Lemmatize verbs by specifying pos
lemmed = [WordNetLemmatizer().lemmatize(w, pos='v') for w in lemmed]
print(lemmed)
